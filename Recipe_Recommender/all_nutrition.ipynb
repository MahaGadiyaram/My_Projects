# %%
#import libraries
import pandas as pd
import json
import re
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import requests
import warnings
import pprint
warnings.simplefilter('ignore')

# %%
#read all files
for file in os.listdir("./all_nutrition"):
    print(file)
# Out:
# nutrition1.csv
# nutrition2.csv
# nutrition3.csv
# nutrition4.csv
# nutrition5.csv
# nutrition6.csv
# nutrition7.csv
# nutrition8.csv
# nutrition9.csv

# %%
#store all csv into a dataframe
df_list = []
for file in os.listdir("./all_nutrition"):
    if file.endswith(".csv"):
        nutrition_df = pd.read_csv(f"./all_nutrition/{file}")#, sep=";")#, parse_dates=True)
        df_list.append(nutrition_df)
nutrition_df = pd.concat(df_list, sort=True)

# %%
nutrition_df.head()
# Out:
#    Alcohol g  Caffeine mg  Calcium mg  Calories kcal  Carbohydrates g  \
# 0        NaN          NaN      139.72         625.07            71.66
# 1        NaN          NaN      224.86         221.45            49.50
# 2        NaN          NaN      114.77         450.17            72.38
# 3        NaN          NaN       75.51         445.72            62.82
# 4        NaN          NaN       74.17         232.48            16.15
#
#    Cholesterol mg  Copper mg  Fat g  Fiber g  Folate µg  ...  Vitamin B2 mg  \
# 0             0.0       0.97  30.69     9.56     191.83  ...           0.33
# 1             0.0       1.07   0.82    25.12     310.98  ...           0.31
# 2             0.0       0.76  10.35     8.43     201.32  ...           0.94
# 3             0.0       0.25  16.90     5.28     176.59  ...           0.52
# 4             0.0       0.12  18.01     6.48     103.78  ...           0.15
#
#    Vitamin B3 mg  Vitamin B5 mg  Vitamin B6 mg  Vitamin C mg  Vitamin D µg  \
# 0           1.67           0.88           0.63         81.79           NaN
# 1           4.82           1.56           0.57         54.16           NaN
# 2           9.50           2.35           0.75          9.75          0.23
# 3           6.30           0.69           0.43        112.67           NaN
# 4           1.27           0.53           0.38        144.82           NaN
#
#    Vitamin E mg  Vitamin K µg  Zinc mg  recipe_id
# 0          3.29          5.16     3.60     715769
# 1          0.99         76.29     2.32     648257
# 2          1.18         75.67     2.60    1095745
# 3          4.08         27.70     1.46     658753
# 4          4.02        311.62     0.73     658515
#
# [5 rows x 34 columns]

# %%
#nutrition_df.info()

# %%
nutrition_df.fillna(value=0,inplace=True)

# %%
#nutrition_df.info()

# %%
new_nutrition_df=nutrition_df[['recipe_id','Carbohydrates g','Calories kcal','Fat g','Protein g']]
new_nutrition_df.head()
# Out:
#    recipe_id  Carbohydrates g  Calories kcal  Fat g  Protein g
# 0     715769            71.66         625.07  30.69      19.86
# 1     648257            49.50         221.45   0.82      15.21
# 2    1095745            72.38         450.17  10.35      20.54
# 3     658753            62.82         445.72  16.90      12.75
# 4     658515            16.15         232.48  18.01       5.82

# %%
#Creating new dataframe with selected nutrition elements
new_nutrition_df.to_csv('./final/new_nutrition.csv',index=False)

# %% [markdown]
# # Removing Duplicate rows

# %%
print(nutrition_df.duplicated().sum())
# Out:
# 62

# %%
nutrition_df.drop_duplicates(inplace=True)
nutrition_df.rename(columns={'recipe_id':'id'},inplace=True)
nutrition_df.head()
# Out:
#    Alcohol g  Caffeine mg  Calcium mg  Calories kcal  Carbohydrates g  \
# 0        0.0          0.0      139.72         625.07            71.66
# 1        0.0          0.0      224.86         221.45            49.50
# 2        0.0          0.0      114.77         450.17            72.38
# 3        0.0          0.0       75.51         445.72            62.82
# 4        0.0          0.0       74.17         232.48            16.15
#
#    Cholesterol mg  Copper mg  Fat g  Fiber g  Folate µg  ...  Vitamin B2 mg  \
# 0             0.0       0.97  30.69     9.56     191.83  ...           0.33
# 1             0.0       1.07   0.82    25.12     310.98  ...           0.31
# 2             0.0       0.76  10.35     8.43     201.32  ...           0.94
# 3             0.0       0.25  16.90     5.28     176.59  ...           0.52
# 4             0.0       0.12  18.01     6.48     103.78  ...           0.15
#
#    Vitamin B3 mg  Vitamin B5 mg  Vitamin B6 mg  Vitamin C mg  Vitamin D µg  \
# 0           1.67           0.88           0.63         81.79          0.00
# 1           4.82           1.56           0.57         54.16          0.00
# 2           9.50           2.35           0.75          9.75          0.23
# 3           6.30           0.69           0.43        112.67          0.00
# 4           1.27           0.53           0.38        144.82          0.00
#
#    Vitamin E mg  Vitamin K µg  Zinc mg       id
# 0          3.29          5.16     3.60   715769
# 1          0.99         76.29     2.32   648257
# 2          1.18         75.67     2.60  1095745
# 3          4.08         27.70     1.46   658753
# 4          4.02        311.62     0.73   658515
#
# [5 rows x 34 columns]

# %%
nutri_recipes=pd.read_csv('./final/all_recipes_new_df.csv')
nutri_recipes.head()
# Out:
#    Unnamed: 0                                  cuisines  dish  \
# 0           8  ['Mediterranean', 'Italian', 'European']     1
# 1          12                                   Italian     1
# 2          16                                   Italian     1
# 3          20                                   Italian     1
# 4          24                                   Italian     1
#
#                                    ingredients_lists       id  \
# 0  ['broccolini', 'garlic clove', 'olive oil', 'o...   715769
# 1  ['artichoke', 'bay leaf', 'coriander seeds', '...   648257
# 2  ['crusty bread', 'mushrooms', 'spinach', 'chic...  1095745
# 3  ['balsamic vinegar', 'extra virgin olive oil',...   658753
# 4  ['balsamic vinegar', 'brussels sprouts', 'extr...   658515
#
#                                                image  \
# 0  https://spoonacular.com/recipeImages/715769-31...
# 1  https://spoonacular.com/recipeImages/648257-31...
# 2  https://spoonacular.com/recipeImages/1095745-3...
# 3  https://spoonacular.com/recipeImages/658753-31...
# 4  https://spoonacular.com/recipeImages/658515-31...
#
#                                          ingredients  \
# 0  {'broccolini': '0.5 bunch', 'garlic clove': '0...
# 1  {'artichoke': '1.0 pound', 'bay leaf': '1.0 ',...
# 2  {'crusty bread': '0.25 loaf', 'mushrooms': '0....
# 3  {'balsamic vinegar': '0.5 tablespoons', 'extra...
# 4  {'balsamic vinegar': '0.25 tablespoon', 'bruss...
#
#                                         instructions  readyInMinutes  \
# 0  In a large pan with lid heat olive oil over me...              30
# 1  Snip the thorns off the artichoke leaves.Place...              35
# 2  To make the hummus, place all ingredients in a...              30
# 3  Slice the bread on a bias about 1/2 inch thick...              45
# 4  Heat oven to 450 degrees. Trim bottom of Bruss...              45
#
#    servings                                 title  Carbohydrates g  \
# 0         2               Broccolini Quinoa Pilaf            71.66
# 1         1            Italian Steamed Artichokes            49.50
# 2         4              Mushroom Hummus Crostini            76.92
# 3         4                Roma Tomato Bruschetta            67.36
# 4         4  Roasted Brussels Sprouts With Garlic            16.15
#
#    Calories kcal  Fat g  Protein g
# 0         625.07  30.69      19.86
# 1         221.45   0.82      15.21
# 2         468.07   9.76      21.49
# 3         466.44  16.31      13.70
# 4         232.48  18.01       5.82

# %%
nutri_eda_df=nutri_recipes.merge(nutrition_df,on='id')
nutri_eda_df.head()
# Out:
#    Unnamed: 0                                  cuisines  dish  \
# 0           8  ['Mediterranean', 'Italian', 'European']     1
# 1          12                                   Italian     1
# 2          16                                   Italian     1
# 3          20                                   Italian     1
# 4          24                                   Italian     1
#
#                                    ingredients_lists       id  \
# 0  ['broccolini', 'garlic clove', 'olive oil', 'o...   715769
# 1  ['artichoke', 'bay leaf', 'coriander seeds', '...   648257
# 2  ['crusty bread', 'mushrooms', 'spinach', 'chic...  1095745
# 3  ['balsamic vinegar', 'extra virgin olive oil',...   658753
# 4  ['balsamic vinegar', 'brussels sprouts', 'extr...   658515
#
#                                                image  \
# 0  https://spoonacular.com/recipeImages/715769-31...
# 1  https://spoonacular.com/recipeImages/648257-31...
# 2  https://spoonacular.com/recipeImages/1095745-3...
# 3  https://spoonacular.com/recipeImages/658753-31...
# 4  https://spoonacular.com/recipeImages/658515-31...
#
#                                          ingredients  \
# 0  {'broccolini': '0.5 bunch', 'garlic clove': '0...
# 1  {'artichoke': '1.0 pound', 'bay leaf': '1.0 ',...
# 2  {'crusty bread': '0.25 loaf', 'mushrooms': '0....
# 3  {'balsamic vinegar': '0.5 tablespoons', 'extra...
# 4  {'balsamic vinegar': '0.25 tablespoon', 'bruss...
#
#                                         instructions  readyInMinutes  \
# 0  In a large pan with lid heat olive oil over me...              30
# 1  Snip the thorns off the artichoke leaves.Place...              35
# 2  To make the hummus, place all ingredients in a...              30
# 3  Slice the bread on a bias about 1/2 inch thick...              45
# 4  Heat oven to 450 degrees. Trim bottom of Bruss...              45
#
#    servings  ... Vitamin B12 µg  Vitamin B2 mg  Vitamin B3 mg  Vitamin B5 mg  \
# 0         2  ...            0.0           0.33           1.67           0.88
# 1         1  ...            0.0           0.31           4.82           1.56
# 2         4  ...            0.0           0.94           9.50           2.35
# 3         4  ...            0.0           0.52           6.30           0.69
# 4         4  ...            0.0           0.15           1.27           0.53
#
#    Vitamin B6 mg  Vitamin C mg  Vitamin D µg  Vitamin E mg  Vitamin K µg  \
# 0           0.63         81.79          0.00          3.29          5.16
# 1           0.57         54.16          0.00          0.99         76.29
# 2           0.75          9.75          0.23          1.18         75.67
# 3           0.43        112.67          0.00          4.08         27.70
# 4           0.38        144.82          0.00          4.02        311.62
#
#    Zinc mg
# 0     3.60
# 1     2.32
# 2     2.60
# 3     1.46
# 4     0.73
#
# [5 rows x 48 columns]

# %%
nutri_eda_df.to_csv("./final/nutri_eda_df.csv")

# %%
nutri_eda_df.groupby(['title'])["Calcium mg"].max().sort_values(ascending=False).head(10).plot.barh()
# Out:
# <AxesSubplot:ylabel='title'>

# %%
#nutri_eda_df.groupby(['title'])["Calories kcal"].min().sort_values(ascending=True).head(10).plot.barh()

# %%
nutri_eda_df.groupby(['title'])["Iron mg"].max().sort_values(ascending=False).head(10).plot.barh()
# Out:
# <AxesSubplot:ylabel='title'>

# %%
nutri_eda_df.groupby(['title'])["Vitamin D µg"].max().sort_values(ascending=False).head(10).plot.barh()
# Out:
# <AxesSubplot:ylabel='title'>

# %%
nutri_eda_df.groupby(['title'])["Vitamin C mg"].max().sort_values(ascending=False).head(10).plot.barh()
# Out:
# <AxesSubplot:ylabel='title'>
