# %%
#import libraries
import pandas as pd
import json
import re
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import requests
import warnings
import pprint
import pymongo
from pymongo import MongoClient
warnings.simplefilter('ignore')

# %%
url ='https://api.spoonacular.com/recipes/complexSearch?apiKey=257730c23cd0485c954fa85caf38e2a1&cuisine=American&query=brunch&addRecipeInformation=True&addRecipeNutrition=True&number=100'
new_res4= requests.get(url).json()
new_res4
# Out:
# {'results': [{'vegetarian': False,
#    'vegan': False,
#    'glutenFree': True,
#    'dairyFree': False,
#    'veryHealthy': False,
#    'cheap': False,
#    'veryPopular': False,
#    'sustainable': False,
#    'weightWatcherSmartPoints': 32,
#    'gaps': 'no',
#    'lowFodmap': False,
#    'aggregateLikes': 1,
#    'spoonacularScore': 80.0,
#    'healthScore': 47.0,
#    'creditsText': 'Foodista.com – The Cooking Encyclopedia Everyone Can Edit',
#    'license': 'CC BY 3.0',
#    'sourceName': 'Foodista',
#    'pricePerServing': 391.1,
#    'id': 650377,
#    'title': 'Low Carb Brunch Burger',
#    'readyInMinutes': 30,
#    'servings': 2,
#    'sourceUrl': 'http://www.foodista.com/recipe/5SPTY657/low-carb-brunch-burger',
#    'image': 'https://spoonacular.com/recipeImages/650377-312x231.jpg',
#    'imageType': 'jpg',
#    'nutrition': {'nutrients': [{'name': 'Calories',
#       'amount': 1028.27,
#       'unit': 'kcal',
#       'percentOfDailyNeeds': 51.41},
#      {'name': 'Fat',
#       'amount': 82.55,
#       'unit': 'g',
#       'percentOfDailyNeeds': 127.0},
#      {'name': 'Saturated Fat',
#       'amount': 27.02,
#       'unit': 'g',
#       'percentOfDailyNeeds': 168.88},
#      {'name': 'Carbohydrates',
#       'amount': 17.57,
#       'unit': 'g',
#       'percentOfDailyNeeds': 5.86},
#      {'name': 'Net Carbohydrates',
#       'amount': 8.74,
#       'unit': 'g',
#       'percentOfDailyNeeds': 3.18},
#      {'name': 'Sugar',
#       'amount': 4.22,
#       'unit': 'g',
#       'percentOfDailyNeeds': 4.69},
#      {'name': 'Cholesterol',
#       'amount': 354.8,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 118.27},
#      {'name': 'Sodium',
#       'amount': 732.38,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 31.84},
#      {'name': 'Protein',
#       'amount': 53.8,
#       'unit': 'g',
#       'percentOfDailyNeeds': 107.59},
#      {'name': 'Vitamin C',
#       'amount': 105.74,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 128.17},
#      {'name': 'Vitamin B12',
#       'amount': 5.47,
#       'unit': 'µg',
#       'percentOfDailyNeeds': 91.22},
#      {'name': 'Selenium',
#       'amount': 57.9,
#       'unit': 'µg',
#       'percentOfDailyNeeds': 82.72},
#      {'name': 'Zinc',
#       'amount': 11.61,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 77.39},
#      {'name': 'Vitamin B6',
#       'amount': 1.46,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 73.08},
#      {'name': 'Vitamin B3',
#       'amount': 13.95,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 69.73},
#      {'name': 'Phosphorus',
#       'amount': 606.81,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 60.68},
#      {'name': 'Vitamin A',
#       'amount': 2756.88,
#       'unit': 'IU',
#       'percentOfDailyNeeds': 55.14},
#      {'name': 'Vitamin B2',
#       'amount': 0.78,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 45.87},
#      {'name': 'Potassium',
#       'amount': 1477.49,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 42.21},
#      {'name': 'Iron',
#       'amount': 7.16,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 39.76},
#      {'name': 'Folate',
#       'amount': 154.65,
#       'unit': 'µg',
#       'percentOfDailyNeeds': 38.66},
#      {'name': 'Vitamin B5',
#       'amount': 3.72,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 37.23},
#      {'name': 'Fiber',
#       'amount': 8.83,
#       'unit': 'g',
#       'percentOfDailyNeeds': 35.3},
#      {'name': 'Vitamin E',
#       'amount': 4.9,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 32.66},
#      {'name': 'Vitamin K',
#       'amount': 29.12,
#       'unit': 'µg',
#       'percentOfDailyNeeds': 27.73},
#      {'name': 'Vitamin B1',
#       'amount': 0.37,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 24.6},
#      {'name': 'Magnesium',
#       'amount': 94.72,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 23.68},
#      {'name': 'Copper',
#       'amount': 0.43,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 21.26},
#      {'name': 'Manganese',
#       'amount': 0.34,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 17.12},
#      {'name': 'Calcium',
#       'amount': 108.87,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 10.89},
#      {'name': 'Vitamin D',
#       'amount': 1.29,
#       'unit': 'µg',
#       'percentOfDailyNeeds': 8.59}],
#     'properties': [{'name': 'Glycemic Index', 'amount': 54.5, 'unit': ''},
#      {'name': 'Glycemic Load', 'amount': 1.79, 'unit': ''}],
#     'flavonoids': [{'name': 'Cyanidin', 'amount': 0.33, 'unit': 'mg'},
#      {'name': 'Petunidin', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Delphinidin', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Malvidin', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Pelargonidin', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Peonidin', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Catechin', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Epigallocatechin', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Epicatechin', 'amount': 0.37, 'unit': 'mg'},
#      {'name': 'Epicatechin 3-gallate', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Epigallocatechin 3-gallate', 'amount': 0.15, 'unit': 'mg'},
#      {'name': 'Theaflavin', 'amount': 0.0, 'unit': ''},
#      {'name': 'Thearubigins', 'amount': 0.0, 'unit': ''},
#      {'name': 'Eriodictyol', 'amount': 0.0, 'unit': ''},
#      {'name': 'Hesperetin', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Naringenin', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Apigenin', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Luteolin', 'amount': 0.45, 'unit': 'mg'},
#      {'name': 'Isorhamnetin', 'amount': 0.0, 'unit': ''},
#      {'name': 'Kaempferol', 'amount': 0.01, 'unit': 'mg'},
#      {'name': 'Myricetin', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Quercetin', 'amount': 0.17, 'unit': 'mg'},
#      {'name': "Theaflavin-3,3'-digallate", 'amount': 0.0, 'unit': ''},
#      {'name': "Theaflavin-3'-gallate", 'amount': 0.0, 'unit': ''},
#      {'name': 'Theaflavin-3-gallate', 'amount': 0.0, 'unit': ''},
#      {'name': 'Gallocatechin', 'amount': 0.0, 'unit': 'mg'}],
#     'ingredients': [{'id': 9037,
#       'name': 'avocado',
#       'amount': 0.5,
#       'unit': '',
#       'nutrients': [{'name': 'Choline', 'amount': 14.27, 'unit': 'mg'},
#        {'name': 'Fat', 'amount': 14.73, 'unit': 'g'},
#        {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sodium', 'amount': 7.04, 'unit': 'mg'},
#        {'name': 'Net Carbohydrates', 'amount': 1.84, 'unit': 'g'},
#        {'name': 'Phosphorus', 'amount': 52.26, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.07, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Zinc', 'amount': 0.64, 'unit': 'mg'},
#        {'name': 'Carbohydrates', 'amount': 8.57, 'unit': 'g'},
#        {'name': 'Vitamin B2', 'amount': 0.13, 'unit': 'mg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Manganese', 'amount': 0.14, 'unit': 'mg'},
#        {'name': 'Vitamin E', 'amount': 2.08, 'unit': 'mg'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Saturated Fat', 'amount': 2.14, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 160.8, 'unit': 'kcal'},
#        {'name': 'Vitamin A', 'amount': 146.73, 'unit': 'IU'},
#        {'name': 'Sugar', 'amount': 0.66, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 0.4, 'unit': 'µg'},
#        {'name': 'Fiber', 'amount': 6.73, 'unit': 'g'},
#        {'name': 'Iron', 'amount': 0.55, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 81.41, 'unit': 'µg'},
#        {'name': 'Magnesium', 'amount': 29.15, 'unit': 'mg'},
#        {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 1.4, 'unit': 'mg'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 9.85, 'unit': 'g'},
#        {'name': 'Vitamin B3', 'amount': 1.75, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.26, 'unit': 'mg'},
#        {'name': 'Vitamin K', 'amount': 21.11, 'unit': 'µg'},
#        {'name': 'Protein', 'amount': 2.01, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 487.43, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 10.05, 'unit': 'mg'},
#        {'name': 'Fluoride', 'amount': 7.04, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 12.06, 'unit': 'mg'},
#        {'name': 'Copper', 'amount': 0.19, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 1.83, 'unit': 'g'}]},
#      {'id': 10123,
#       'name': 'bacon',
#       'amount': 2.0,
#       'unit': 'strips',
#       'nutrients': [{'name': 'Choline', 'amount': 21.03, 'unit': 'mg'},
#        {'name': 'Fat', 'amount': 17.46, 'unit': 'g'},
#        {'name': 'Vitamin D', 'amount': 0.18, 'unit': 'µg'},
#        {'name': 'Sodium', 'amount': 291.28, 'unit': 'mg'},
#        {'name': 'Net Carbohydrates', 'amount': 0.56, 'unit': 'g'},
#        {'name': 'Phosphorus', 'amount': 63.36, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.12, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 29.04, 'unit': 'mg'},
#        {'name': 'Zinc', 'amount': 0.52, 'unit': 'mg'},
#        {'name': 'Carbohydrates', 'amount': 0.56, 'unit': 'g'},
#        {'name': 'Vitamin B2', 'amount': 0.04, 'unit': 'mg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Manganese', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin E', 'amount': 0.19, 'unit': 'mg'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Saturated Fat', 'amount': 5.85, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 183.48, 'unit': 'kcal'},
#        {'name': 'Vitamin A', 'amount': 16.28, 'unit': 'IU'},
#        {'name': 'Sugar', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 8.84, 'unit': 'µg'},
#        {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Iron', 'amount': 0.18, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Magnesium', 'amount': 5.28, 'unit': 'mg'},
#        {'name': 'Vitamin B12', 'amount': 0.22, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.24, 'unit': 'mg'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 7.67, 'unit': 'g'},
#        {'name': 'Vitamin B3', 'amount': 1.77, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.12, 'unit': 'mg'},
#        {'name': 'Vitamin K', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Protein', 'amount': 5.55, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 87.12, 'unit': 'mg'},
#        {'name': 'Trans Fat', 'amount': 0.06, 'unit': 'g'},
#        {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 2.2, 'unit': 'mg'},
#        {'name': 'Copper', 'amount': 0.02, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 2.84, 'unit': 'g'}]},
#      {'id': 1002014,
#       'name': 'cumin',
#       'amount': 1.0,
#       'unit': 'servings',
#       'nutrients': [{'name': 'Choline', 'amount': 0.25, 'unit': 'mg'},
#        {'name': 'Fat', 'amount': 0.22, 'unit': 'g'},
#        {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sodium', 'amount': 1.68, 'unit': 'mg'},
#        {'name': 'Net Carbohydrates', 'amount': 0.34, 'unit': 'g'},
#        {'name': 'Phosphorus', 'amount': 4.99, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Zinc', 'amount': 0.05, 'unit': 'mg'},
#        {'name': 'Carbohydrates', 'amount': 0.44, 'unit': 'g'},
#        {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Manganese', 'amount': 0.03, 'unit': 'mg'},
#        {'name': 'Vitamin E', 'amount': 0.03, 'unit': 'mg'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Saturated Fat', 'amount': 0.02, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 3.75, 'unit': 'kcal'},
#        {'name': 'Vitamin A', 'amount': 12.7, 'unit': 'IU'},
#        {'name': 'Sugar', 'amount': 0.02, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 0.05, 'unit': 'µg'},
#        {'name': 'Fiber', 'amount': 0.11, 'unit': 'g'},
#        {'name': 'Iron', 'amount': 0.66, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 0.1, 'unit': 'µg'},
#        {'name': 'Magnesium', 'amount': 3.66, 'unit': 'mg'},
#        {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 0.14, 'unit': 'g'},
#        {'name': 'Vitamin B3', 'amount': 0.05, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin K', 'amount': 0.05, 'unit': 'µg'},
#        {'name': 'Protein', 'amount': 0.18, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 17.88, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 0.08, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 9.31, 'unit': 'mg'},
#        {'name': 'Copper', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.03, 'unit': 'g'}]},
#      {'id': 1123,
#       'name': 'eggs',
#       'amount': 1.0,
#       'unit': '',
#       'nutrients': [{'name': 'Choline', 'amount': 129.27, 'unit': 'mg'},
#        {'name': 'Fat', 'amount': 4.18, 'unit': 'g'},
#        {'name': 'Vitamin D', 'amount': 0.88, 'unit': 'µg'},
#        {'name': 'Sodium', 'amount': 62.48, 'unit': 'mg'},
#        {'name': 'Net Carbohydrates', 'amount': 0.32, 'unit': 'g'},
#        {'name': 'Phosphorus', 'amount': 87.12, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.02, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 163.68, 'unit': 'mg'},
#        {'name': 'Zinc', 'amount': 0.57, 'unit': 'mg'},
#        {'name': 'Carbohydrates', 'amount': 0.32, 'unit': 'g'},
#        {'name': 'Vitamin B2', 'amount': 0.2, 'unit': 'mg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Manganese', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Vitamin E', 'amount': 0.46, 'unit': 'mg'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Saturated Fat', 'amount': 1.38, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 62.92, 'unit': 'kcal'},
#        {'name': 'Vitamin A', 'amount': 237.6, 'unit': 'IU'},
#        {'name': 'Sugar', 'amount': 0.16, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 13.51, 'unit': 'µg'},
#        {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Iron', 'amount': 0.77, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 20.68, 'unit': 'µg'},
#        {'name': 'Magnesium', 'amount': 5.28, 'unit': 'mg'},
#        {'name': 'Vitamin B12', 'amount': 0.39, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.67, 'unit': 'mg'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 1.61, 'unit': 'g'},
#        {'name': 'Vitamin B3', 'amount': 0.03, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.07, 'unit': 'mg'},
#        {'name': 'Vitamin K', 'amount': 0.13, 'unit': 'µg'},
#        {'name': 'Protein', 'amount': 5.53, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 60.72, 'unit': 'mg'},
#        {'name': 'Trans Fat', 'amount': 0.02, 'unit': 'g'},
#        {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Fluoride', 'amount': 0.48, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 24.64, 'unit': 'mg'},
#        {'name': 'Copper', 'amount': 0.03, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.84, 'unit': 'g'}]},
#      {'id': 1022020,
#       'name': 'garlic powder',
#       'amount': 1.0,
#       'unit': 'servings',
#       'nutrients': [{'name': 'Choline', 'amount': 2.03, 'unit': 'mg'},
#        {'name': 'Fat', 'amount': 0.02, 'unit': 'g'},
#        {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sodium', 'amount': 1.8, 'unit': 'mg'},
#        {'name': 'Net Carbohydrates', 'amount': 1.91, 'unit': 'g'},
#        {'name': 'Phosphorus', 'amount': 12.42, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Zinc', 'amount': 0.09, 'unit': 'mg'},
#        {'name': 'Carbohydrates', 'amount': 2.18, 'unit': 'g'},
#        {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Manganese', 'amount': 0.03, 'unit': 'mg'},
#        {'name': 'Vitamin E', 'amount': 0.02, 'unit': 'mg'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Saturated Fat', 'amount': 0.01, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 9.93, 'unit': 'kcal'},
#        {'name': 'Vitamin A', 'amount': 0.0, 'unit': 'IU'},
#        {'name': 'Sugar', 'amount': 0.07, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 0.72, 'unit': 'µg'},
#        {'name': 'Fiber', 'amount': 0.27, 'unit': 'g'},
#        {'name': 'Iron', 'amount': 0.17, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 1.41, 'unit': 'µg'},
#        {'name': 'Magnesium', 'amount': 2.31, 'unit': 'mg'},
#        {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.02, 'unit': 'mg'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin B3', 'amount': 0.02, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.05, 'unit': 'mg'},
#        {'name': 'Vitamin K', 'amount': 0.01, 'unit': 'µg'},
#        {'name': 'Protein', 'amount': 0.5, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 35.79, 'unit': 'mg'},
#        {'name': 'Trans Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin C', 'amount': 0.04, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 2.37, 'unit': 'mg'},
#        {'name': 'Copper', 'amount': 0.02, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.01, 'unit': 'g'}]},
#      {'id': 10023572,
#       'name': 'ground beef',
#       'amount': 0.5,
#       'unit': 'lb',
#       'nutrients': [{'name': 'Choline', 'amount': 127.91, 'unit': 'mg'},
#        {'name': 'Fat', 'amount': 45.36, 'unit': 'g'},
#        {'name': 'Vitamin D', 'amount': 0.23, 'unit': 'µg'},
#        {'name': 'Sodium', 'amount': 151.95, 'unit': 'mg'},
#        {'name': 'Net Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Phosphorus', 'amount': 358.34, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.1, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 161.03, 'unit': 'mg'},
#        {'name': 'Zinc', 'amount': 9.48, 'unit': 'mg'},
#        {'name': 'Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin B2', 'amount': 0.34, 'unit': 'mg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Manganese', 'amount': 0.02, 'unit': 'mg'},
#        {'name': 'Vitamin E', 'amount': 0.93, 'unit': 'mg'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Saturated Fat', 'amount': 17.4, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 576.06, 'unit': 'kcal'},
#        {'name': 'Vitamin A', 'amount': 0.0, 'unit': 'IU'},
#        {'name': 'Sugar', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 34.02, 'unit': 'µg'},
#        {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Iron', 'amount': 4.4, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 15.88, 'unit': 'µg'},
#        {'name': 'Magnesium', 'amount': 38.56, 'unit': 'mg'},
#        {'name': 'Vitamin B12', 'amount': 4.85, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 1.14, 'unit': 'mg'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 19.86, 'unit': 'g'},
#        {'name': 'Vitamin B3', 'amount': 9.59, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.73, 'unit': 'mg'},
#        {'name': 'Vitamin K', 'amount': 4.08, 'unit': 'µg'},
#        {'name': 'Protein', 'amount': 38.94, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 612.35, 'unit': 'mg'},
#        {'name': 'Trans Fat', 'amount': 2.79, 'unit': 'g'},
#        {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Fluoride', 'amount': 50.8, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 40.82, 'unit': 'mg'},
#        {'name': 'Copper', 'amount': 0.14, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 1.18, 'unit': 'g'}]},
#      {'id': 2026,
#       'name': 'onion powder',
#       'amount': 1.0,
#       'unit': 'servings',
#       'nutrients': [{'name': 'Choline', 'amount': 0.39, 'unit': 'mg'},
#        {'name': 'Fat', 'amount': 0.01, 'unit': 'g'},
#        {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sodium', 'amount': 0.73, 'unit': 'mg'},
#        {'name': 'Net Carbohydrates', 'amount': 0.64, 'unit': 'g'},
#        {'name': 'Phosphorus', 'amount': 3.22, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Zinc', 'amount': 0.04, 'unit': 'mg'},
#        {'name': 'Carbohydrates', 'amount': 0.79, 'unit': 'g'},
#        {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Manganese', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Vitamin E', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 3.41, 'unit': 'kcal'},
#        {'name': 'Vitamin A', 'amount': 0.0, 'unit': 'IU'},
#        {'name': 'Sugar', 'amount': 0.07, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 0.14, 'unit': 'µg'},
#        {'name': 'Fiber', 'amount': 0.15, 'unit': 'g'},
#        {'name': 'Iron', 'amount': 0.04, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 0.64, 'unit': 'µg'},
#        {'name': 'Magnesium', 'amount': 1.13, 'unit': 'mg'},
#        {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin B3', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Vitamin K', 'amount': 0.04, 'unit': 'µg'},
#        {'name': 'Protein', 'amount': 0.1, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 9.85, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 0.23, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 3.84, 'unit': 'mg'},
#        {'name': 'Copper', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.0, 'unit': 'g'}]},
#      {'id': 10211821,
#       'name': 'bell pepper',
#       'amount': 1.0,
#       'unit': 'servings',
#       'nutrients': [{'name': 'Choline', 'amount': 4.17, 'unit': 'mg'},
#        {'name': 'Fat', 'amount': 0.22, 'unit': 'g'},
#        {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sodium', 'amount': 2.98, 'unit': 'mg'},
#        {'name': 'Net Carbohydrates', 'amount': 2.93, 'unit': 'g'},
#        {'name': 'Phosphorus', 'amount': 19.37, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.04, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Zinc', 'amount': 0.19, 'unit': 'mg'},
#        {'name': 'Carbohydrates', 'amount': 4.49, 'unit': 'g'},
#        {'name': 'Vitamin B2', 'amount': 0.06, 'unit': 'mg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Manganese', 'amount': 0.08, 'unit': 'mg'},
#        {'name': 'Vitamin E', 'amount': 1.18, 'unit': 'mg'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Saturated Fat', 'amount': 0.02, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 23.1, 'unit': 'kcal'},
#        {'name': 'Vitamin A', 'amount': 2332.59, 'unit': 'IU'},
#        {'name': 'Sugar', 'amount': 3.13, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 0.07, 'unit': 'µg'},
#        {'name': 'Fiber', 'amount': 1.56, 'unit': 'g'},
#        {'name': 'Iron', 'amount': 0.32, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 34.27, 'unit': 'µg'},
#        {'name': 'Magnesium', 'amount': 8.94, 'unit': 'mg'},
#        {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.24, 'unit': 'mg'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin B3', 'amount': 0.73, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.22, 'unit': 'mg'},
#        {'name': 'Vitamin K', 'amount': 3.65, 'unit': 'µg'},
#        {'name': 'Protein', 'amount': 0.74, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 157.2, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 95.14, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 5.22, 'unit': 'mg'},
#        {'name': 'Copper', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.05, 'unit': 'g'}]},
#      {'id': 2047,
#       'name': 'salt',
#       'amount': 1.0,
#       'unit': 'servings',
#       'nutrients': [{'name': 'Choline', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sodium', 'amount': 193.79, 'unit': 'mg'},
#        {'name': 'Net Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Phosphorus', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Zinc', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Manganese', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin E', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 0.0, 'unit': 'kcal'},
#        {'name': 'Vitamin A', 'amount': 0.0, 'unit': 'IU'},
#        {'name': 'Sugar', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Iron', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Magnesium', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin B3', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin K', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Protein', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 0.04, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Fluoride', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 0.12, 'unit': 'mg'},
#        {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.0, 'unit': 'g'}]},
#      {'id': 1031009,
#       'name': 'sharp cheddar',
#       'amount': 1.0,
#       'unit': 'large slices',
#       'nutrients': [{'name': 'Choline', 'amount': 0.17, 'unit': 'mg'},
#        {'name': 'Fat', 'amount': 0.33, 'unit': 'g'},
#        {'name': 'Vitamin D', 'amount': 0.01, 'unit': 'µg'},
#        {'name': 'Sodium', 'amount': 6.21, 'unit': 'mg'},
#        {'name': 'Net Carbohydrates', 'amount': 0.01, 'unit': 'g'},
#        {'name': 'Phosphorus', 'amount': 5.12, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 1.05, 'unit': 'mg'},
#        {'name': 'Zinc', 'amount': 0.03, 'unit': 'mg'},
#        {'name': 'Carbohydrates', 'amount': 0.01, 'unit': 'g'},
#        {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Manganese', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin E', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Saturated Fat', 'amount': 0.21, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 4.03, 'unit': 'kcal'},
#        {'name': 'Vitamin A', 'amount': 10.02, 'unit': 'IU'},
#        {'name': 'Sugar', 'amount': 0.01, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 0.14, 'unit': 'µg'},
#        {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Iron', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 0.18, 'unit': 'µg'},
#        {'name': 'Magnesium', 'amount': 0.28, 'unit': 'mg'},
#        {'name': 'Vitamin B12', 'amount': 0.01, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 0.09, 'unit': 'g'},
#        {'name': 'Vitamin B3', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin K', 'amount': 0.03, 'unit': 'µg'},
#        {'name': 'Protein', 'amount': 0.25, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 0.98, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Fluoride', 'amount': 0.35, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 7.21, 'unit': 'mg'},
#        {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.01, 'unit': 'g'}]},
#      {'id': 6168,
#       'name': 'tabasco sauce',
#       'amount': 1.0,
#       'unit': 'dashes',
#       'nutrients': [{'name': 'Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Sodium', 'amount': 2.64, 'unit': 'mg'},
#        {'name': 'Net Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Phosphorus', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Zinc', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Manganese', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin E', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 0.01, 'unit': 'kcal'},
#        {'name': 'Vitamin A', 'amount': 0.16, 'unit': 'IU'},
#        {'name': 'Sugar', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Iron', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 0.01, 'unit': 'µg'},
#        {'name': 'Magnesium', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin B3', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin K', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Protein', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 0.14, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 0.07, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.0, 'unit': 'g'}]},
#      {'id': 6971,
#       'name': 'worcestershire sauce',
#       'amount': 1.0,
#       'unit': 'dashes',
#       'nutrients': [{'name': 'Choline', 'amount': 0.03, 'unit': 'mg'},
#        {'name': 'Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sodium', 'amount': 9.8, 'unit': 'mg'},
#        {'name': 'Net Carbohydrates', 'amount': 0.19, 'unit': 'g'},
#        {'name': 'Phosphorus', 'amount': 0.6, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Zinc', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Carbohydrates', 'amount': 0.19, 'unit': 'g'},
#        {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin E', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 0.78, 'unit': 'kcal'},
#        {'name': 'Vitamin A', 'amount': 0.79, 'unit': 'IU'},
#        {'name': 'Sugar', 'amount': 0.1, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 0.01, 'unit': 'µg'},
#        {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Iron', 'amount': 0.05, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 0.08, 'unit': 'µg'},
#        {'name': 'Magnesium', 'amount': 0.13, 'unit': 'mg'},
#        {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin B3', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin K', 'amount': 0.01, 'unit': 'µg'},
#        {'name': 'Protein', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 8.0, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 0.13, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 1.07, 'unit': 'mg'},
#        {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.0, 'unit': 'g'}]}],
#     'caloricBreakdown': {'percentProtein': 20.92,
#      'percentFat': 72.24,
#      'percentCarbs': 6.84},
#     'weightPerServing': {'amount': 497, 'unit': 'g'}},
#    'summary': 'The recipe Low Carb Brunch Burger could satisfy your American craving in approximately <b>30 minutes</b>. One serving contains <b>1114 calories</b>, <b>60g of protein</b>, and <b>91g of fat</b>. This gluten free recipe serves 2 and costs <b>$3.83 per serving</b>. Only a few people really liked this main course. This recipe from Foodista has 1 fans. A mixture of pepper, garlic powder, ground beef, and a handful of other ingredients are all it takes to make this recipe so delicious. To use up the cumin you could follow this main course with the <a href="https://spoonacular.com/recipes/moroccan-chocolate-mousse-752536">Moroccan Chocolate Mousse</a> as a dessert. All things considered, we decided this recipe <b>deserves a spoonacular score of 77%</b>. This score is good. Try <a href="https://spoonacular.com/recipes/low-carb-cauliflower-tortillas-918971">Low-carb cauliflower tortillas</a>, <a href="https://spoonacular.com/recipes/low-carb-cauliflower-pizza-918972">Low-carb cauliflower pizza</a>, and <a href="https://spoonacular.com/recipes/best-low-carb-chocolate-buttercream-921159">Best Low Carb Chocolate Buttercream</a> for similar recipes.',
#    'cuisines': ['American'],
#    'dishTypes': ['morning meal', 'brunch', 'breakfast'],
#    'diets': ['gluten free'],
#    'occasions': [],
#    'analyzedInstructions': [{'name': '',
#      'steps': [{'number': 1,
#        'step': 'Fry up 4 strips of bacon and set aside.Leave some of the bacon fat in the pan but remove from the eye.Put all of the spices and sauces into the ground beef, mix well and form even patties.',
#        'ingredients': [{'id': 10023572,
#          'name': 'ground beef',
#          'localizedName': 'ground beef',
#          'image': 'fresh-ground-beef.jpg'},
#         {'id': 4609,
#          'name': 'bacon drippings',
#          'localizedName': 'bacon drippings',
#          'image': 'raw-bacon.png'},
#         {'id': 2035,
#          'name': 'spices',
#          'localizedName': 'spices',
#          'image': 'spices.png'},
#         {'id': 10123,
#          'name': 'bacon',
#          'localizedName': 'bacon',
#          'image': 'raw-bacon.png'}],
#        'equipment': [{'id': 404645,
#          'name': 'frying pan',
#          'localizedName': 'frying pan',
#          'image': 'pan.png'}]},
#       {'number': 2,
#        'step': 'Heat a large non-stick skillet until the pan (with some of the bacon fat in it) is hot.',
#        'ingredients': [{'id': 4609,
#          'name': 'bacon drippings',
#          'localizedName': 'bacon drippings',
#          'image': 'raw-bacon.png'}],
#        'equipment': [{'id': 404645,
#          'name': 'frying pan',
#          'localizedName': 'frying pan',
#          'image': 'pan.png'}]},
#       {'number': 3,
#        'step': 'Place patties in hot pan and sear for 1 minute and 30 seconds each side. After searing the burgers, remove them from stove top and bake off in the oven at 415 degrees until it reaches your desired temperature (3-4 minutes).While the burgers are in the oven, get your egg going. On the same hot eye where you did your burger, use a new non-stick pan for the eggs. On the two over easy eggs, grind 2 grinds of salt, 2 grinds of pepper and a dash of Tabasco onto each egg yolk.',
#        'ingredients': [{'id': 1125,
#          'name': 'egg yolk',
#          'localizedName': 'egg yolk',
#          'image': 'egg-yolk.jpg'},
#         {'id': 1026168,
#          'name': 'tabasco sauce',
#          'localizedName': 'tabasco sauce',
#          'image': 'hot-sauce-or-tabasco.png'},
#         {'id': 1002030,
#          'name': 'pepper',
#          'localizedName': 'pepper',
#          'image': 'pepper.jpg'},
#         {'id': 1123,
#          'name': 'egg',
#          'localizedName': 'egg',
#          'image': 'egg.png'},
#         {'id': 2047,
#          'name': 'salt',
#          'localizedName': 'salt',
#          'image': 'salt.jpg'}],
#        'equipment': [{'id': 404794,
#          'name': 'stove',
#          'localizedName': 'stove',
#          'image': 'oven.jpg'},
#         {'id': 404784,
#          'name': 'oven',
#          'localizedName': 'oven',
#          'image': 'oven.jpg'},
#         {'id': 404645,
#          'name': 'frying pan',
#          'localizedName': 'frying pan',
#          'image': 'pan.png'}],
#        'length': {'number': 5, 'unit': 'minutes'}},
#       {'number': 4,
#        'step': 'Add the cheese on the burgers when the burgers have about 1 minute of cook time remaining, so the cheese melts.',
#        'ingredients': [{'id': 1041009,
#          'name': 'cheese',
#          'localizedName': 'cheese',
#          'image': 'cheddar-cheese.png'}],
#        'equipment': [],
#        'length': {'number': 1, 'unit': 'minutes'}}]}],
#    'spoonacularSourceUrl': 'https://spoonacular.com/low-carb-brunch-burger-650377'},
#   {'vegetarian': True,
#    'vegan': False,
#    'glutenFree': True,
#    'dairyFree': True,
#    'veryHealthy': False,
#    'cheap': False,
#    'veryPopular': False,
#    'sustainable': False,
#    'weightWatcherSmartPoints': 7,
#    'gaps': 'no',
#    'lowFodmap': False,
#    'aggregateLikes': 1,
#    'spoonacularScore': 36.0,
#    'healthScore': 6.0,
#    'creditsText': 'Foodista.com – The Cooking Encyclopedia Everyone Can Edit',
#    'license': 'CC BY 3.0',
#    'sourceName': 'Foodista',
#    'pricePerServing': 100.65,
#    'id': 662584,
#    'title': 'Sweet Potato Kimchi Hash Brunch - gluten free, dairy free, vegetarian',
#    'readyInMinutes': 45,
#    'servings': 6,
#    'sourceUrl': 'https://www.foodista.com/recipe/T8TJXJ3K/sweet-potato-kimchi-hash-brunch-gluten-free-dairy-free-vegetarian',
#    'image': 'https://spoonacular.com/recipeImages/662584-312x231.jpg',
#    'imageType': 'jpg',
#    'nutrition': {'nutrients': [{'name': 'Calories',
#       'amount': 225.13,
#       'unit': 'kcal',
#       'percentOfDailyNeeds': 11.26},
#      {'name': 'Fat',
#       'amount': 7.85,
#       'unit': 'g',
#       'percentOfDailyNeeds': 12.07},
#      {'name': 'Saturated Fat',
#       'amount': 6.33,
#       'unit': 'g',
#       'percentOfDailyNeeds': 39.59},
#      {'name': 'Carbohydrates',
#       'amount': 36.06,
#       'unit': 'g',
#       'percentOfDailyNeeds': 12.02},
#      {'name': 'Net Carbohydrates',
#       'amount': 30.76,
#       'unit': 'g',
#       'percentOfDailyNeeds': 11.18},
#      {'name': 'Sugar',
#       'amount': 9.11,
#       'unit': 'g',
#       'percentOfDailyNeeds': 10.13},
#      {'name': 'Cholesterol',
#       'amount': 27.28,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 9.09},
#      {'name': 'Sodium',
#       'amount': 870.66,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 37.85},
#      {'name': 'Protein',
#       'amount': 3.89,
#       'unit': 'g',
#       'percentOfDailyNeeds': 7.78},
#      {'name': 'Vitamin A',
#       'amount': 21464.9,
#       'unit': 'IU',
#       'percentOfDailyNeeds': 429.3},
#      {'name': 'Manganese',
#       'amount': 0.52,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 26.08},
#      {'name': 'Fiber',
#       'amount': 5.3,
#       'unit': 'g',
#       'percentOfDailyNeeds': 21.2},
#      {'name': 'Vitamin B6',
#       'amount': 0.4,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 19.93},
#      {'name': 'Potassium',
#       'amount': 588.63,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 16.82},
#      {'name': 'Vitamin B5',
#       'amount': 1.38,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 13.83},
#      {'name': 'Copper',
#       'amount': 0.26,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 13.01},
#      {'name': 'Magnesium',
#       'amount': 43.92,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 10.98},
#      {'name': 'Phosphorus',
#       'amount': 100.44,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 10.04},
#      {'name': 'Vitamin B1',
#       'amount': 0.14,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 9.5},
#      {'name': 'Vitamin C',
#       'amount': 7.57,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 9.18},
#      {'name': 'Vitamin B2',
#       'amount': 0.14,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 8.2},
#      {'name': 'Folate',
#       'amount': 28.32,
#       'unit': 'µg',
#       'percentOfDailyNeeds': 7.08},
#      {'name': 'Iron',
#       'amount': 1.23,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 6.84},
#      {'name': 'Calcium',
#       'amount': 64.67,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 6.47},
#      {'name': 'Vitamin K',
#       'amount': 5.8,
#       'unit': 'µg',
#       'percentOfDailyNeeds': 5.53},
#      {'name': 'Selenium',
#       'amount': 3.65,
#       'unit': 'µg',
#       'percentOfDailyNeeds': 5.21},
#      {'name': 'Vitamin B3',
#       'amount': 0.91,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 4.56},
#      {'name': 'Zinc',
#       'amount': 0.65,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 4.3},
#      {'name': 'Vitamin E',
#       'amount': 0.49,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 3.27},
#      {'name': 'Vitamin B12',
#       'amount': 0.07,
#       'unit': 'µg',
#       'percentOfDailyNeeds': 1.09}],
#     'properties': [{'name': 'Glycemic Index', 'amount': 43.5, 'unit': ''},
#      {'name': 'Glycemic Load', 'amount': 16.15, 'unit': ''}],
#     'flavonoids': [{'name': 'Cyanidin', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Petunidin', 'amount': 0.0, 'unit': ''},
#      {'name': 'Delphinidin', 'amount': 0.0, 'unit': ''},
#      {'name': 'Malvidin', 'amount': 0.0, 'unit': ''},
#      {'name': 'Pelargonidin', 'amount': 0.0, 'unit': ''},
#      {'name': 'Peonidin', 'amount': 0.0, 'unit': ''},
#      {'name': 'Catechin', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Epigallocatechin', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Epicatechin', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Epicatechin 3-gallate', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Epigallocatechin 3-gallate', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Theaflavin', 'amount': 0.0, 'unit': ''},
#      {'name': 'Thearubigins', 'amount': 0.0, 'unit': ''},
#      {'name': 'Eriodictyol', 'amount': 0.0, 'unit': ''},
#      {'name': 'Hesperetin', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Naringenin', 'amount': 0.0, 'unit': ''},
#      {'name': 'Apigenin', 'amount': 0.02, 'unit': 'mg'},
#      {'name': 'Luteolin', 'amount': 0.04, 'unit': 'mg'},
#      {'name': 'Isorhamnetin', 'amount': 1.91, 'unit': 'mg'},
#      {'name': 'Kaempferol', 'amount': 0.42, 'unit': 'mg'},
#      {'name': 'Myricetin', 'amount': 0.09, 'unit': 'mg'},
#      {'name': 'Quercetin', 'amount': 7.55, 'unit': 'mg'},
#      {'name': "Theaflavin-3,3'-digallate", 'amount': 0.0, 'unit': ''},
#      {'name': "Theaflavin-3'-gallate", 'amount': 0.0, 'unit': ''},
#      {'name': 'Theaflavin-3-gallate', 'amount': 0.0, 'unit': ''},
#      {'name': 'Gallocatechin', 'amount': 0.0, 'unit': 'mg'}],
#     'ingredients': [{'id': 4047,
#       'name': 'coconut oil',
#       'amount': 0.5,
#       'unit': 'tablespoons',
#       'nutrients': [{'name': 'Choline', 'amount': 0.02, 'unit': 'mg'},
#        {'name': 'Fat', 'amount': 7.0, 'unit': 'g'},
#        {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sodium', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Net Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Phosphorus', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Zinc', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Manganese', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin E', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Saturated Fat', 'amount': 6.06, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 60.34, 'unit': 'kcal'},
#        {'name': 'Vitamin A', 'amount': 0.0, 'unit': 'IU'},
#        {'name': 'Sugar', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Iron', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Magnesium', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 0.41, 'unit': 'g'},
#        {'name': 'Vitamin B3', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin K', 'amount': 0.03, 'unit': 'µg'},
#        {'name': 'Protein', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.13, 'unit': 'g'}]},
#      {'id': 11282,
#       'name': 'onions',
#       'amount': 0.33,
#       'unit': 'medium',
#       'nutrients': [{'name': 'Choline', 'amount': 2.24, 'unit': 'mg'},
#        {'name': 'Fat', 'amount': 0.04, 'unit': 'g'},
#        {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sodium', 'amount': 1.47, 'unit': 'mg'},
#        {'name': 'Net Carbohydrates', 'amount': 2.8, 'unit': 'g'},
#        {'name': 'Phosphorus', 'amount': 10.63, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.02, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Zinc', 'amount': 0.06, 'unit': 'mg'},
#        {'name': 'Carbohydrates', 'amount': 3.42, 'unit': 'g'},
#        {'name': 'Vitamin B2', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Manganese', 'amount': 0.05, 'unit': 'mg'},
#        {'name': 'Vitamin E', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Saturated Fat', 'amount': 0.02, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 14.67, 'unit': 'kcal'},
#        {'name': 'Vitamin A', 'amount': 0.73, 'unit': 'IU'},
#        {'name': 'Sugar', 'amount': 1.55, 'unit': 'g'},
# ...
#        {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Manganese', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Vitamin E', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 2.67, 'unit': 'kcal'},
#        {'name': 'Vitamin A', 'amount': 0.27, 'unit': 'IU'},
#        {'name': 'Sugar', 'amount': 0.05, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 0.02, 'unit': 'µg'},
#        {'name': 'Fiber', 'amount': 0.06, 'unit': 'g'},
#        {'name': 'Iron', 'amount': 0.03, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 0.69, 'unit': 'µg'},
#        {'name': 'Magnesium', 'amount': 0.84, 'unit': 'mg'},
#        {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin B3', 'amount': 0.04, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Vitamin K', 'amount': 0.11, 'unit': 'µg'},
#        {'name': 'Protein', 'amount': 0.07, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 17.34, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 0.33, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 0.38, 'unit': 'mg'},
#        {'name': 'Copper', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.0, 'unit': 'g'}]},
#      {'id': 1002030,
#       'name': 'black pepper',
#       'amount': 1.0,
#       'unit': 'teaspoons',
#       'nutrients': [{'name': 'Choline', 'amount': 0.23, 'unit': 'mg'},
#        {'name': 'Fat', 'amount': 0.07, 'unit': 'g'},
#        {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sodium', 'amount': 0.4, 'unit': 'mg'},
#        {'name': 'Net Carbohydrates', 'amount': 0.77, 'unit': 'g'},
#        {'name': 'Phosphorus', 'amount': 3.16, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Zinc', 'amount': 0.02, 'unit': 'mg'},
#        {'name': 'Carbohydrates', 'amount': 1.28, 'unit': 'g'},
#        {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Manganese', 'amount': 0.26, 'unit': 'mg'},
#        {'name': 'Vitamin E', 'amount': 0.02, 'unit': 'mg'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Saturated Fat', 'amount': 0.03, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 5.02, 'unit': 'kcal'},
#        {'name': 'Vitamin A', 'amount': 10.94, 'unit': 'IU'},
#        {'name': 'Sugar', 'amount': 0.01, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 0.1, 'unit': 'µg'},
#        {'name': 'Fiber', 'amount': 0.51, 'unit': 'g'},
#        {'name': 'Iron', 'amount': 0.19, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 0.34, 'unit': 'µg'},
#        {'name': 'Magnesium', 'amount': 3.42, 'unit': 'mg'},
#        {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.03, 'unit': 'mg'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 0.01, 'unit': 'g'},
#        {'name': 'Vitamin B3', 'amount': 0.02, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Vitamin K', 'amount': 3.27, 'unit': 'µg'},
#        {'name': 'Protein', 'amount': 0.21, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 26.58, 'unit': 'mg'},
#        {'name': 'Trans Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Fluoride', 'amount': 0.68, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 8.86, 'unit': 'mg'},
#        {'name': 'Copper', 'amount': 0.03, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.02, 'unit': 'g'}]},
#      {'id': 2047,
#       'name': 'salt',
#       'amount': 0.75,
#       'unit': 'teaspoons',
#       'nutrients': [{'name': 'Choline', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sodium', 'amount': 1744.11, 'unit': 'mg'},
#        {'name': 'Net Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Phosphorus', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Zinc', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Manganese', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin E', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 0.0, 'unit': 'kcal'},
#        {'name': 'Vitamin A', 'amount': 0.0, 'unit': 'IU'},
#        {'name': 'Sugar', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Iron', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Magnesium', 'amount': 0.05, 'unit': 'mg'},
#        {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin B3', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin K', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Protein', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 0.36, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Fluoride', 'amount': 0.09, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 1.08, 'unit': 'mg'},
#        {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.0, 'unit': 'g'}]},
#      {'id': 4053,
#       'name': 'olive oil',
#       'amount': 1.0,
#       'unit': 'tablespoons',
#       'nutrients': [{'name': 'Choline', 'amount': 0.04, 'unit': 'mg'},
#        {'name': 'Fat', 'amount': 14.0, 'unit': 'g'},
#        {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sodium', 'amount': 0.28, 'unit': 'mg'},
#        {'name': 'Net Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Phosphorus', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Zinc', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Manganese', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin E', 'amount': 2.01, 'unit': 'mg'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Saturated Fat', 'amount': 1.93, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 123.76, 'unit': 'kcal'},
#        {'name': 'Vitamin A', 'amount': 0.0, 'unit': 'IU'},
#        {'name': 'Sugar', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Iron', 'amount': 0.08, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Magnesium', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 10.21, 'unit': 'g'},
#        {'name': 'Vitamin B3', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin K', 'amount': 8.43, 'unit': 'µg'},
#        {'name': 'Protein', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 0.14, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 0.14, 'unit': 'mg'},
#        {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 1.47, 'unit': 'g'}]}],
#     'caloricBreakdown': {'percentProtein': 21.38,
#      'percentFat': 62.23,
#      'percentCarbs': 16.39},
#     'weightPerServing': {'amount': 436, 'unit': 'g'}},
#    'summary': 'Country Breakfast: Tofu and Veggie Scramble With Home Fries is a <b>gluten free, dairy free, lacto ovo vegetarian, and vegan</b> recipe with 2 servings. One serving contains <b>443 calories</b>, <b>25g of protein</b>, and <b>32g of fat</b>. For <b>$3.1 per serving</b>, this recipe <b>covers 18%</b> of your daily requirements of vitamins and minerals. Not a lot of people made this recipe, and 1 would say it hit the spot. It works well as a breakfast. It is brought to you by Foodista. Head to the store and pick up asparagus, cayenne pepper, olive oil, and a few other things to make it today. From preparation to the plate, this recipe takes about <b>about 45 minutes</b>. This recipe is typical of American cuisine. All things considered, we decided this recipe <b>deserves a spoonacular score of 59%</b>. This score is solid. If you like this recipe, you might also like recipes such as <a href="https://spoonacular.com/recipes/veggie-scramble-and-breakfast-sandwich-607324">Veggie Scramble and Breakfast Sandwich</a>, <a href="https://spoonacular.com/recipes/tofu-scramble-protein-packed-breakfast-578311">Tofu Scramble: Protein Packed Breakfast</a>, and <a href="https://spoonacular.com/recipes/spicy-breakfast-home-fries-146931">Spicy Breakfast Home Fries</a>.',
#    'cuisines': ['American'],
#    'dishTypes': ['morning meal', 'brunch', 'breakfast'],
#    'diets': ['gluten free', 'dairy free', 'lacto ovo vegetarian', 'vegan'],
#    'occasions': [],
#    'analyzedInstructions': [{'name': '',
#      'steps': [{'number': 1,
#        'step': 'Tofu and veggie scramble',
#        'ingredients': [{'id': 16213,
#          'name': 'tofu',
#          'localizedName': 'tofu',
#          'image': 'tofu.png'}],
#        'equipment': []},
#       {'number': 2,
#        'step': 'Press the tofu for 30 minutes prior to cooking. Chop all the veggies and leave ready to begin cooking process.',
#        'ingredients': [{'id': 16213,
#          'name': 'tofu',
#          'localizedName': 'tofu',
#          'image': 'tofu.png'}],
#        'equipment': [],
#        'length': {'number': 30, 'unit': 'minutes'}},
#       {'number': 3,
#        'step': 'Using a non-stick skillet, heat olive oil on medium heat.',
#        'ingredients': [{'id': 4053,
#          'name': 'olive oil',
#          'localizedName': 'olive oil',
#          'image': 'olive-oil.jpg'}],
#        'equipment': [{'id': 404645,
#          'name': 'frying pan',
#          'localizedName': 'frying pan',
#          'image': 'pan.png'}]},
#       {'number': 4,
#        'step': 'Add pressed tofu and crumble in large pieces. The tofu will need to cook and dry out a little for 10 to 15 minutes, so meanwhile, add onions and garlic to tofu.',
#        'ingredients': [{'id': 11215,
#          'name': 'garlic',
#          'localizedName': 'garlic',
#          'image': 'garlic.png'},
#         {'id': 11282,
#          'name': 'onion',
#          'localizedName': 'onion',
#          'image': 'brown-onion.png'},
#         {'id': 16213,
#          'name': 'tofu',
#          'localizedName': 'tofu',
#          'image': 'tofu.png'}],
#        'equipment': [],
#        'length': {'number': 10, 'unit': 'minutes'}},
#       {'number': 5,
#        'step': 'After those 15 minutes, add asparagus and mushroom and all the rest of the spices plus the water. Cook for 5 minutes and serve hot!',
#        'ingredients': [{'id': 11011,
#          'name': 'asparagus',
#          'localizedName': 'asparagus',
#          'image': 'asparagus.png'},
#         {'id': 11260,
#          'name': 'mushrooms',
#          'localizedName': 'mushrooms',
#          'image': 'mushrooms.png'},
#         {'id': 2035,
#          'name': 'spices',
#          'localizedName': 'spices',
#          'image': 'spices.png'},
#         {'id': 14412,
#          'name': 'water',
#          'localizedName': 'water',
#          'image': 'water.png'}],
#        'equipment': [],
#        'length': {'number': 20, 'unit': 'minutes'}},
#       {'number': 6,
#        'step': 'Home Fries',
#        'ingredients': [{'id': 11408,
#          'name': 'french fries',
#          'localizedName': 'french fries',
#          'image': 'french-fries-isolated.jpg'}],
#        'equipment': []},
#       {'number': 7,
#        'step': 'Prepare potatoes before starting on tofu scramble.',
#        'ingredients': [{'id': 11352,
#          'name': 'potato',
#          'localizedName': 'potato',
#          'image': 'potatoes-yukon-gold.png'},
#         {'id': 16213,
#          'name': 'tofu',
#          'localizedName': 'tofu',
#          'image': 'tofu.png'}],
#        'equipment': []},
#       {'number': 8,
#        'step': 'Preheat oven to 450F and move oven rack to the next to last highest row. Line a small cookie sheet with parchment paper.',
#        'ingredients': [{'id': 10118192,
#          'name': 'cookies',
#          'localizedName': 'cookies',
#          'image': 'shortbread-cookies.jpg'}],
#        'equipment': [{'id': 404770,
#          'name': 'baking paper',
#          'localizedName': 'baking paper',
#          'image': 'baking-paper.jpg'},
#         {'id': 404727,
#          'name': 'baking sheet',
#          'localizedName': 'baking sheet',
#          'image': 'baking-sheet.jpg'},
#         {'id': 404784,
#          'name': 'oven',
#          'localizedName': 'oven',
#          'image': 'oven.jpg',
#          'temperature': {'number': 450.0, 'unit': 'Fahrenheit'}}]},
#       {'number': 9,
#        'step': 'Wash and scrub potatoes. Dice them and add to a medium bowl.',
#        'ingredients': [{'id': 11352,
#          'name': 'potato',
#          'localizedName': 'potato',
#          'image': 'potatoes-yukon-gold.png'}],
#        'equipment': [{'id': 404783,
#          'name': 'bowl',
#          'localizedName': 'bowl',
#          'image': 'bowl.jpg'}]},
#       {'number': 10,
#        'step': 'Add olive oil, salt and pepper and mix well.',
#        'ingredients': [{'id': 1102047,
#          'name': 'salt and pepper',
#          'localizedName': 'salt and pepper',
#          'image': 'salt-and-pepper.jpg'},
#         {'id': 4053,
#          'name': 'olive oil',
#          'localizedName': 'olive oil',
#          'image': 'olive-oil.jpg'}],
#        'equipment': []},
#       {'number': 11,
#        'step': 'Pour potatoes on cookie sheet and spread evenly.',
#        'ingredients': [{'id': 11352,
#          'name': 'potato',
#          'localizedName': 'potato',
#          'image': 'potatoes-yukon-gold.png'},
#         {'id': 10118192,
#          'name': 'cookies',
#          'localizedName': 'cookies',
#          'image': 'shortbread-cookies.jpg'},
#         {'id': 0, 'name': 'spread', 'localizedName': 'spread', 'image': ''}],
#        'equipment': [{'id': 404727,
#          'name': 'baking sheet',
#          'localizedName': 'baking sheet',
#          'image': 'baking-sheet.jpg'}]},
#       {'number': 12,
#        'step': 'Bake for 20 minutes and serve while hot.',
#        'ingredients': [],
#        'equipment': [{'id': 404784,
#          'name': 'oven',
#          'localizedName': 'oven',
#          'image': 'oven.jpg'}],
#        'length': {'number': 20, 'unit': 'minutes'}}]}],
#    'spoonacularSourceUrl': 'https://spoonacular.com/country-breakfast-tofu-and-veggie-scramble-with-home-fries-640194'}],
#  'offset': 0,
#  'number': 100,
#  'totalResults': 12}

# %%
recipe8_df=pd.json_normalize(new_res4,record_path=['results'])
recipe8_df
# Out:
#     vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0        False  False        True      False        False  False        False
# 1         True  False        True       True        False  False        False
# 2         True  False       False      False        False  False        False
# 3        False  False       False       True        False  False        False
# 4        False  False       False       True        False  False        False
# 5         True  False       False      False        False  False        False
# 6         True  False       False      False        False  False        False
# 7         True  False       False      False        False  False        False
# 8         True  False       False      False        False  False        False
# 9         True  False       False       True        False  False        False
# 10       False  False       False      False        False  False        False
# 11        True   True        True       True        False  False        False
#
#     sustainable  weightWatcherSmartPoints gaps  ...  \
# 0         False                        32   no  ...
# 1         False                         7   no  ...
# 2         False                        10   no  ...
# 3         False                        23   no  ...
# 4         False                         5   no  ...
# 5         False                        20   no  ...
# 6         False                        17   no  ...
# 7         False                        12   no  ...
# 8         False                        13   no  ...
# 9         False                        13   no  ...
# 10        False                         6   no  ...
# 11        False                        12   no  ...
#
#                                  nutrition.flavonoids  \
# 0   [{'name': 'Cyanidin', 'amount': 0.33, 'unit': ...
# 1   [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 2   [{'name': 'Cyanidin', 'amount': 6.67, 'unit': ...
# 3   [{'name': 'Cyanidin', 'amount': 3.82, 'unit': ...
# 4   [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 5   [{'name': 'Cyanidin', 'amount': 3.38, 'unit': ...
# 6   [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 7   [{'name': 'Cyanidin', 'amount': 0.37, 'unit': ...
# 8   [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 9   [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 10  [{'name': 'Cyanidin', 'amount': 1.97, 'unit': ...
# 11  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
#
#                                 nutrition.ingredients  \
# 0   [{'id': 9037, 'name': 'avocado', 'amount': 0.5...
# 1   [{'id': 4047, 'name': 'coconut oil', 'amount':...
# 2   [{'id': 18371, 'name': 'baking powder', 'amoun...
# 3   [{'id': 93607, 'name': 'almond milk', 'amount'...
# 4   [{'id': 93801, 'name': 'hollandaise sauce', 'a...
# 5   [{'id': 1123, 'name': 'eggs', 'amount': 1.5, '...
# 6   [{'id': 1123, 'name': 'eggs', 'amount': 1.0, '...
# 7   [{'id': 20080, 'name': 'whole wheat flour', 'a...
# 8   [{'id': 18027, 'name': 'challah', 'amount': 0....
# 9   [{'id': 18064, 'name': 'bread', 'amount': 2.0,...
# 10  [{'id': 98915, 'name': 'bread', 'amount': 1.0,...
# 11  [{'id': 16213, 'name': 'tofu', 'amount': 0.5, ...
#
#     nutrition.caloricBreakdown.percentProtein  \
# 0                                       20.92
# 1                                        6.76
# 2                                        5.87
# 3                                        7.94
# 4                                       28.49
# 5                                       13.86
# 6                                       10.15
# 7                                        6.28
# 8                                       14.66
# 9                                       15.02
# 10                                      10.01
# 11                                      21.38
#
#     nutrition.caloricBreakdown.percentFat  \
# 0                                   72.24
# 1                                   30.65
# 2                                   30.45
# 3                                   37.70
# 4                                   41.68
# 5                                   38.23
# 6                                   47.74
# 7                                   43.40
# 8                                   24.14
# 9                                   37.12
# 10                                  71.25
# 11                                  62.23
#
#    nutrition.caloricBreakdown.percentCarbs nutrition.weightPerServing.amount  \
# 0                                     6.84                               497
# 1                                    62.59                               240
# 2                                    63.68                               149
# 3                                    54.36                               408
# 4                                    29.83                               110
# 5                                    47.91                               346
# 6                                    42.11                               127
# 7                                    50.32                               105
# 8                                    61.20                               201
# 9                                    47.86                               290
# 10                                   18.74                               199
# 11                                   16.39                               436
#
#    nutrition.weightPerServing.unit  preparationMinutes  cookingMinutes  \
# 0                                g                 NaN             NaN
# 1                                g                 NaN             NaN
# 2                                g                20.0            30.0
# 3                                g                 NaN             NaN
# 4                                g                 NaN             NaN
# 5                                g                 NaN             NaN
# 6                                g                 NaN             NaN
# 7                                g                 NaN             NaN
# 8                                g                 NaN             NaN
# 9                                g                 NaN             NaN
# 10                               g                 5.0            25.0
# 11                               g                 NaN             NaN
#
#            author
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5      coffeebean
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10  maplewoodroad
# 11            NaN
#
# [12 rows x 44 columns]

# %%
recipe8_df.drop(columns=['vegetarian', 'vegan', 'glutenFree', 'dairyFree', 'veryHealthy', 'cheap', 'veryPopular', 'sustainable', 'weightWatcherSmartPoints', 'gaps', 'lowFodmap', 'aggregateLikes', 'spoonacularScore',
                      'healthScore', 'creditsText', 'license', 'sourceName', 'pricePerServing','sourceUrl','imageType','summary','diets', 'occasions','spoonacularSourceUrl','nutrition.properties','nutrition.flavonoids','nutrition.caloricBreakdown.percentProtein','nutrition.caloricBreakdown.percentFat','nutrition.caloricBreakdown.percentCarbs','nutrition.weightPerServing.amount',
                      'nutrition.weightPerServing.unit','preparationMinutes','cookingMinutes','author','nutrition.nutrients','nutrition.ingredients'],inplace=True)
recipe8_df
# Out:
#          id                                              title  \
# 0    650377                             Low Carb Brunch Burger
# 1    662584  Sweet Potato Kimchi Hash Brunch - gluten free,...
# 2    729530                 Upside-Down Blueberry Puffs Brunch
# 3   1095748                                 Vegan French Toast
# 4    639594                              Classic Eggs Benedict
# 5   1444543                            Easy Berry French Toast
# 6    653371                       Nutella Stuffed French Toast
# 7    632570                       Apple Pie Honey Wheat Scones
# 8    636588                      Butternut Squash French Toast
# 9    655239                  Peanut Butter Banana French Toast
# 10  1697823             Bacon-Apple-Pecan Stuffed French Toast
# 11   640194  Country Breakfast: Tofu and Veggie Scramble Wi...
#
#     readyInMinutes  servings  \
# 0               30         2
# 1               45         6
# 2               50         6
# 3               45         2
# 4               45         4
# 5               45         4
# 6               45         2
# 7               45         8
# 8               45         4
# 9               45         1
# 10              30         2
# 11              45         2
#
#                                                 image         cuisines  \
# 0   https://spoonacular.com/recipeImages/650377-31...       [American]
# 1   https://spoonacular.com/recipeImages/662584-31...  [Korean, Asian]
# 2   https://spoonacular.com/recipeImages/729530-31...               []
# 3   https://spoonacular.com/recipeImages/1095748-3...       [American]
# 4   https://spoonacular.com/recipeImages/639594-31...       [American]
# 5   https://spoonacular.com/recipeImages/1444543-3...       [American]
# 6   https://spoonacular.com/recipeImages/653371-31...       [American]
# 7   https://spoonacular.com/recipeImages/632570-31...       [American]
# 8   https://spoonacular.com/recipeImages/636588-31...       [American]
# 9   https://spoonacular.com/recipeImages/655239-31...       [American]
# 10  https://spoonacular.com/recipeImages/1697823-3...       [American]
# 11  https://spoonacular.com/recipeImages/640194-31...       [American]
#
#                                      dishTypes  \
# 0            [morning meal, brunch, breakfast]
# 1                                           []
# 2            [morning meal, brunch, breakfast]
# 3            [morning meal, brunch, breakfast]
# 4            [morning meal, brunch, breakfast]
# 5            [morning meal, brunch, breakfast]
# 6            [morning meal, brunch, breakfast]
# 7   [morning meal, dessert, brunch, breakfast]
# 8            [morning meal, brunch, breakfast]
# 9            [morning meal, brunch, breakfast]
# 10           [morning meal, brunch, breakfast]
# 11           [morning meal, brunch, breakfast]
#
#                                  analyzedInstructions
# 0   [{'name': '', 'steps': [{'number': 1, 'step': ...
# 1   [{'name': '', 'steps': [{'number': 1, 'step': ...
# 2   [{'name': '', 'steps': [{'number': 1, 'step': ...
# 3   [{'name': '', 'steps': [{'number': 1, 'step': ...
# 4   [{'name': '', 'steps': [{'number': 1, 'step': ...
# 5   [{'name': '', 'steps': [{'number': 1, 'step': ...
# 6   [{'name': '', 'steps': [{'number': 1, 'step': ...
# 7   [{'name': '', 'steps': [{'number': 1, 'step': ...
# 8   [{'name': '', 'steps': [{'number': 1, 'step': ...
# 9   [{'name': '', 'steps': [{'number': 1, 'step': ...
# 10  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 11  [{'name': '', 'steps': [{'number': 1, 'step': ...

# %% [markdown]
# # One hot encoding dishType column

# %%
#recipe6_df['main dish']=0
recipe8_df['dish']=0
#recipes['empty']=0
recipe8_df.columns
# Out:
# Index(['id', 'title', 'readyInMinutes', 'servings', 'image', 'cuisines',
#        'dishTypes', 'analyzedInstructions', 'dish'],
#       dtype='object')

# %%
for i in range(0,12):
    item =recipe8_df['dishTypes'][i]
    if len(item)==0:
        recipe8_df.iloc[i,8]=0
        
    else:
        #print(item[0])
        
        #if any(x in ['lunch', 'dinner', 'antipasti','side dish','salad'] for x in item):
            #print(f"{i}:lunch")
            #recipe5_df.iloc[i,7]=1
        if any(x in ['breakfast', 'bread'] for x in item):
            recipe8_df.iloc[i,8]=0
recipe8_df
# Out:
#          id                                              title  \
# 0    650377                             Low Carb Brunch Burger
# 1    662584  Sweet Potato Kimchi Hash Brunch - gluten free,...
# 2    729530                 Upside-Down Blueberry Puffs Brunch
# 3   1095748                                 Vegan French Toast
# 4    639594                              Classic Eggs Benedict
# 5   1444543                            Easy Berry French Toast
# 6    653371                       Nutella Stuffed French Toast
# 7    632570                       Apple Pie Honey Wheat Scones
# 8    636588                      Butternut Squash French Toast
# 9    655239                  Peanut Butter Banana French Toast
# 10  1697823             Bacon-Apple-Pecan Stuffed French Toast
# 11   640194  Country Breakfast: Tofu and Veggie Scramble Wi...
#
#     readyInMinutes  servings  \
# 0               30         2
# 1               45         6
# 2               50         6
# 3               45         2
# 4               45         4
# 5               45         4
# 6               45         2
# 7               45         8
# 8               45         4
# 9               45         1
# 10              30         2
# 11              45         2
#
#                                                 image         cuisines  \
# 0   https://spoonacular.com/recipeImages/650377-31...       [American]
# 1   https://spoonacular.com/recipeImages/662584-31...  [Korean, Asian]
# 2   https://spoonacular.com/recipeImages/729530-31...               []
# 3   https://spoonacular.com/recipeImages/1095748-3...       [American]
# 4   https://spoonacular.com/recipeImages/639594-31...       [American]
# 5   https://spoonacular.com/recipeImages/1444543-3...       [American]
# 6   https://spoonacular.com/recipeImages/653371-31...       [American]
# 7   https://spoonacular.com/recipeImages/632570-31...       [American]
# 8   https://spoonacular.com/recipeImages/636588-31...       [American]
# 9   https://spoonacular.com/recipeImages/655239-31...       [American]
# 10  https://spoonacular.com/recipeImages/1697823-3...       [American]
# 11  https://spoonacular.com/recipeImages/640194-31...       [American]
#
#                                      dishTypes  \
# 0            [morning meal, brunch, breakfast]
# 1                                           []
# 2            [morning meal, brunch, breakfast]
# 3            [morning meal, brunch, breakfast]
# 4            [morning meal, brunch, breakfast]
# 5            [morning meal, brunch, breakfast]
# 6            [morning meal, brunch, breakfast]
# 7   [morning meal, dessert, brunch, breakfast]
# 8            [morning meal, brunch, breakfast]
# 9            [morning meal, brunch, breakfast]
# 10           [morning meal, brunch, breakfast]
# 11           [morning meal, brunch, breakfast]
#
#                                  analyzedInstructions  dish
# 0   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 1   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 2   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 3   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 4   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 5   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 6   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 7   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 8   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 9   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 10  [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 11  [{'name': '', 'steps': [{'number': 1, 'step': ...     0

# %%
recipe8_df.drop(columns=['dishTypes'],inplace=True)
recipe8_df
# Out:
#          id                                              title  \
# 0    650377                             Low Carb Brunch Burger
# 1    662584  Sweet Potato Kimchi Hash Brunch - gluten free,...
# 2    729530                 Upside-Down Blueberry Puffs Brunch
# 3   1095748                                 Vegan French Toast
# 4    639594                              Classic Eggs Benedict
# 5   1444543                            Easy Berry French Toast
# 6    653371                       Nutella Stuffed French Toast
# 7    632570                       Apple Pie Honey Wheat Scones
# 8    636588                      Butternut Squash French Toast
# 9    655239                  Peanut Butter Banana French Toast
# 10  1697823             Bacon-Apple-Pecan Stuffed French Toast
# 11   640194  Country Breakfast: Tofu and Veggie Scramble Wi...
#
#     readyInMinutes  servings  \
# 0               30         2
# 1               45         6
# 2               50         6
# 3               45         2
# 4               45         4
# 5               45         4
# 6               45         2
# 7               45         8
# 8               45         4
# 9               45         1
# 10              30         2
# 11              45         2
#
#                                                 image         cuisines  \
# 0   https://spoonacular.com/recipeImages/650377-31...       [American]
# 1   https://spoonacular.com/recipeImages/662584-31...  [Korean, Asian]
# 2   https://spoonacular.com/recipeImages/729530-31...               []
# 3   https://spoonacular.com/recipeImages/1095748-3...       [American]
# 4   https://spoonacular.com/recipeImages/639594-31...       [American]
# 5   https://spoonacular.com/recipeImages/1444543-3...       [American]
# 6   https://spoonacular.com/recipeImages/653371-31...       [American]
# 7   https://spoonacular.com/recipeImages/632570-31...       [American]
# 8   https://spoonacular.com/recipeImages/636588-31...       [American]
# 9   https://spoonacular.com/recipeImages/655239-31...       [American]
# 10  https://spoonacular.com/recipeImages/1697823-3...       [American]
# 11  https://spoonacular.com/recipeImages/640194-31...       [American]
#
#                                  analyzedInstructions  dish
# 0   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 1   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 2   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 3   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 4   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 5   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 6   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 7   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 8   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 9   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 10  [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 11  [{'name': '', 'steps': [{'number': 1, 'step': ...     0

# %%
#Getting ingredients for each recipe
#Ingredients is a list of dictionaries in nutrition key
ingredients_list=[]
recipe_idlist=[]

for recipe in new_res4['results']:
    recipe_id =recipe['id']
    ingres=recipe['nutrition']['ingredients']
    ingri_dict={}
    for ingredient_dict in ingres:
        name=ingredient_dict['name']
        amount=ingredient_dict['amount']
        unit=ingredient_dict['unit']
        value=str(round(amount,2))+' '+unit 
        ingri_dict[name]=value
    ingredients_list.append(ingri_dict)
    recipe_idlist.append(recipe_id)

# %%
ingredient_names=[]
for i in range(0,12):
    ingredients=list(ingredients_list[i])
    ingredient_names.append(ingredients)
len(ingredient_names)
# Out:
# 12

# %%
recipe8_df['ingredients']=ingredients_list

# %%
recipe8_df['grocery']=ingredient_names
recipe8_df
# Out:
#          id                                              title  \
# 0    650377                             Low Carb Brunch Burger
# 1    662584  Sweet Potato Kimchi Hash Brunch - gluten free,...
# 2    729530                 Upside-Down Blueberry Puffs Brunch
# 3   1095748                                 Vegan French Toast
# 4    639594                              Classic Eggs Benedict
# 5   1444543                            Easy Berry French Toast
# 6    653371                       Nutella Stuffed French Toast
# 7    632570                       Apple Pie Honey Wheat Scones
# 8    636588                      Butternut Squash French Toast
# 9    655239                  Peanut Butter Banana French Toast
# 10  1697823             Bacon-Apple-Pecan Stuffed French Toast
# 11   640194  Country Breakfast: Tofu and Veggie Scramble Wi...
#
#     readyInMinutes  servings  \
# 0               30         2
# 1               45         6
# 2               50         6
# 3               45         2
# 4               45         4
# 5               45         4
# 6               45         2
# 7               45         8
# 8               45         4
# 9               45         1
# 10              30         2
# 11              45         2
#
#                                                 image         cuisines  \
# 0   https://spoonacular.com/recipeImages/650377-31...       [American]
# 1   https://spoonacular.com/recipeImages/662584-31...  [Korean, Asian]
# 2   https://spoonacular.com/recipeImages/729530-31...               []
# 3   https://spoonacular.com/recipeImages/1095748-3...       [American]
# 4   https://spoonacular.com/recipeImages/639594-31...       [American]
# 5   https://spoonacular.com/recipeImages/1444543-3...       [American]
# 6   https://spoonacular.com/recipeImages/653371-31...       [American]
# 7   https://spoonacular.com/recipeImages/632570-31...       [American]
# 8   https://spoonacular.com/recipeImages/636588-31...       [American]
# 9   https://spoonacular.com/recipeImages/655239-31...       [American]
# 10  https://spoonacular.com/recipeImages/1697823-3...       [American]
# 11  https://spoonacular.com/recipeImages/640194-31...       [American]
#
#                                  analyzedInstructions  dish  \
# 0   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 1   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 2   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 3   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 4   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 5   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 6   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 7   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 8   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 9   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 10  [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 11  [{'name': '', 'steps': [{'number': 1, 'step': ...     0
#
#                                           ingredients  \
# 0   {'avocado': '0.5 ', 'bacon': '2.0 strips', 'cu...
# 1   {'coconut oil': '0.5 tablespoons', 'onions': '...
# 2   {'baking powder': '0.25 teaspoons', 'blueberri...
# 3   {'almond milk': '0.5 cup', 'vanilla extract': ...
# 4   {'hollandaise sauce': '0.25 package', 'canadia...
# 5   {'eggs': '1.5 ', 'milk': '0.38 cups', 'vanilla...
# 6   {'eggs': '1.0 ', 'milk': '0.13 cup', 'sugar': ...
# 7   {'whole wheat flour': '0.13 cup', 'all purpose...
# 8   {'challah': '0.25 pound', 'butternut squash': ...
# 9   {'bread': '2.0 slices', 'peanut butter': '2.0 ...
# 10  {'bread': '1.0 slices', 'an apple': '0.13 ', '...
# 11  {'tofu': '6.0 ounces', 'olive oil': '1.0 table...
#
#                                               grocery
# 0   [avocado, bacon, cumin, eggs, garlic powder, g...
# 1   [coconut oil, onions, garlic, sweet potatoes, ...
# 2   [baking powder, blueberries, butter, cream of ...
# 3   [almond milk, vanilla extract, ground cinnamon...
# 4   [hollandaise sauce, canadian bacon, english mu...
# 5   [eggs, milk, vanilla sugar, bread, butter, ber...
# 6   [eggs, milk, sugar, cinnamon powder, bread, nu...
# 7   [whole wheat flour, all purpose flour, dark br...
# 8   [challah, butternut squash, milk, eggs, vanill...
# 9   [bread, peanut butter, banana, whole egg, oran...
# 10  [bread, an apple, bacon, brown sugar, pecans, ...
# 11  [tofu, olive oil, mushrooms, asparagus, onions...

# %% [markdown]
# # EXtracting Instructions

# %%
recipe_instructions=recipe8_df[['analyzedInstructions','id']]
#recipe_instructions.head

# %%
recipe_inst=[]
for instructions,ids in zip(list(recipe_instructions['analyzedInstructions'].values),list(recipe_instructions['id'].values)):
    #print(instructions,ids)
    #print(instructions[0]['steps'])
    instruct={}
    recipe_step=''
    try:
    #break   
        for no_steps in range(len(instructions[0]['steps'])):
            #print(no_steps)
            recipe_step+=instructions[0]['steps'][no_steps]['step']    
            #break
            #print(recipe_step)
        instruct[ids]=recipe_step
        #print(instruct)
        recipe_inst.append(instruct)
    except:
        pass

# %%
instruction_final=pd.DataFrame()
for dict_recipe in recipe_inst:
    df=pd.DataFrame(dict_recipe,index=dict_recipe.keys())
    df.columns=['instructions']
    #print(df)
    #break
    instruction_final=pd.concat([instruction_final,df],ignore_index=False,axis=0)

# %%
instruction_final.index.names = ['id']
#instruction_final

# %%
recipe8_df=recipe8_df.merge(instruction_final,on='id')
recipe8_df.drop(columns=['analyzedInstructions'],inplace=True)

# %%
recipe8_df
# Out:
#          id                                              title  \
# 0    650377                             Low Carb Brunch Burger
# 1    662584  Sweet Potato Kimchi Hash Brunch - gluten free,...
# 2    729530                 Upside-Down Blueberry Puffs Brunch
# 3   1095748                                 Vegan French Toast
# 4    639594                              Classic Eggs Benedict
# 5   1444543                            Easy Berry French Toast
# 6    653371                       Nutella Stuffed French Toast
# 7    632570                       Apple Pie Honey Wheat Scones
# 8    636588                      Butternut Squash French Toast
# 9    655239                  Peanut Butter Banana French Toast
# 10  1697823             Bacon-Apple-Pecan Stuffed French Toast
# 11   640194  Country Breakfast: Tofu and Veggie Scramble Wi...
#
#     readyInMinutes  servings  \
# 0               30         2
# 1               45         6
# 2               50         6
# 3               45         2
# 4               45         4
# 5               45         4
# 6               45         2
# 7               45         8
# 8               45         4
# 9               45         1
# 10              30         2
# 11              45         2
#
#                                                 image         cuisines  dish  \
# 0   https://spoonacular.com/recipeImages/650377-31...       [American]     0
# 1   https://spoonacular.com/recipeImages/662584-31...  [Korean, Asian]     0
# 2   https://spoonacular.com/recipeImages/729530-31...               []     0
# 3   https://spoonacular.com/recipeImages/1095748-3...       [American]     0
# 4   https://spoonacular.com/recipeImages/639594-31...       [American]     0
# 5   https://spoonacular.com/recipeImages/1444543-3...       [American]     0
# 6   https://spoonacular.com/recipeImages/653371-31...       [American]     0
# 7   https://spoonacular.com/recipeImages/632570-31...       [American]     0
# 8   https://spoonacular.com/recipeImages/636588-31...       [American]     0
# 9   https://spoonacular.com/recipeImages/655239-31...       [American]     0
# 10  https://spoonacular.com/recipeImages/1697823-3...       [American]     0
# 11  https://spoonacular.com/recipeImages/640194-31...       [American]     0
#
#                                           ingredients  \
# 0   {'avocado': '0.5 ', 'bacon': '2.0 strips', 'cu...
# 1   {'coconut oil': '0.5 tablespoons', 'onions': '...
# 2   {'baking powder': '0.25 teaspoons', 'blueberri...
# 3   {'almond milk': '0.5 cup', 'vanilla extract': ...
# 4   {'hollandaise sauce': '0.25 package', 'canadia...
# 5   {'eggs': '1.5 ', 'milk': '0.38 cups', 'vanilla...
# 6   {'eggs': '1.0 ', 'milk': '0.13 cup', 'sugar': ...
# 7   {'whole wheat flour': '0.13 cup', 'all purpose...
# 8   {'challah': '0.25 pound', 'butternut squash': ...
# 9   {'bread': '2.0 slices', 'peanut butter': '2.0 ...
# 10  {'bread': '1.0 slices', 'an apple': '0.13 ', '...
# 11  {'tofu': '6.0 ounces', 'olive oil': '1.0 table...
#
#                                               grocery  \
# 0   [avocado, bacon, cumin, eggs, garlic powder, g...
# 1   [coconut oil, onions, garlic, sweet potatoes, ...
# 2   [baking powder, blueberries, butter, cream of ...
# 3   [almond milk, vanilla extract, ground cinnamon...
# 4   [hollandaise sauce, canadian bacon, english mu...
# 5   [eggs, milk, vanilla sugar, bread, butter, ber...
# 6   [eggs, milk, sugar, cinnamon powder, bread, nu...
# 7   [whole wheat flour, all purpose flour, dark br...
# 8   [challah, butternut squash, milk, eggs, vanill...
# 9   [bread, peanut butter, banana, whole egg, oran...
# 10  [bread, an apple, bacon, brown sugar, pecans, ...
# 11  [tofu, olive oil, mushrooms, asparagus, onions...
#
#                                          instructions
# 0   Fry up 4 strips of bacon and set aside.Leave s...
# 1   Set a large skillet over medium high heat.When...
# 2   Preheat oven to 375 degrees.Wash blueberries a...
# 3   Grind up the chia seeds into a powder, I used ...
# 4   Prepare Knorr Hollandaise Sauce according to p...
# 5   Beat eggs.Add milk and vanilla sugar.Dip the b...
# 6   n a deep large bowl, mix eggs, milk, sugar and...
# 7   Preheat oven to 400 degrees.Line a baking shee...
# 8   Slice the loaf of bread into 8-10 slices (depe...
# 9   Prepare a Peanut Butter and Banana SandwichMix...
# 10  Preheat toaster oven to 400°F. Place bacon and...
# 11  Tofu and veggie scramblePress the tofu for 30 ...

# %%
#Saving 100 recipes dataframe to a csv
recipe8_df.to_csv('./recipe8.csv',index=False)

# %% [markdown]
# #scraping nutrition data

# %%
nutri_list =[]
id_list=[]
for recipe in new_res4['results']:
    recipe_id =recipe['id']
    nutrients =recipe['nutrition']['nutrients']
    nutri_dict={}
    for nutrient_dict in nutrients:
        name = nutrient_dict['name']
        amount = nutrient_dict['amount']
        unit = nutrient_dict['unit']
        #value = str(round(amount,2))+' '+unit
        key=name+' '+unit
        #print(name)
        nutri_dict[key]=amount
    nutri_list.append(nutri_dict)
    id_list.append(recipe_id)

# %%
#nutri_list

# %%
nutrition6_df= pd.DataFrame(nutri_list,index=id_list)
nutrition6_df.index.name='recipe_id'
nutrition6_df.head()
# Out:
#            Calories kcal  Fat g  Saturated Fat g  Carbohydrates g  \
# recipe_id
# 650377           1028.27  82.55            27.02            17.57
# 662584            225.13   7.85             6.33            36.06
# 729530            276.14   9.62             5.61            45.24
# 1095748           665.44  28.89            13.30            93.70
# 639594            197.50   8.96             2.61            14.43
#
#            Net Carbohydrates g  Sugar g  Cholesterol mg  Sodium mg  Protein g  \
# recipe_id
# 650377                    8.74     4.22          354.80     732.38      53.80
# 662584                   30.76     9.11           27.28     870.66       3.89
# 729530                   42.77    25.26           49.87     185.98       4.17
# 1095748                  82.17    45.61            0.00     534.07      13.68
# 639594                   13.66     0.16          178.81     497.87      13.78
#
#            Vitamin C mg  ...  Fiber g  Vitamin E mg  Vitamin K µg  \
# recipe_id                ...
# 650377           105.74  ...     8.83          4.90         29.12
# 662584             7.57  ...     5.30          0.49          5.80
# 729530             7.65  ...     2.48          0.78         16.04
# 1095748            7.33  ...    11.53          5.31         16.71
# 639594              NaN  ...     0.77          0.52           NaN
#
#            Vitamin B1 mg  Magnesium mg  Copper mg  Manganese mg  Calcium mg  \
# recipe_id
# 650377              0.37         94.72       0.43          0.34      108.87
# 662584              0.14         43.92       0.26          0.52       64.67
# 729530              0.20         12.04       0.09          0.42       73.21
# 1095748             0.46        126.86       0.43          2.38      384.64
# 639594              0.28         16.12       0.08          0.12       41.78
#
#            Vitamin D µg  Alcohol g
# recipe_id
# 650377             1.29        NaN
# 662584              NaN        NaN
# 729530             0.47        NaN
# 1095748             NaN       0.36
# 639594             1.68        NaN
#
# [5 rows x 32 columns]

# %%
#saving the nutrition details of 100 recipes dataframe to csv
nutrition6_df.to_csv('./nutrition8.csv',index=True)

# %%
#Defining dataframe for ingredients
ingres6_df=pd.DataFrame(ingredients_list,index= recipe_idlist)
ingres6_df.fillna(value=0,inplace=True)
ingres6_df.index.name='recipe_id'
ingres6_df.head()
# Out:
#           avocado       bacon         cumin  eggs garlic powder ground beef  \
# recipe_id
# 650377       0.5   2.0 strips  1.0 servings  1.0   1.0 servings      0.5 lb
# 662584          0           0             0     0             0           0
# 729530          0           0             0     0             0           0
# 1095748         0           0             0     0             0           0
# 639594          0           0             0  1.0              0           0
#
#            onion powder   bell pepper           salt     sharp cheddar  ...  \
# recipe_id                                                               ...
# 650377     1.0 servings  1.0 servings   1.0 servings  1.0 large slices  ...
# 662584                0             0              0                 0  ...
# 729530                0             0  0.04 teaspoon                 0  ...
# 1095748               0             0              0                 0  ...
# 639594                0             0              0                 0  ...
#
#           olive oil mushrooms asparagus garlic clove italian seasonings  \
# recipe_id
# 650377            0         0         0            0                  0
# 662584            0         0         0            0                  0
# 729530            0         0         0            0                  0
# 1095748           0         0         0            0                  0
# 639594            0         0         0            0                  0
#
#           tumeric cayenne pepper water fries red potatoes
# recipe_id
# 650377          0              0     0     0            0
# 662584          0              0     0     0            0
# 729530          0              0     0     0            0
# 1095748         0              0     0     0            0
# 639594          0              0     0     0            0
#
# [5 rows x 81 columns]

# %%
#saving the ingredients of 100 recipes dataframe to csv
ingres6_df.to_csv('./ingredients8.csv',index=True)

# %%
#recipe_instructions=pd.DataFrame(columns=['recipe_id','number','step','ingredients','equipment','length.number','length.unit'])
#recipe_instructions

for recipe in new_res4['results']:
    current_index=new_res4['results'].index(recipe)
    instructions= recipe['analyzedInstructions']
    if current_index==0:
        full6_df=pd.json_normalize(instructions,record_path=['steps'])
        full6_df['recipe_id']=current_index
        #print(current_index)
    else:
        #print(current_index)
        df=pd.json_normalize(instructions,record_path=['steps'])
        df['recipe_id']=current_index
        #print(df)
        full6_df=full6_df.append(df,ignore_index=True)

# %%
full6_df.drop(columns=['ingredients','equipment','length.number','length.unit'])
# Out:
#      number                                               step  recipe_id
# 0         1  Fry up 4 strips of bacon and set aside.Leave s...          0
# 1         2  Heat a large non-stick skillet until the pan (...          0
# 2         3  Place patties in hot pan and sear for 1 minute...          0
# 3         4  Add the cheese on the burgers when the burgers...          0
# 4         1         Set a large skillet over medium high heat.          1
# ..      ...                                                ...        ...
# 101       8  Preheat oven to 450F and move oven rack to the...         11
# 102       9  Wash and scrub potatoes. Dice them and add to ...         11
# 103      10       Add olive oil, salt and pepper and mix well.         11
# 104      11   Pour potatoes on cookie sheet and spread evenly.         11
# 105      12           Bake for 20 minutes and serve while hot.         11
#
# [106 rows x 3 columns]

# %%
#saving instructions of 100 recipes dataframe to a csv
full6_df.to_csv('./instructions8.csv',index=True)
