# %%
#import libraries
import pandas as pd
import json
import re
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import requests
import warnings
import pprint
warnings.simplefilter('ignore')

# %%
url ='https://api.spoonacular.com/recipes/complexSearch?apiKey&cuisine=Indian&addRecipeInformation=True&addRecipeNutrition=True&number=100'
new_res5= requests.get(url).json()
#new_res5

# %%
recipe9_df=pd.json_normalize(new_res5,record_path=['results'])
recipe9_df.head(3)
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0        True   True        True       True         True  False        False
# 1        True   True        True       True         True  False        False
# 2       False  False        True       True        False  False        False
#
#    sustainable  weightWatcherSmartPoints gaps  ...  \
# 0        False                         2   no  ...
# 1        False                        12   no  ...
# 2        False                        22   no  ...
#
#                                 nutrition.flavonoids  \
# 0  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 1  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 2  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
#
#                                nutrition.ingredients  \
# 0  [{'id': 16063, 'name': 'black eyed peas', 'amo...
# 1  [{'id': 18371, 'name': 'baking powder', 'amoun...
# 2  [{'id': 12118, 'name': 'coconut milk', 'amount...
#
#    nutrition.caloricBreakdown.percentProtein  \
# 0                                      19.69
# 1                                      20.97
# 2                                      19.50
#
#    nutrition.caloricBreakdown.percentFat  \
# 0                                  14.39
# 1                                  11.90
# 2                                  48.24
#
#   nutrition.caloricBreakdown.percentCarbs nutrition.weightPerServing.amount  \
# 0                                   65.92                               259
# 1                                   67.13                               171
# 2                                   32.26                               324
#
#   nutrition.weightPerServing.unit  author  preparationMinutes cookingMinutes
# 0                               g     NaN                 NaN            NaN
# 1                               g     NaN                 NaN            NaN
# 2                               g     NaN                 NaN            NaN
#
# [3 rows x 44 columns]

# %%
recipe9_df.drop(columns=['vegetarian', 'vegan', 'glutenFree', 'dairyFree', 'veryHealthy', 'cheap', 'veryPopular', 'sustainable', 'weightWatcherSmartPoints', 'gaps', 'lowFodmap', 'aggregateLikes', 'spoonacularScore',
                      'healthScore', 'creditsText', 'license', 'sourceName', 'pricePerServing','sourceUrl','imageType','summary','diets', 'occasions','spoonacularSourceUrl','nutrition.properties','nutrition.flavonoids','nutrition.caloricBreakdown.percentProtein','nutrition.caloricBreakdown.percentFat','nutrition.caloricBreakdown.percentCarbs','nutrition.weightPerServing.amount',
                      'nutrition.weightPerServing.unit','preparationMinutes','cookingMinutes','author','nutrition.nutrients','nutrition.ingredients'],inplace=True)
#recipe9_df.head()

# %% [markdown]
# # One hot encoding dishType column

# %%
recipe9_df['dish']=0
recipe9_df.columns
# Out:
# Index(['id', 'title', 'readyInMinutes', 'servings', 'image', 'cuisines',
#        'dishTypes', 'analyzedInstructions', 'dish'],
#       dtype='object')

# %%
for i in range(0,100):
    item =recipe9_df['dishTypes'][i]
    if len(item)==0:
        recipe9_df.iloc[i,8]=0
        
    else:
        #print(item[0])
        
        if any(x in ['lunch', 'dinner', 'antipasti','side dish','salad'] for x in item):
            #print(f"{i}:lunch")
            recipe9_df.iloc[i,8]=1
        if any(x in ['breakfast', 'bread'] for x in item):
            recipe9_df.iloc[i,8]=0
#recipe9_df

# %%
recipe9_df.drop(columns=['dishTypes'],inplace=True)
recipe9_df.head(3)
# Out:
#        id                                              title  readyInMinutes  \
# 0  798400  Spicy Black-Eyed Pea Curry with Swiss Chard an...              45
# 1  646043                       Gujarati Dry Mung Bean Curry              45
# 2  716364          Rice and Peas with Coconut Curry Mackerel              45
#
#    servings                                              image  \
# 0         6  https://spoonacular.com/recipeImages/798400-31...
# 1         4  https://spoonacular.com/recipeImages/646043-31...
# 2         4  https://spoonacular.com/recipeImages/716364-31...
#
#           cuisines                               analyzedInstructions  dish
# 0  [Indian, Asian]  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 1  [Indian, Asian]  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 2  [Indian, Asian]  [{'name': '', 'steps': [{'number': 1, 'step': ...     1

# %%
#Getting ingredients for each recipe
#Ingredients is a list of dictionaries in nutrition key
ingredients_list=[]
recipe_idlist=[]

for recipe in new_res5['results']:
    recipe_id =recipe['id']
    ingres=recipe['nutrition']['ingredients']
    ingri_dict={}
    for ingredient_dict in ingres:
        name=ingredient_dict['name']
        amount=ingredient_dict['amount']
        unit=ingredient_dict['unit']
        value=str(round(amount,2))+' '+unit 
        ingri_dict[name]=value
    ingredients_list.append(ingri_dict)
    recipe_idlist.append(recipe_id)

# %%
ingredient_names=[]
for i in range(0,100):
    ingredients=list(ingredients_list[i])
    ingredient_names.append(ingredients)
len(ingredient_names)
# Out:
# 100

# %%
recipe9_df['ingredients']=ingredients_list

# %%
recipe9_df['grocery']=ingredient_names
recipe9_df.head(3)
# Out:
#        id                                              title  readyInMinutes  \
# 0  798400  Spicy Black-Eyed Pea Curry with Swiss Chard an...              45
# 1  646043                       Gujarati Dry Mung Bean Curry              45
# 2  716364          Rice and Peas with Coconut Curry Mackerel              45
#
#    servings                                              image  \
# 0         6  https://spoonacular.com/recipeImages/798400-31...
# 1         4  https://spoonacular.com/recipeImages/646043-31...
# 2         4  https://spoonacular.com/recipeImages/716364-31...
#
#           cuisines                               analyzedInstructions  dish  \
# 0  [Indian, Asian]  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 1  [Indian, Asian]  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 2  [Indian, Asian]  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
#
#                                          ingredients  \
# 0  {'black eyed peas': '0.33 cups', 'curry powder...
# 1  {'baking powder': '0.25 small pinch', 'chillie...
# 2  {'coconut milk': '0.5 cups', 'corn starch': '0...
#
#                                              grocery
# 0  [black eyed peas, curry powder, garam masala, ...
# 1  [baking powder, chillies, cinnamon powder, cor...
# 2  [coconut milk, corn starch, curry powder, garl...

# %% [markdown]
# # Extracting Instructions

# %%
recipe_instructions=recipe9_df[['analyzedInstructions','id']]
#recipe_instructions.head

# %%
recipe_inst=[]
for instructions,ids in zip(list(recipe_instructions['analyzedInstructions'].values),list(recipe_instructions['id'].values)):
    #print(instructions,ids)
    #print(instructions[0]['steps'])
    instruct={}
    recipe_step=''
    try:
    #break   
        for no_steps in range(len(instructions[0]['steps'])):
            #print(no_steps)
            recipe_step+=instructions[0]['steps'][no_steps]['step']    
            #break
            #print(recipe_step)
        instruct[ids]=recipe_step
        #print(instruct)
        recipe_inst.append(instruct)
    except:
        pass

# %%
instruction_final=pd.DataFrame()
for dict_recipe in recipe_inst:
    df=pd.DataFrame(dict_recipe,index=dict_recipe.keys())
    df.columns=['instructions']
    #print(df)
    #break
    instruction_final=pd.concat([instruction_final,df],ignore_index=False,axis=0)

# %%
instruction_final.index.names = ['id']
#instruction_final

# %%
recipe9_df=recipe9_df.merge(instruction_final,on='id')
recipe9_df.drop(columns=['analyzedInstructions'],inplace=True)

# %%
recipe9_df.head(3)
# Out:
#        id                                              title  readyInMinutes  \
# 0  798400  Spicy Black-Eyed Pea Curry with Swiss Chard an...              45
# 1  646043                       Gujarati Dry Mung Bean Curry              45
# 2  716364          Rice and Peas with Coconut Curry Mackerel              45
#
#    servings                                              image  \
# 0         6  https://spoonacular.com/recipeImages/798400-31...
# 1         4  https://spoonacular.com/recipeImages/646043-31...
# 2         4  https://spoonacular.com/recipeImages/716364-31...
#
#           cuisines  dish                                        ingredients  \
# 0  [Indian, Asian]     1  {'black eyed peas': '0.33 cups', 'curry powder...
# 1  [Indian, Asian]     1  {'baking powder': '0.25 small pinch', 'chillie...
# 2  [Indian, Asian]     1  {'coconut milk': '0.5 cups', 'corn starch': '0...
#
#                                              grocery  \
# 0  [black eyed peas, curry powder, garam masala, ...
# 1  [baking powder, chillies, cinnamon powder, cor...
# 2  [coconut milk, corn starch, curry powder, garl...
#
#                                         instructions
# 0  Rinse the black-eyed peas and soak in several ...
# 1  Wash the mung beans and boil them in plenty of...
# 2  Pour 1 cup of coconut milk in a pot with 1 sea...

# %%
#Saving 100 recipes dataframe to a csv
recipe9_df.to_csv('./all_recipes/recipe9.csv',index=False)

# %% [markdown]
# # Extracting nutrition data

# %%
nutri_list =[]
id_list=[]
for recipe in new_res5['results']:
    recipe_id =recipe['id']
    nutrients =recipe['nutrition']['nutrients']
    nutri_dict={}
    for nutrient_dict in nutrients:
        name = nutrient_dict['name']
        amount = nutrient_dict['amount']
        unit = nutrient_dict['unit']
        #value = str(round(amount,2))+' '+unit
        key=name+' '+unit
        #print(name)
        nutri_dict[key]=amount
    nutri_list.append(nutri_dict)
    id_list.append(recipe_id)

# %%
nutrition9_df= pd.DataFrame(nutri_list,index=id_list)
nutrition9_df.index.name='recipe_id'
nutrition9_df.head(3)
# Out:
#            Calories kcal  Fat g  Saturated Fat g  Carbohydrates g  \
# recipe_id
# 798400            130.74   2.28             0.35            23.47
# 646043            416.87   5.81             0.69            73.79
# 716364            624.26  33.86            24.08            50.96
#
#            Net Carbohydrates g  Sugar g  Cholesterol mg  Sodium mg  Protein g  \
# recipe_id
# 798400                   15.46     7.54            0.00     502.78       7.01
# 646043                   58.28    20.38            0.00     242.66      23.05
# 716364                   47.35     1.20           52.88     117.46      30.80
#
#            Vitamin K µg  ...  Vitamin E mg  Zinc mg  Vitamin B2 mg  \
# recipe_id                ...
# 798400           423.92  ...          1.93     1.21           0.13
# 646043           214.10  ...          2.41     3.03           0.44
# 716364             6.13  ...          1.90     2.30           0.53
#
#            Vitamin B3 mg  Vitamin B5 mg  Calcium mg  Selenium µg  \
# recipe_id
# 798400              1.36           0.63       61.26         2.82
# 646043             21.16           1.58      322.18        12.81
# 716364             11.17           1.08       85.42        49.09
#
#            Vitamin B12 µg  Vitamin D µg  Alcohol g
# recipe_id
# 798400                NaN           NaN        NaN
# 646043                NaN           NaN        NaN
# 716364               4.95         10.24        NaN
#
# [3 rows x 32 columns]

# %%
#saving the nutrition details of 100 recipes dataframe to csv
nutrition9_df.to_csv('./all_nutrition/nutrition9.csv',index=True)

# %%
#Defining dataframe for ingredients
ingres9_df=pd.DataFrame(ingredients_list,index= recipe_idlist)
ingres9_df.fillna(value=0,inplace=True)
ingres9_df.index.name='recipe_id'
ingres9_df.head(3)
# Out:
#           black eyed peas     curry powder   garam masala globe eggplant  \
# recipe_id
# 798400          0.33 cups   0.33 teaspoons  0.08 teaspoon     0.17 large
# 646043                  0                0              0              0
# 716364                  0  0.5 tablespoons              0              0
#
#           ground coriander   ground cumin mustard powder juice of lemon  \
# recipe_id
# 798400       0.08 teaspoon  0.08 teaspoon  0.08 teaspoon           0.5
# 646043                   0              0              0              0
# 716364                   0              0              0              0
#
#                 olive oil red chilies  ... desiccated coconut methi  \
# recipe_id                              ...
# 798400     0.33 teaspoons       0.33   ...                  0     0
# 646043                  0           0  ...                  0     0
# 716364                  0           0  ...                  0     0
#
#           white button mushrooms ground tumeric mint natural yoghurt  \
# recipe_id
# 798400                         0              0    0               0
# 646043                         0              0    0               0
# 716364                         0              0    0               0
#
#           ground almond low fat yogurt wheat flour all purpose flour
# recipe_id
# 798400                0              0           0                 0
# 646043                0              0           0                 0
# 716364                0              0           0                 0
#
# [3 rows x 388 columns]

# %%
#saving the ingredients of 100 recipes dataframe to csv
ingres9_df.to_csv('./all_ingredients/ingredients9.csv',index=True)
