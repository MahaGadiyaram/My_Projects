# %%
#import libraries
import pandas as pd
import json
import re
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import requests
import warnings
import pprint
warnings.simplefilter('ignore')

# %%
url ='https://api.spoonacular.com/recipes/complexSearch?apiKey=f8ee45e309f245b898a387c198c560c1&query=Lamb&addRecipeInformation=True&addRecipeNutrition=True&number=100'
new_res2= requests.get(url).json()
new_res2
# Out:
# {'results': [{'vegetarian': False,
#    'vegan': False,
#    'glutenFree': False,
#    'dairyFree': False,
#    'veryHealthy': False,
#    'cheap': False,
#    'veryPopular': False,
#    'sustainable': False,
#    'weightWatcherSmartPoints': 27,
#    'gaps': 'no',
#    'lowFodmap': False,
#    'aggregateLikes': 1,
#    'spoonacularScore': 78.0,
#    'healthScore': 42.0,
#    'creditsText': 'Foodista.com – The Cooking Encyclopedia Everyone Can Edit',
#    'license': 'CC BY 3.0',
#    'sourceName': 'Foodista',
#    'pricePerServing': 528.5,
#    'id': 649225,
#    'title': 'Lamb Moussaka',
#    'readyInMinutes': 45,
#    'servings': 12,
#    'sourceUrl': 'http://www.foodista.com/recipe/RSSXNKVB/lamb-moussaka',
#    'image': 'https://spoonacular.com/recipeImages/649225-312x231.jpg',
#    'imageType': 'jpg',
#    'nutrition': {'nutrients': [{'name': 'Calories',
#       'amount': 763.16,
#       'unit': 'kcal',
#       'percentOfDailyNeeds': 38.16},
#      {'name': 'Fat',
#       'amount': 32.56,
#       'unit': 'g',
#       'percentOfDailyNeeds': 50.09},
#      {'name': 'Saturated Fat',
#       'amount': 10.88,
#       'unit': 'g',
#       'percentOfDailyNeeds': 68.02},
#      {'name': 'Carbohydrates',
#       'amount': 35.64,
#       'unit': 'g',
#       'percentOfDailyNeeds': 11.88},
#      {'name': 'Net Carbohydrates',
#       'amount': 29.69,
#       'unit': 'g',
#       'percentOfDailyNeeds': 10.8},
#      {'name': 'Sugar',
#       'amount': 20.59,
#       'unit': 'g',
#       'percentOfDailyNeeds': 22.87},
#      {'name': 'Cholesterol',
#       'amount': 261.5,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 87.17},
#      {'name': 'Sodium',
#       'amount': 1587.14,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 69.01},
#      {'name': 'Alcohol',
#       'amount': 1.05,
#       'unit': 'g',
#       'percentOfDailyNeeds': 5.83},
#      {'name': 'Protein',
#       'amount': 78.7,
#       'unit': 'g',
#       'percentOfDailyNeeds': 157.41},
#      {'name': 'Vitamin B3',
#       'amount': 30.58,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 152.9},
#      {'name': 'Selenium',
#       'amount': 104.77,
#       'unit': 'µg',
#       'percentOfDailyNeeds': 149.67},
#      {'name': 'Vitamin B6',
#       'amount': 2.15,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 107.6},
#      {'name': 'Phosphorus',
#       'amount': 986.46,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 98.65},
#      {'name': 'Vitamin K',
#       'amount': 59.93,
#       'unit': 'µg',
#       'percentOfDailyNeeds': 57.08},
#      {'name': 'Potassium',
#       'amount': 1844.61,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 52.7},
#      {'name': 'Vitamin B2',
#       'amount': 0.89,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 52.34},
#      {'name': 'Vitamin B12',
#       'amount': 3.01,
#       'unit': 'µg',
#       'percentOfDailyNeeds': 50.21},
#      {'name': 'Vitamin B5',
#       'amount': 4.81,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 48.09},
#      {'name': 'Calcium',
#       'amount': 478.31,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 47.83},
#      {'name': 'Zinc',
#       'amount': 6.2,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 41.31},
#      {'name': 'Magnesium',
#       'amount': 137.55,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 34.39},
#      {'name': 'Vitamin B1',
#       'amount': 0.46,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 30.62},
#      {'name': 'Manganese',
#       'amount': 0.6,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 30.03},
#      {'name': 'Vitamin C',
#       'amount': 24.71,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 29.95},
#      {'name': 'Iron',
#       'amount': 4.58,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 25.43},
#      {'name': 'Folate',
#       'amount': 100.48,
#       'unit': 'µg',
#       'percentOfDailyNeeds': 25.12},
#      {'name': 'Fiber',
#       'amount': 5.95,
#       'unit': 'g',
#       'percentOfDailyNeeds': 23.82},
#      {'name': 'Vitamin A',
#       'amount': 1089.49,
#       'unit': 'IU',
#       'percentOfDailyNeeds': 21.79},
#      {'name': 'Copper',
#       'amount': 0.42,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 21.03},
#      {'name': 'Vitamin E',
#       'amount': 2.94,
#       'unit': 'mg',
#       'percentOfDailyNeeds': 19.61},
#      {'name': 'Vitamin D',
#       'amount': 1.57,
#       'unit': 'µg',
#       'percentOfDailyNeeds': 10.5}],
#     'properties': [{'name': 'Glycemic Index', 'amount': 27.52, 'unit': ''},
#      {'name': 'Glycemic Load', 'amount': 7.29, 'unit': ''}],
#     'flavonoids': [{'name': 'Cyanidin', 'amount': 0.0, 'unit': ''},
#      {'name': 'Petunidin', 'amount': 0.33, 'unit': 'mg'},
#      {'name': 'Delphinidin', 'amount': 81.39, 'unit': 'mg'},
#      {'name': 'Malvidin', 'amount': 2.62, 'unit': 'mg'},
#      {'name': 'Pelargonidin', 'amount': 0.0, 'unit': ''},
#      {'name': 'Peonidin', 'amount': 0.19, 'unit': 'mg'},
#      {'name': 'Catechin', 'amount': 0.77, 'unit': 'mg'},
#      {'name': 'Epigallocatechin', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Epicatechin', 'amount': 1.07, 'unit': 'mg'},
#      {'name': 'Epicatechin 3-gallate', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Epigallocatechin 3-gallate', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Theaflavin', 'amount': 0.0, 'unit': ''},
#      {'name': 'Thearubigins', 'amount': 0.0, 'unit': ''},
#      {'name': 'Eriodictyol', 'amount': 0.0, 'unit': ''},
#      {'name': 'Hesperetin', 'amount': 0.0, 'unit': 'mg'},
#      {'name': 'Naringenin', 'amount': 0.0, 'unit': ''},
#      {'name': 'Apigenin', 'amount': 5.39, 'unit': 'mg'},
#      {'name': 'Luteolin', 'amount': 0.04, 'unit': 'mg'},
#      {'name': 'Isorhamnetin', 'amount': 0.92, 'unit': 'mg'},
#      {'name': 'Kaempferol', 'amount': 0.16, 'unit': 'mg'},
#      {'name': 'Myricetin', 'amount': 0.41, 'unit': 'mg'},
#      {'name': 'Quercetin', 'amount': 4.16, 'unit': 'mg'},
#      {'name': "Theaflavin-3,3'-digallate", 'amount': 0.0, 'unit': ''},
#      {'name': "Theaflavin-3'-gallate", 'amount': 0.0, 'unit': ''},
#      {'name': 'Theaflavin-3-gallate', 'amount': 0.0, 'unit': ''},
#      {'name': 'Gallocatechin', 'amount': 0.0, 'unit': 'mg'}],
#     'ingredients': [{'id': 20081,
#       'name': 'all purpose flour',
#       'amount': 0.04,
#       'unit': 'cup',
#       'nutrients': [{'name': 'Folic Acid', 'amount': 8.02, 'unit': 'µg'},
#        {'name': 'Vitamin E', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B2', 'amount': 0.03, 'unit': 'mg'},
#        {'name': 'Fiber', 'amount': 0.14, 'unit': 'g'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Net Carbohydrates', 'amount': 3.83, 'unit': 'g'},
#        {'name': 'Fat', 'amount': 0.05, 'unit': 'g'},
#        {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Manganese', 'amount': 0.04, 'unit': 'mg'},
#        {'name': 'Lycopene', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sugar', 'amount': 0.01, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 5.57, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 9.53, 'unit': 'µg'},
#        {'name': 'Vitamin K', 'amount': 0.02, 'unit': 'µg'},
#        {'name': 'Zinc', 'amount': 0.04, 'unit': 'mg'},
#        {'name': 'Phosphorus', 'amount': 5.63, 'unit': 'mg'},
#        {'name': 'Iron', 'amount': 0.24, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B3', 'amount': 0.31, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Magnesium', 'amount': 1.15, 'unit': 'mg'},
#        {'name': 'Choline', 'amount': 0.54, 'unit': 'mg'},
#        {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.02, 'unit': 'mg'},
#        {'name': 'Protein', 'amount': 0.54, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 18.96, 'unit': 'kcal'},
#        {'name': 'Sodium', 'amount': 0.1, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.04, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.02, 'unit': 'g'},
#        {'name': 'Copper', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 0.78, 'unit': 'mg'},
#        {'name': 'Saturated Fat', 'amount': 0.01, 'unit': 'g'},
#        {'name': 'Vitamin A', 'amount': 0.0, 'unit': 'IU'},
#        {'name': 'Carbohydrates', 'amount': 3.97, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 1.77, 'unit': 'µg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'}]},
#      {'id': 10011693,
#       'name': 'canned tomatoes',
#       'amount': 0.08,
#       'unit': 'can',
#       'nutrients': [{'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin E', 'amount': 0.43, 'unit': 'mg'},
#        {'name': 'Vitamin B2', 'amount': 0.02, 'unit': 'mg'},
#        {'name': 'Fiber', 'amount': 0.65, 'unit': 'g'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 0.01, 'unit': 'g'},
#        {'name': 'Net Carbohydrates', 'amount': 1.85, 'unit': 'g'},
#        {'name': 'Fat', 'amount': 0.1, 'unit': 'g'},
#        {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Manganese', 'amount': 0.06, 'unit': 'mg'},
#        {'name': 'Lycopene', 'amount': 1748.81, 'unit': 'µg'},
#        {'name': 'Sugar', 'amount': 1.51, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 100.35, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 4.45, 'unit': 'µg'},
#        {'name': 'Vitamin K', 'amount': 1.82, 'unit': 'µg'},
#        {'name': 'Zinc', 'amount': 0.09, 'unit': 'mg'},
#        {'name': 'Phosphorus', 'amount': 10.96, 'unit': 'mg'},
#        {'name': 'Iron', 'amount': 0.45, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.05, 'unit': 'mg'},
#        {'name': 'Vitamin B3', 'amount': 0.42, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 3.15, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Magnesium', 'amount': 6.85, 'unit': 'mg'},
#        {'name': 'Choline', 'amount': 4.42, 'unit': 'mg'},
#        {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.1, 'unit': 'mg'},
#        {'name': 'Protein', 'amount': 0.56, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 10.96, 'unit': 'kcal'},
#        {'name': 'Sodium', 'amount': 45.21, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.03, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.04, 'unit': 'g'},
#        {'name': 'Copper', 'amount': 0.06, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 11.65, 'unit': 'mg'},
#        {'name': 'Saturated Fat', 'amount': 0.01, 'unit': 'g'},
#        {'name': 'Vitamin A', 'amount': 73.64, 'unit': 'IU'},
#        {'name': 'Carbohydrates', 'amount': 2.5, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 0.21, 'unit': 'µg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'}]},
#      {'id': 18139,
#       'name': 'cup cake',
#       'amount': 0.08,
#       'unit': 'cup',
#       'nutrients': [{'name': 'Folic Acid', 'amount': 6.11, 'unit': 'µg'},
#        {'name': 'Vitamin E', 'amount': 0.02, 'unit': 'mg'},
#        {'name': 'Vitamin B2', 'amount': 0.05, 'unit': 'mg'},
#        {'name': 'Fiber', 'amount': 0.16, 'unit': 'g'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 1.05, 'unit': 'g'},
#        {'name': 'Net Carbohydrates', 'amount': 11.12, 'unit': 'g'},
#        {'name': 'Fat', 'amount': 2.44, 'unit': 'g'},
#        {'name': 'Vitamin B12', 'amount': 0.02, 'unit': 'µg'},
#        {'name': 'Manganese', 'amount': 0.04, 'unit': 'mg'},
#        {'name': 'Lycopene', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sugar', 'amount': 7.0, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 18.73, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 7.49, 'unit': 'µg'},
#        {'name': 'Vitamin K', 'amount': 1.01, 'unit': 'µg'},
#        {'name': 'Zinc', 'amount': 0.06, 'unit': 'mg'},
#        {'name': 'Phosphorus', 'amount': 18.34, 'unit': 'mg'},
#        {'name': 'Iron', 'amount': 0.3, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B3', 'amount': 0.3, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 0.04, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 0.39, 'unit': 'mg'},
#        {'name': 'Magnesium', 'amount': 2.37, 'unit': 'mg'},
#        {'name': 'Choline', 'amount': 1.12, 'unit': 'mg'},
#        {'name': 'Vitamin B5', 'amount': 0.04, 'unit': 'mg'},
#        {'name': 'Protein', 'amount': 1.06, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 70.38, 'unit': 'kcal'},
#        {'name': 'Sodium', 'amount': 64.47, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.04, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.62, 'unit': 'g'},
#        {'name': 'Copper', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 25.63, 'unit': 'mg'},
#        {'name': 'Saturated Fat', 'amount': 0.64, 'unit': 'g'},
#        {'name': 'Vitamin A', 'amount': 10.25, 'unit': 'IU'},
#        {'name': 'Carbohydrates', 'amount': 11.28, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 2.56, 'unit': 'µg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'}]},
#      {'id': 14097,
#       'name': 'dry red wine',
#       'amount': 0.04,
#       'unit': 'cup',
#       'nutrients': [{'name': 'Net Carbohydrates', 'amount': 0.26, 'unit': 'g'},
#        {'name': 'Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Protein', 'amount': 0.01, 'unit': 'g'},
#        {'name': 'Carbohydrates', 'amount': 0.26, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 8.3, 'unit': 'kcal'},
#        {'name': 'Alcohol', 'amount': 1.05, 'unit': 'g'}]},
#      {'id': 1123,
#       'name': 'egg',
#       'amount': 0.33,
#       'unit': '',
#       'nutrients': [{'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin E', 'amount': 0.15, 'unit': 'mg'},
#        {'name': 'Vitamin B2', 'amount': 0.07, 'unit': 'mg'},
#        {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 0.54, 'unit': 'g'},
#        {'name': 'Net Carbohydrates', 'amount': 0.11, 'unit': 'g'},
#        {'name': 'Fat', 'amount': 1.39, 'unit': 'g'},
#        {'name': 'Vitamin B12', 'amount': 0.13, 'unit': 'µg'},
#        {'name': 'Manganese', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Lycopene', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sugar', 'amount': 0.05, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 20.24, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 6.89, 'unit': 'µg'},
#        {'name': 'Vitamin K', 'amount': 0.04, 'unit': 'µg'},
#        {'name': 'Zinc', 'amount': 0.19, 'unit': 'mg'},
#        {'name': 'Phosphorus', 'amount': 29.04, 'unit': 'mg'},
#        {'name': 'Iron', 'amount': 0.26, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.02, 'unit': 'mg'},
#        {'name': 'Vitamin B3', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 54.56, 'unit': 'mg'},
#        {'name': 'Magnesium', 'amount': 1.76, 'unit': 'mg'},
#        {'name': 'Choline', 'amount': 43.09, 'unit': 'mg'},
#        {'name': 'Vitamin D', 'amount': 0.29, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.22, 'unit': 'mg'},
#        {'name': 'Protein', 'amount': 1.84, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 20.97, 'unit': 'kcal'},
#        {'name': 'Sodium', 'amount': 20.83, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Fluoride', 'amount': 0.16, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.28, 'unit': 'g'},
#        {'name': 'Copper', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 8.21, 'unit': 'mg'},
#        {'name': 'Saturated Fat', 'amount': 0.46, 'unit': 'g'},
#        {'name': 'Vitamin A', 'amount': 79.2, 'unit': 'IU'},
#        {'name': 'Carbohydrates', 'amount': 0.11, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 4.5, 'unit': 'µg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Trans Fat', 'amount': 0.01, 'unit': 'g'}]},
#      {'id': 11209,
#       'name': 'eggplant',
#       'amount': 0.21,
#       'unit': 'pounds',
#       'nutrients': [{'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin E', 'amount': 0.28, 'unit': 'mg'},
#        {'name': 'Vitamin B2', 'amount': 0.03, 'unit': 'mg'},
#        {'name': 'Fiber', 'amount': 2.83, 'unit': 'g'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 0.02, 'unit': 'g'},
#        {'name': 'Net Carbohydrates', 'amount': 2.72, 'unit': 'g'},
#        {'name': 'Fat', 'amount': 0.17, 'unit': 'g'},
#        {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Manganese', 'amount': 0.22, 'unit': 'mg'},
#        {'name': 'Lycopene', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sugar', 'amount': 3.34, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 216.4, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 20.79, 'unit': 'µg'},
#        {'name': 'Vitamin K', 'amount': 3.31, 'unit': 'µg'},
#        {'name': 'Zinc', 'amount': 0.15, 'unit': 'mg'},
#        {'name': 'Phosphorus', 'amount': 22.68, 'unit': 'mg'},
#        {'name': 'Iron', 'amount': 0.22, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.08, 'unit': 'mg'},
#        {'name': 'Vitamin B3', 'amount': 0.61, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 2.08, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Magnesium', 'amount': 13.23, 'unit': 'mg'},
#        {'name': 'Choline', 'amount': 6.52, 'unit': 'mg'},
#        {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.27, 'unit': 'mg'},
#        {'name': 'Protein', 'amount': 0.93, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 23.62, 'unit': 'kcal'},
#        {'name': 'Sodium', 'amount': 1.89, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.04, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.07, 'unit': 'g'},
#        {'name': 'Copper', 'amount': 0.08, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 8.5, 'unit': 'mg'},
#        {'name': 'Saturated Fat', 'amount': 0.03, 'unit': 'g'},
#        {'name': 'Vitamin A', 'amount': 21.73, 'unit': 'IU'},
#        {'name': 'Carbohydrates', 'amount': 5.56, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 0.28, 'unit': 'µg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'}]},
#      {'id': 1085,
#       'name': 'fat-free milk',
#       'amount': 0.33,
#       'unit': 'cups',
#       'nutrients': [{'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin E', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Vitamin B2', 'amount': 0.15, 'unit': 'mg'},
#        {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 0.02, 'unit': 'g'},
#        {'name': 'Net Carbohydrates', 'amount': 4.05, 'unit': 'g'},
#        {'name': 'Fat', 'amount': 0.07, 'unit': 'g'},
#        {'name': 'Vitamin B12', 'amount': 0.41, 'unit': 'µg'},
#        {'name': 'Manganese', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Lycopene', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sugar', 'amount': 4.16, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 127.4, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 4.08, 'unit': 'µg'},
#        {'name': 'Vitamin K', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Zinc', 'amount': 0.34, 'unit': 'mg'},
#        {'name': 'Phosphorus', 'amount': 82.48, 'unit': 'mg'},
#        {'name': 'Iron', 'amount': 0.02, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.03, 'unit': 'mg'},
#        {'name': 'Vitamin B3', 'amount': 0.08, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 1.63, 'unit': 'mg'},
#        {'name': 'Magnesium', 'amount': 8.98, 'unit': 'mg'},
#        {'name': 'Choline', 'amount': 12.74, 'unit': 'mg'},
#        {'name': 'Vitamin D', 'amount': 0.98, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.29, 'unit': 'mg'},
#        {'name': 'Protein', 'amount': 2.75, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 27.77, 'unit': 'kcal'},
#        {'name': 'Sodium', 'amount': 34.3, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.04, 'unit': 'mg'},
#        {'name': 'Fluoride', 'amount': 2.53, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Copper', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 99.63, 'unit': 'mg'},
#        {'name': 'Saturated Fat', 'amount': 0.05, 'unit': 'g'},
#        {'name': 'Vitamin A', 'amount': 166.6, 'unit': 'IU'},
#        {'name': 'Carbohydrates', 'amount': 4.05, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 2.53, 'unit': 'µg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'}]},
#      {'id': 42304,
#       'name': 'fat free mozzarella cheese',
#       'amount': 0.25,
#       'unit': 'cups',
#       'nutrients': [{'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin E', 'amount': 0.04, 'unit': 'mg'},
#        {'name': 'Vitamin B2', 'amount': 0.08, 'unit': 'mg'},
#        {'name': 'Fiber', 'amount': 0.51, 'unit': 'g'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Net Carbohydrates', 'amount': 0.48, 'unit': 'g'},
#        {'name': 'Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin B12', 'amount': 0.26, 'unit': 'µg'},
#        {'name': 'Lycopene', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sugar', 'amount': 0.42, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 29.94, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 2.83, 'unit': 'µg'},
#        {'name': 'Vitamin K', 'amount': 0.45, 'unit': 'µg'},
#        {'name': 'Zinc', 'amount': 1.11, 'unit': 'mg'},
#        {'name': 'Phosphorus', 'amount': 185.32, 'unit': 'mg'},
#        {'name': 'Iron', 'amount': 0.09, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.02, 'unit': 'mg'},
#        {'name': 'Vitamin B3', 'amount': 0.03, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 5.09, 'unit': 'mg'},
#        {'name': 'Magnesium', 'amount': 9.32, 'unit': 'mg'},
#        {'name': 'Choline', 'amount': 4.35, 'unit': 'mg'},
#        {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Protein', 'amount': 8.96, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 39.83, 'unit': 'kcal'},
#        {'name': 'Sodium', 'amount': 209.9, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Copper', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 271.48, 'unit': 'mg'},
#        {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin A', 'amount': 135.88, 'unit': 'IU'},
#        {'name': 'Carbohydrates', 'amount': 0.99, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 5.34, 'unit': 'µg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'}]},
#      {'id': 11297,
#       'name': 'fresh parsley',
#       'amount': 0.04,
#       'unit': 'cup',
#       'nutrients': [{'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin E', 'amount': 0.02, 'unit': 'mg'},
#        {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Fiber', 'amount': 0.08, 'unit': 'g'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 0.01, 'unit': 'g'},
#        {'name': 'Net Carbohydrates', 'amount': 0.08, 'unit': 'g'},
#        {'name': 'Fat', 'amount': 0.02, 'unit': 'g'},
#        {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Manganese', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Lycopene', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sugar', 'amount': 0.02, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 13.85, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 3.8, 'unit': 'µg'},
#        {'name': 'Vitamin K', 'amount': 41.0, 'unit': 'µg'},
#        {'name': 'Zinc', 'amount': 0.03, 'unit': 'mg'},
#        {'name': 'Phosphorus', 'amount': 1.45, 'unit': 'mg'},
#        {'name': 'Iron', 'amount': 0.16, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B3', 'amount': 0.03, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 3.33, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Magnesium', 'amount': 1.25, 'unit': 'mg'},
#        {'name': 'Choline', 'amount': 0.32, 'unit': 'mg'},
#        {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Protein', 'amount': 0.07, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 0.9, 'unit': 'kcal'},
#        {'name': 'Sodium', 'amount': 1.4, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 3.45, 'unit': 'mg'},
#        {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin A', 'amount': 210.6, 'unit': 'IU'},
#        {'name': 'Carbohydrates', 'amount': 0.16, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'}]},
#      {'id': 11215,
#       'name': 'garlic',
#       'amount': 0.17,
#       'unit': '',
#       'nutrients': [{'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin E', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Fiber', 'amount': 0.01, 'unit': 'g'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Net Carbohydrates', 'amount': 0.15, 'unit': 'g'},
#        {'name': 'Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Manganese', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Lycopene', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sugar', 'amount': 0.01, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 2.01, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 0.02, 'unit': 'µg'},
#        {'name': 'Vitamin K', 'amount': 0.01, 'unit': 'µg'},
#        {'name': 'Zinc', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Phosphorus', 'amount': 0.77, 'unit': 'mg'},
#        {'name': 'Iron', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Vitamin B3', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 0.16, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Magnesium', 'amount': 0.13, 'unit': 'mg'},
#        {'name': 'Choline', 'amount': 0.12, 'unit': 'mg'},
#        {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Protein', 'amount': 0.03, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 0.75, 'unit': 'kcal'},
#        {'name': 'Sodium', 'amount': 0.09, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 0.9, 'unit': 'mg'},
#        {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin A', 'amount': 0.05, 'unit': 'IU'},
#        {'name': 'Carbohydrates', 'amount': 0.17, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 0.07, 'unit': 'µg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'}]},
#      {'id': 17224,
#       'name': 'ground lamb',
#       'amount': 0.17,
#       'unit': 'pounds',
#       'nutrients': [{'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin E', 'amount': 0.15, 'unit': 'mg'},
#        {'name': 'Vitamin B2', 'amount': 0.16, 'unit': 'mg'},
#        {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 7.26, 'unit': 'g'},
#        {'name': 'Net Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Fat', 'amount': 17.7, 'unit': 'g'},
#        {'name': 'Vitamin B12', 'amount': 1.75, 'unit': 'µg'},
#        {'name': 'Manganese', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Lycopene', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sugar', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 167.83, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 13.61, 'unit': 'µg'},
#        {'name': 'Vitamin K', 'amount': 2.72, 'unit': 'µg'},
#        {'name': 'Zinc', 'amount': 2.58, 'unit': 'mg'},
#        {'name': 'Phosphorus', 'amount': 118.69, 'unit': 'mg'},
#        {'name': 'Iron', 'amount': 1.17, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.1, 'unit': 'mg'},
#        {'name': 'Vitamin B3', 'amount': 4.51, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 55.19, 'unit': 'mg'},
#        {'name': 'Magnesium', 'amount': 15.88, 'unit': 'mg'},
#        {'name': 'Choline', 'amount': 52.39, 'unit': 'mg'},
#        {'name': 'Vitamin D', 'amount': 0.08, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.49, 'unit': 'mg'},
#        {'name': 'Protein', 'amount': 12.52, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 213.19, 'unit': 'kcal'},
#        {'name': 'Sodium', 'amount': 44.6, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.08, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 1.4, 'unit': 'g'},
#        {'name': 'Copper', 'amount': 0.08, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 12.1, 'unit': 'mg'},
#        {'name': 'Saturated Fat', 'amount': 7.7, 'unit': 'g'},
#        {'name': 'Vitamin A', 'amount': 0.0, 'unit': 'IU'},
#        {'name': 'Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 14.21, 'unit': 'µg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'}]},
#      {'id': 6150,
#       'name': 'bbq sauce',
#       'amount': 1.0,
#       'unit': 'servings',
#       'nutrients': [{'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin E', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Fiber', 'amount': 0.01, 'unit': 'g'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Net Carbohydrates', 'amount': 0.4, 'unit': 'g'},
#        {'name': 'Fat', 'amount': 0.01, 'unit': 'g'},
#        {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Manganese', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Lycopene', 'amount': 45.5, 'unit': 'µg'},
#        {'name': 'Sugar', 'amount': 0.33, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 2.32, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 0.02, 'unit': 'µg'},
#        {'name': 'Vitamin K', 'amount': 0.02, 'unit': 'µg'},
#        {'name': 'Zinc', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Phosphorus', 'amount': 0.2, 'unit': 'mg'},
#        {'name': 'Iron', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B3', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Magnesium', 'amount': 0.13, 'unit': 'mg'},
#        {'name': 'Choline', 'amount': 0.07, 'unit': 'mg'},
#        {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Protein', 'amount': 0.01, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 1.72, 'unit': 'kcal'},
#        {'name': 'Sodium', 'amount': 10.27, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 0.33, 'unit': 'mg'},
#        {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin A', 'amount': 2.24, 'unit': 'IU'},
#        {'name': 'Carbohydrates', 'amount': 0.41, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 0.01, 'unit': 'µg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Trans Fat', 'amount': 0.0, 'unit': 'g'}]},
#      {'id': 1065062,
#       'name': 'meat',
#       'amount': 1.0,
#       'unit': 'servings',
#       'nutrients': [{'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin E', 'amount': 0.43, 'unit': 'mg'},
#        {'name': 'Vitamin B2', 'amount': 0.23, 'unit': 'mg'},
#        {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 1.72, 'unit': 'g'},
#        {'name': 'Net Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Fat', 'amount': 5.85, 'unit': 'g'},
#        {'name': 'Vitamin B12', 'amount': 0.45, 'unit': 'µg'},
#        {'name': 'Manganese', 'amount': 0.03, 'unit': 'mg'},
#        {'name': 'Lycopene', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sugar', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 836.2, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 9.04, 'unit': 'µg'},
#        {'name': 'Vitamin K', 'amount': 0.45, 'unit': 'µg'},
#        {'name': 'Zinc', 'amount': 1.31, 'unit': 'mg'},
#        {'name': 'Phosphorus', 'amount': 474.6, 'unit': 'mg'},
#        {'name': 'Iron', 'amount': 0.84, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 1.69, 'unit': 'mg'},
#        {'name': 'Vitamin B3', 'amount': 23.57, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 2.71, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 144.64, 'unit': 'mg'},
#        {'name': 'Magnesium', 'amount': 58.76, 'unit': 'mg'},
#        {'name': 'Choline', 'amount': 165.88, 'unit': 'mg'},
#        {'name': 'Vitamin D', 'amount': 0.23, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 3.22, 'unit': 'mg'},
#        {'name': 'Protein', 'amount': 47.98, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 257.64, 'unit': 'kcal'},
#        {'name': 'Sodium', 'amount': 262.16, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.14, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.9, 'unit': 'g'},
#        {'name': 'Copper', 'amount': 0.06, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 11.3, 'unit': 'mg'},
#        {'name': 'Saturated Fat', 'amount': 1.28, 'unit': 'g'},
#        {'name': 'Vitamin A', 'amount': 67.8, 'unit': 'IU'},
#        {'name': 'Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 72.32, 'unit': 'µg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Trans Fat', 'amount': 0.03, 'unit': 'g'}]},
#      {'id': 4053,
#       'name': 'olive oil',
#       'amount': 0.02,
#       'unit': 'cup',
#       'nutrients': [{'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin E', 'amount': 0.65, 'unit': 'mg'},
#        {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 3.28, 'unit': 'g'},
#        {'name': 'Net Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Fat', 'amount': 4.5, 'unit': 'g'},
#        {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Manganese', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Lycopene', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sugar', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 0.05, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin K', 'amount': 2.71, 'unit': 'µg'},
#        {'name': 'Zinc', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Phosphorus', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Iron', 'amount': 0.03, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B3', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Magnesium', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Choline', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Protein', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 39.78, 'unit': 'kcal'},
#        {'name': 'Sodium', 'amount': 0.09, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.47, 'unit': 'g'},
#        {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 0.05, 'unit': 'mg'},
#        {'name': 'Saturated Fat', 'amount': 0.62, 'unit': 'g'},
#        {'name': 'Vitamin A', 'amount': 0.0, 'unit': 'IU'},
#        {'name': 'Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'}]},
#      {'id': 11282,
#       'name': 'onion',
#       'amount': 0.17,
#       'unit': 'medium',
#       'nutrients': [{'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin E', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Fiber', 'amount': 0.31, 'unit': 'g'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Net Carbohydrates', 'amount': 1.4, 'unit': 'g'},
#        {'name': 'Fat', 'amount': 0.02, 'unit': 'g'},
#        {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Manganese', 'amount': 0.02, 'unit': 'mg'},
#        {'name': 'Lycopene', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sugar', 'amount': 0.78, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 26.77, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 3.48, 'unit': 'µg'},
#        {'name': 'Vitamin K', 'amount': 0.07, 'unit': 'µg'},
#        {'name': 'Zinc', 'amount': 0.03, 'unit': 'mg'},
#        {'name': 'Phosphorus', 'amount': 5.32, 'unit': 'mg'},
#        {'name': 'Iron', 'amount': 0.04, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.02, 'unit': 'mg'},
#        {'name': 'Vitamin B3', 'amount': 0.02, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 1.36, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Magnesium', 'amount': 1.83, 'unit': 'mg'},
#        {'name': 'Choline', 'amount': 1.12, 'unit': 'mg'},
#        {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.02, 'unit': 'mg'},
#        {'name': 'Protein', 'amount': 0.2, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 7.33, 'unit': 'kcal'},
#        {'name': 'Sodium', 'amount': 0.73, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Fluoride', 'amount': 0.2, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Copper', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 4.22, 'unit': 'mg'},
#        {'name': 'Saturated Fat', 'amount': 0.01, 'unit': 'g'},
#        {'name': 'Vitamin A', 'amount': 0.37, 'unit': 'IU'},
#        {'name': 'Carbohydrates', 'amount': 1.71, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 0.09, 'unit': 'µg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'}]},
#      {'id': 2027,
#       'name': 'oregano leaves',
#       'amount': 0.08,
#       'unit': 'tablespoon',
#       'nutrients': [{'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin E', 'amount': 0.08, 'unit': 'mg'},
#        {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Fiber', 'amount': 0.18, 'unit': 'g'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Net Carbohydrates', 'amount': 0.11, 'unit': 'g'},
#        {'name': 'Fat', 'amount': 0.02, 'unit': 'g'},
#        {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Manganese', 'amount': 0.02, 'unit': 'mg'},
#        {'name': 'Lycopene', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sugar', 'amount': 0.02, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 5.25, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 0.99, 'unit': 'µg'},
#        {'name': 'Vitamin K', 'amount': 2.59, 'unit': 'µg'},
#        {'name': 'Zinc', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Phosphorus', 'amount': 0.62, 'unit': 'mg'},
#        {'name': 'Iron', 'amount': 0.15, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B3', 'amount': 0.02, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Magnesium', 'amount': 1.13, 'unit': 'mg'},
#        {'name': 'Choline', 'amount': 0.13, 'unit': 'mg'},
#        {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Protein', 'amount': 0.04, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 1.1, 'unit': 'kcal'},
#        {'name': 'Sodium', 'amount': 0.1, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.01, 'unit': 'g'},
#        {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 6.65, 'unit': 'mg'},
#        {'name': 'Saturated Fat', 'amount': 0.01, 'unit': 'g'},
#        {'name': 'Vitamin A', 'amount': 7.09, 'unit': 'IU'},
#        {'name': 'Carbohydrates', 'amount': 0.29, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 0.02, 'unit': 'µg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Trans Fat', 'amount': 0.0, 'unit': 'g'}]},
#      {'id': 2047,
#       'name': 'salt',
#       'amount': 0.08,
#       'unit': 'tablespoon',
#       'nutrients': [{'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin E', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Net Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Manganese', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Lycopene', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sugar', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 0.12, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin K', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Zinc', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Phosphorus', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Iron', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B3', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Magnesium', 'amount': 0.02, 'unit': 'mg'},
#        {'name': 'Choline', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Protein', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 0.0, 'unit': 'kcal'},
#        {'name': 'Sodium', 'amount': 581.37, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Fluoride', 'amount': 0.03, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 0.36, 'unit': 'mg'},
#        {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin A', 'amount': 0.0, 'unit': 'IU'},
#        {'name': 'Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'}]},
#      {'id': 2047,
#       'name': 'salt',
#       'amount': 0.08,
#       'unit': 'teaspoon',
#       'nutrients': [{'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin E', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Net Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Manganese', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Lycopene', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sugar', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 0.04, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin K', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Zinc', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Phosphorus', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Iron', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B3', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Magnesium', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Choline', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Protein', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 0.0, 'unit': 'kcal'},
#        {'name': 'Sodium', 'amount': 193.79, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Fluoride', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 0.12, 'unit': 'mg'},
#        {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin A', 'amount': 0.0, 'unit': 'IU'},
#        {'name': 'Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'}]},
#      {'id': 1102047,
#       'name': 'salt and pepper',
#       'amount': 0.08,
#       'unit': '',
#       'nutrients': [{'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin E', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Net Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Manganese', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Lycopene', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sugar', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin K', 'amount': 0.0, 'unit': 'µg'},
# ...
#        {'name': 'Lycopene', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sugar', 'amount': 0.75, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 195.84, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 4.76, 'unit': 'µg'},
#        {'name': 'Vitamin K', 'amount': 19.92, 'unit': 'µg'},
#        {'name': 'Zinc', 'amount': 0.07, 'unit': 'mg'},
#        {'name': 'Phosphorus', 'amount': 9.52, 'unit': 'mg'},
#        {'name': 'Iron', 'amount': 0.15, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.02, 'unit': 'mg'},
#        {'name': 'Vitamin B3', 'amount': 0.2, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 5.44, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Magnesium', 'amount': 8.16, 'unit': 'mg'},
#        {'name': 'Choline', 'amount': 4.15, 'unit': 'mg'},
#        {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.06, 'unit': 'mg'},
#        {'name': 'Protein', 'amount': 0.61, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 14.28, 'unit': 'kcal'},
#        {'name': 'Sodium', 'amount': 2.72, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.07, 'unit': 'g'},
#        {'name': 'Copper', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 58.48, 'unit': 'mg'},
#        {'name': 'Saturated Fat', 'amount': 0.04, 'unit': 'g'},
#        {'name': 'Vitamin A', 'amount': 69.36, 'unit': 'IU'},
#        {'name': 'Carbohydrates', 'amount': 3.09, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 0.75, 'unit': 'µg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'}]},
#      {'id': 1102047,
#       'name': 'salt and pepper',
#       'amount': 1.0,
#       'unit': 'servings',
#       'nutrients': [{'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin E', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Net Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Manganese', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Lycopene', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sugar', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 0.04, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin K', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Zinc', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Phosphorus', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Iron', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B3', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Magnesium', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Choline', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Protein', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 0.0, 'unit': 'kcal'},
#        {'name': 'Sodium', 'amount': 193.79, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Fluoride', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 0.12, 'unit': 'mg'},
#        {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin A', 'amount': 0.0, 'unit': 'IU'},
#        {'name': 'Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'}]},
#      {'id': 19335,
#       'name': 'sugar',
#       'amount': 0.5,
#       'unit': 'tablespoons',
#       'nutrients': [{'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin E', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Net Carbohydrates', 'amount': 6.0, 'unit': 'g'},
#        {'name': 'Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Manganese', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Lycopene', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sugar', 'amount': 5.99, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 0.12, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin K', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Zinc', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Phosphorus', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Iron', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B3', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Magnesium', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Choline', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin B5', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Protein', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 23.22, 'unit': 'kcal'},
#        {'name': 'Sodium', 'amount': 0.06, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Fluoride', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 0.06, 'unit': 'mg'},
#        {'name': 'Saturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Vitamin A', 'amount': 0.0, 'unit': 'IU'},
#        {'name': 'Carbohydrates', 'amount': 6.0, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 0.04, 'unit': 'µg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'}]},
#      {'id': 2043,
#       'name': 'turmeric',
#       'amount': 0.08,
#       'unit': 'teaspoon',
#       'nutrients': [{'name': 'Folic Acid', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Vitamin E', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Vitamin B2', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Fiber', 'amount': 0.04, 'unit': 'g'},
#        {'name': 'Mono Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Net Carbohydrates', 'amount': 0.07, 'unit': 'g'},
#        {'name': 'Fat', 'amount': 0.02, 'unit': 'g'},
#        {'name': 'Vitamin B12', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Manganese', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Lycopene', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Sugar', 'amount': 0.01, 'unit': 'g'},
#        {'name': 'Potassium', 'amount': 4.21, 'unit': 'mg'},
#        {'name': 'Folate', 'amount': 0.07, 'unit': 'µg'},
#        {'name': 'Vitamin K', 'amount': 0.02, 'unit': 'µg'},
#        {'name': 'Zinc', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Phosphorus', 'amount': 0.45, 'unit': 'mg'},
#        {'name': 'Iron', 'amount': 0.07, 'unit': 'mg'},
#        {'name': 'Vitamin B6', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Vitamin B3', 'amount': 0.01, 'unit': 'mg'},
#        {'name': 'Vitamin C', 'amount': 0.04, 'unit': 'mg'},
#        {'name': 'Cholesterol', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Magnesium', 'amount': 0.32, 'unit': 'mg'},
#        {'name': 'Choline', 'amount': 0.08, 'unit': 'mg'},
#        {'name': 'Vitamin D', 'amount': 0.0, 'unit': 'µg'},
#        {'name': 'Protein', 'amount': 0.01, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 0.59, 'unit': 'kcal'},
#        {'name': 'Sodium', 'amount': 0.06, 'unit': 'mg'},
#        {'name': 'Vitamin B1', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Poly Unsaturated Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Copper', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 0.31, 'unit': 'mg'},
#        {'name': 'Saturated Fat', 'amount': 0.01, 'unit': 'g'},
#        {'name': 'Vitamin A', 'amount': 0.0, 'unit': 'IU'},
#        {'name': 'Carbohydrates', 'amount': 0.11, 'unit': 'g'},
#        {'name': 'Selenium', 'amount': 0.01, 'unit': 'µg'},
#        {'name': 'Alcohol', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Caffeine', 'amount': 0.0, 'unit': 'mg'}]},
#      {'id': 14412,
#       'name': 'water',
#       'amount': 1.0,
#       'unit': 'servings',
#       'nutrients': [{'name': 'Magnesium', 'amount': 2.37, 'unit': 'mg'},
#        {'name': 'Fiber', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Net Carbohydrates', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Fat', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Protein', 'amount': 0.0, 'unit': 'g'},
#        {'name': 'Calories', 'amount': 0.0, 'unit': 'kcal'},
#        {'name': 'Manganese', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Sodium', 'amount': 11.83, 'unit': 'mg'},
#        {'name': 'Potassium', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Fluoride', 'amount': 61.04, 'unit': 'mg'},
#        {'name': 'Copper', 'amount': 0.04, 'unit': 'mg'},
#        {'name': 'Zinc', 'amount': 0.02, 'unit': 'mg'},
#        {'name': 'Calcium', 'amount': 7.1, 'unit': 'mg'},
#        {'name': 'Phosphorus', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Iron', 'amount': 0.0, 'unit': 'mg'},
#        {'name': 'Carbohydrates', 'amount': 0.0, 'unit': 'g'}]}],
#     'caloricBreakdown': {'percentProtein': 40.61,
#      'percentFat': 41.75,
#      'percentCarbs': 17.64},
#     'weightPerServing': {'amount': 441, 'unit': 'g'}},
#    'summary': 'Persian Rhubarb Stew (Khoresh Rivas) might be just the main course you are searching for. This gluten free and dairy free recipe serves 6 and costs <b>$1.49 per serving</b>. One serving contains <b>239 calories</b>, <b>24g of protein</b>, and <b>11g of fat</b>. A mixture of water, turmeric, onion, and a handful of other ingredients are all it takes to make this recipe so flavorful. To use up the salt and pepper you could follow this main course with the <a href="https://spoonacular.com/recipes/dr-pepper-cake-with-flour-cooked-frosting-539165">Dr. Pepper Cake with Flour Cooked Frosting</a> as a dessert. 4 people were impressed by this recipe. It can be enjoyed any time, but it is especially good for <b>Mother\'s Day</b>. From preparation to the plate, this recipe takes about <b>45 minutes</b>. All things considered, we decided this recipe <b>deserves a spoonacular score of 58%</b>. This score is pretty good. Try <a href="https://spoonacular.com/recipes/persian-chicken-stew-330791">Persian Chicken Stew</a>, <a href="https://spoonacular.com/recipes/persian-lamb-stew-15762">Persian Lamb Stew</a>, and <a href="https://spoonacular.com/recipes/persian-beef-and-split-pea-stew-33373">Persian Beef-and-Split-Pea Stew</a> for similar recipes.',
#    'cuisines': [],
#    'dishTypes': ['lunch', 'main course', 'main dish', 'dinner'],
#    'diets': ['gluten free', 'dairy free'],
#    'occasions': ['spring', "mother's day", 'fall', 'winter'],
#    'analyzedInstructions': [{'name': '',
#      'steps': [{'number': 1,
#        'step': 'In a pan, heat 2-3 tablespoons of oil and saute chopped onions until translucent.',
#        'ingredients': [{'id': 11282,
#          'name': 'onion',
#          'localizedName': 'onion',
#          'image': 'brown-onion.png'},
#         {'id': 4582,
#          'name': 'cooking oil',
#          'localizedName': 'cooking oil',
#          'image': 'vegetable-oil.jpg'}],
#        'equipment': [{'id': 404645,
#          'name': 'frying pan',
#          'localizedName': 'frying pan',
#          'image': 'pan.png'}]},
#       {'number': 2,
#        'step': 'Add turmeric, stir, add the meat and brown on all sides.',
#        'ingredients': [{'id': 2043,
#          'name': 'turmeric',
#          'localizedName': 'turmeric',
#          'image': 'turmeric.jpg'},
#         {'id': 1065062,
#          'name': 'meat',
#          'localizedName': 'meat',
#          'image': 'whole-chicken.jpg'}],
#        'equipment': []},
#       {'number': 3,
#        'step': 'Add salt and pepper to taste.',
#        'ingredients': [{'id': 1102047,
#          'name': 'salt and pepper',
#          'localizedName': 'salt and pepper',
#          'image': 'salt-and-pepper.jpg'}],
#        'equipment': []},
#       {'number': 4,
#        'step': 'Pour enough water to cover the meat. Cover and cook for an hour on medium to low heat, longer if it is not yet tender.In a medium-sized frying pan, saute the chopped parsley and mint together in 2 tablespoons of oil over medium heat.',
#        'ingredients': [{'id': 11297,
#          'name': 'parsley',
#          'localizedName': 'parsley',
#          'image': 'parsley.jpg'},
#         {'id': 14412,
#          'name': 'water',
#          'localizedName': 'water',
#          'image': 'water.png'},
#         {'id': 1065062,
#          'name': 'meat',
#          'localizedName': 'meat',
#          'image': 'whole-chicken.jpg'},
#         {'id': 2064,
#          'name': 'mint',
#          'localizedName': 'mint',
#          'image': 'mint.jpg'},
#         {'id': 4582,
#          'name': 'cooking oil',
#          'localizedName': 'cooking oil',
#          'image': 'vegetable-oil.jpg'}],
#        'equipment': [{'id': 404645,
#          'name': 'frying pan',
#          'localizedName': 'frying pan',
#          'image': 'pan.png'}]},
#       {'number': 5,
#        'step': 'Combine the parsley and mint mixture with the meat sauce half way through the cooking.',
#        'ingredients': [{'id': 11297,
#          'name': 'parsley',
#          'localizedName': 'parsley',
#          'image': 'parsley.jpg'},
#         {'id': 0, 'name': 'sauce', 'localizedName': 'sauce', 'image': ''},
#         {'id': 1065062,
#          'name': 'meat',
#          'localizedName': 'meat',
#          'image': 'whole-chicken.jpg'},
#         {'id': 2064,
#          'name': 'mint',
#          'localizedName': 'mint',
#          'image': 'mint.jpg'}],
#        'equipment': []},
#       {'number': 6,
#        'step': 'Add water if necessary.Lightly saute sliced rhubarbs in 2 tablespoons of olive oil for 2-3 minutes on medium heat.',
#        'ingredients': [{'id': 4053,
#          'name': 'olive oil',
#          'localizedName': 'olive oil',
#          'image': 'olive-oil.jpg'},
#         {'id': 14412,
#          'name': 'water',
#          'localizedName': 'water',
#          'image': 'water.png'}],
#        'equipment': [],
#        'length': {'number': 3, 'unit': 'minutes'}},
#       {'number': 7,
#        'step': 'Add the rhubarb to the pot, lower the heat to a gentle simmer and cook for an additional 15 minutes.Taste and add 2-3 tablespoons of sugar or to taste, gently stir and cook for an additional 5 minutes.',
#        'ingredients': [{'id': 9307,
#          'name': 'rhubarb',
#          'localizedName': 'rhubarb',
#          'image': 'rhubarb.jpg'},
#         {'id': 19335,
#          'name': 'sugar',
#          'localizedName': 'sugar',
#          'image': 'sugar-in-bowl.png'}],
#        'equipment': [{'id': 404752,
#          'name': 'pot',
#          'localizedName': 'pot',
#          'image': 'stock-pot.jpg'}],
#        'length': {'number': 20, 'unit': 'minutes'}},
#       {'number': 8,
#        'step': 'Serve warm with basmati rice.',
#        'ingredients': [{'id': 10020444,
#          'name': 'basmati rice',
#          'localizedName': 'basmati rice',
#          'image': 'rice-white-long-grain-or-basmatii-cooked.jpg'}],
#        'equipment': []}]}],
#    'spoonacularSourceUrl': 'https://spoonacular.com/persian-rhubarb-stew-khoresh-rivas-655771'}],
#  'offset': 0,
#  'number': 100,
#  'totalResults': 44}

# %%
recipe6_df=pd.json_normalize(new_res2,record_path=['results'])
recipe6_df
# Out:
#     vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0        False  False       False      False        False  False        False
# 1        False  False        True       True        False  False        False
# 2        False  False        True       True         True  False        False
# 3        False  False        True      False         True  False        False
# 4        False  False       False       True        False  False        False
# 5        False  False        True       True        False  False        False
# 6        False  False        True       True        False  False        False
# 7        False  False        True      False        False  False        False
# 8        False  False       False      False        False  False        False
# 9        False  False       False       True         True  False        False
# 10       False  False        True       True        False  False        False
# 11       False  False       False      False        False  False        False
# 12       False  False        True      False        False  False        False
# 13       False  False        True       True        False  False        False
# 14       False  False       False      False        False  False        False
# 15       False  False        True      False        False  False        False
# 16       False  False        True       True         True  False        False
# 17       False  False       False      False        False  False        False
# 18       False  False        True       True        False  False        False
# 19       False  False        True      False        False  False        False
# 20       False  False        True      False        False  False        False
# 21       False  False        True       True         True  False        False
# 22       False  False       False       True        False  False        False
# 23       False  False        True      False        False  False        False
# 24       False  False        True       True        False  False        False
# 25       False  False       False       True         True  False        False
# 26       False  False        True       True         True  False        False
# 27       False  False        True       True         True  False        False
# 28       False  False       False      False        False  False        False
# 29       False  False        True       True         True  False        False
# 30       False  False        True       True        False  False        False
# 31        True  False        True      False        False  False        False
# 32       False  False       False      False        False  False        False
# 33       False  False       False      False        False  False        False
# 34       False  False        True       True        False  False        False
# 35       False  False       False       True        False  False        False
# 36       False  False       False       True        False  False        False
# 37       False  False        True       True        False  False        False
# 38       False  False        True       True        False  False        False
# 39       False  False        True       True        False  False        False
# 40       False  False        True      False        False  False        False
# 41       False  False        True      False        False  False        False
# 42       False  False       False      False        False  False        False
# 43       False  False        True       True        False  False        False
#
#     sustainable  weightWatcherSmartPoints    gaps  ...  \
# 0         False                        27      no  ...
# 1         False                         2      no  ...
# 2         False                        27      no  ...
# 3         False                        15      no  ...
# 4         False                         8      no  ...
# 5         False                         6      no  ...
# 6         False                         9      no  ...
# 7         False                        22      no  ...
# 8         False                        34      no  ...
# 9         False                        16      no  ...
# 10        False                        23      no  ...
# 11        False                        19      no  ...
# 12        False                        12      no  ...
# 13        False                        11      no  ...
# 14        False                        26      no  ...
# 15        False                        18      no  ...
# 16        False                         7      no  ...
# 17        False                        20      no  ...
# 18        False                        16      no  ...
# 19        False                        13      no  ...
# 20        False                        18      no  ...
# 21        False                        27      no  ...
# 22        False                         7      no  ...
# 23        False                         7      no  ...
# 24        False                        32      no  ...
# 25        False                        11      no  ...
# 26        False                         8      no  ...
# 27        False                         7  GAPS_4  ...
# 28        False                        20      no  ...
# 29        False                         7      no  ...
# 30        False                        11      no  ...
# 31        False                        11      no  ...
# 32        False                        15      no  ...
# 33        False                        18      no  ...
# 34        False                        24      no  ...
# 35        False                        13      no  ...
# 36        False                        13      no  ...
# 37        False                        19      no  ...
# 38        False                        13      no  ...
# 39        False                        21      no  ...
# 40        False                        27      no  ...
# 41        False                        28      no  ...
# 42        False                        28      no  ...
# 43        False                         5      no  ...
#
#                                  nutrition.flavonoids  \
# 0   [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 1   [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 2   [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 3   [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 4   [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 5   [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 6   [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 7   [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 8   [{'name': 'Cyanidin', 'amount': 0.06, 'unit': ...
# 9   [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 10  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 11  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 12  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 13  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 14  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 15  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 16  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 17  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 18  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 19  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 20  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 21  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 22  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 23  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 24  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 25  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 26  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 27  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 28  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 29  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 30  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 31  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 32  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 33  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 34  [{'name': 'Cyanidin', 'amount': 1.43, 'unit': ...
# 35  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 36  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 37  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 38  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 39  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 40  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 41  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 42  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
# 43  [{'name': 'Cyanidin', 'amount': 0.0, 'unit': '...
#
#                                 nutrition.ingredients  \
# 0   [{'id': 20081, 'name': 'all purpose flour', 'a...
# 1   [{'id': 11819, 'name': 'chillies', 'amount': 0...
# 2   [{'id': 1002030, 'name': 'black pepper', 'amou...
# 3   [{'id': 2031, 'name': 'cayenne', 'amount': 1.0...
# 4   [{'id': 10123, 'name': 'bacon', 'amount': 0.5,...
# 5   [{'id': 10211821, 'name': 'bell pepper', 'amou...
# 6   [{'id': 98839, 'name': 'chipotle peppers', 'am...
# 7   [{'id': 1001, 'name': 'butter', 'amount': 6.25...
# 8   [{'id': 2004, 'name': 'bay leaf', 'amount': 0....
# 9   [{'id': 10011168, 'name': 'baby corn', 'amount...
# 10  [{'id': 12118, 'name': 'coconut milk', 'amount...
# 11  [{'id': 11206, 'name': 'cucumber', 'amount': 0...
# 12  [{'id': 1159, 'name': 'goat cheese', 'amount':...
# 13  [{'id': 1002014, 'name': 'cumin', 'amount': 1....
# 14  [{'id': 2015, 'name': 'curry powder', 'amount'...
# 15  [{'id': 4513, 'name': 'vegetable oil', 'amount...
# 16  [{'id': 17305, 'name': 'lamb chops', 'amount':...
# 17  [{'id': 17029, 'name': 'rack of lamb', 'amount...
# 18  [{'id': 11165, 'name': 'cilantro', 'amount': 0...
# 19  [{'id': 11353, 'name': 'baking potatoes', 'amo...
# 20  [{'id': 11209, 'name': 'eggplants', 'amount': ...
# 21  [{'id': 17224, 'name': 'ground lamb', 'amount'...
# 22  [{'id': 14003, 'name': 'beer', 'amount': 0.25,...
# 23  [{'id': 4582, 'name': 'cooking oil', 'amount':...
# 24  [{'id': 17023, 'name': 'lamb loin chops', 'amo...
# 25  [{'id': 17013, 'name': 'leg of lamb', 'amount'...
# 26  [{'id': 17013, 'name': 'leg of lamb', 'amount'...
# 27  [{'id': 17013, 'name': 'leg of lamb', 'amount'...
# 28  [{'id': 6170, 'name': 'beef stock', 'amount': ...
# 29  [{'id': 4581, 'name': 'avocado oil', 'amount':...
# 30  [{'id': 10123, 'name': 'bacon strips', 'amount...
# 31  [{'id': 99237, 'name': 'moong dal', 'amount': ...
# 32  [{'id': 1002046, 'name': 'dijon mustard', 'amo...
# 33  [{'id': 20012, 'name': 'bulgur wheat', 'amount...
# 34  [{'id': 11282, 'name': 'onion', 'amount': 0.25...
# 35  [{'id': 18079, 'name': 'bread crumbs', 'amount...
# 36  [{'id': 98940, 'name': 'sub rolls', 'amount': ...
# 37  [{'id': 10017224, 'name': 'lamb', 'amount': 0....
# 38  [{'id': 1002006, 'name': 'cardamon pods', 'amo...
# 39  [{'id': 10017224, 'name': 'lamb', 'amount': 10...
# 40  [{'id': 1032035, 'name': 'asafetida', 'amount'...
# 41  [{'id': 11352, 'name': 'potatoes', 'amount': 2...
# 42  [{'id': 11282, 'name': 'onions', 'amount': 0.5...
# 43  [{'id': 17059, 'name': 'lamb stew meat', 'amou...
#
#     nutrition.caloricBreakdown.percentProtein  \
# 0                                       41.95
# 1                                       50.39
# 2                                       21.18
# 3                                       18.27
# 4                                       14.27
# 5                                       35.91
# 6                                        4.90
# 7                                       19.17
# 8                                        8.85
# 9                                       22.13
# 10                                      17.98
# 11                                      24.69
# 12                                      17.90
# 13                                      48.55
# 14                                      27.24
# 15                                      16.60
# 16                                      52.38
# 17                                      14.31
# 18                                      16.53
# 19                                      48.36
# 20                                      27.30
# 21                                      18.77
# 22                                      57.23
# 23                                      53.15
# 24                                      17.22
# 25                                      27.29
# 26                                      53.42
# 27                                      62.91
# 28                                      18.39
# 29                                      39.86
# 30                                       8.35
# 31                                      17.91
# 32                                      17.89
# 33                                      21.44
# 34                                      24.25
# 35                                      29.67
# 36                                      28.24
# 37                                      18.09
# 38                                      13.29
# 39                                      12.97
# 40                                      24.21
# 41                                      15.08
# 42                                      15.26
# 43                                      40.61
#
#     nutrition.caloricBreakdown.percentFat  \
# 0                                   39.05
# 1                                   41.96
# 2                                   69.65
# 3                                   30.73
# 4                                   23.09
# 5                                   29.15
# 6                                   66.89
# 7                                   60.10
# 8                                   61.27
# 9                                   34.81
# 10                                  75.60
# 11                                  54.46
# 12                                  80.89
# 13                                  44.92
# 14                                  54.68
# 15                                  59.23
# 16                                  32.36
# 17                                  82.14
# 18                                  78.12
# 19                                  38.84
# 20                                  55.47
# 21                                  71.65
# 22                                  21.20
# 23                                  43.11
# 24                                  76.83
# 25                                  21.92
# 26                                  43.69
# 27                                  35.27
# 28                                  58.36
# 29                                  25.15
# 30                                  84.81
# 31                                  32.72
# 32                                  41.32
# 33                                  63.24
# 34                                  49.07
# 35                                  43.49
# 36                                  23.43
# 37                                  79.24
# 38                                  62.13
# 39                                  71.14
# 40                                  71.60
# 41                                  56.71
# 42                                  65.01
# 43                                  41.75
#
#    nutrition.caloricBreakdown.percentCarbs nutrition.weightPerServing.amount  \
# 0                                    19.00                               682
# 1                                     7.65                                98
# 2                                     9.17                               667
# 3                                    51.00                               832
# 4                                    62.64                               381
# 5                                    34.94                               426
# 6                                    28.21                               278
# 7                                    20.73                               482
# 8                                    29.88                               362
# 9                                    43.06                               415
# 10                                    6.42                               379
# 11                                   20.85                               396
# 12                                    1.21                               126
# 13                                    6.53                               299
# 14                                   18.08                               402
# 15                                   24.17                               239
# 16                                   15.26                               326
# 17                                    3.55                               149
# 18                                    5.35                               173
# 19                                   12.80                               511
# 20                                   17.23                               575
# 21                                    9.58                               648
# 22                                   21.57                               377
# 23                                    3.74                               258
# 24                                    5.95                               297
# 25                                   50.79                               857
# 26                                    2.89                               384
# 27                                    1.82                               309
# 28                                   23.25                               412
# 29                                   34.99                               520
# 30                                    6.84                               155
# 31                                   49.37                               177
# 32                                   40.79                               270
# 33                                   15.32                               278
# 34                                   26.68                              1002
# 35                                   26.84                               368
# 36                                   48.33                               175
# 37                                    2.67                               218
# 38                                   24.58                               252
# 39                                   15.89                               315
# 40                                    4.19                               514
# 41                                   28.21                               678
# 42                                   19.73                               476
# 43                                   17.64                               441
#
#    nutrition.weightPerServing.unit         author  preparationMinutes  \
# 0                                g            NaN                 NaN
# 1                                g            NaN                 NaN
# 2                                g            NaN                 NaN
# 3                                g            NaN                 NaN
# 4                                g            NaN                 NaN
# 5                                g            NaN                 NaN
# 6                                g            NaN                 NaN
# 7                                g       marioziv                 NaN
# 8                                g            NaN                 NaN
# 9                                g            NaN                 NaN
# 10                               g            NaN                 NaN
# 11                               g            NaN                 NaN
# 12                               g            NaN                 NaN
# 13                               g            NaN                 NaN
# 14                               g            NaN                 NaN
# 15                               g            NaN                 NaN
# 16                               g            NaN                 NaN
# 17                               g            NaN                 NaN
# 18                               g            NaN                 NaN
# 19                               g            NaN                 NaN
# 20                               g            NaN                 NaN
# 21                               g            NaN                 NaN
# 22                               g            NaN                 NaN
# 23                               g            NaN                 NaN
# 24                               g            NaN                 NaN
# 25                               g            NaN                 NaN
# 26                               g  maplewoodroad                 NaN
# 27                               g            NaN                 NaN
# 28                               g            NaN                 NaN
# 29                               g            NaN                10.0
# 30                               g            NaN                 NaN
# 31                               g            NaN                 NaN
# 32                               g            NaN                 NaN
# 33                               g            NaN                 NaN
# 34                               g            NaN                 NaN
# 35                               g            NaN                 NaN
# 36                               g            NaN                 NaN
# 37                               g            NaN                 NaN
# 38                               g            NaN                 NaN
# 39                               g            NaN                 NaN
# 40                               g            NaN                 NaN
# 41                               g            NaN                 NaN
# 42                               g            NaN                 NaN
# 43                               g            NaN                 NaN
#
#    cookingMinutes
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN
# 28            NaN
# 29           30.0
# 30            NaN
# 31            NaN
# 32            NaN
# 33            NaN
# 34            NaN
# 35            NaN
# 36            NaN
# 37            NaN
# 38            NaN
# 39            NaN
# 40            NaN
# 41            NaN
# 42            NaN
# 43            NaN
#
# [44 rows x 44 columns]

# %%
recipe6_df.drop(columns=['vegetarian', 'vegan', 'glutenFree', 'dairyFree', 'veryHealthy', 'cheap', 'veryPopular', 'sustainable', 'weightWatcherSmartPoints', 'gaps', 'lowFodmap', 'aggregateLikes', 'spoonacularScore',
                      'healthScore', 'creditsText', 'license', 'sourceName', 'pricePerServing','sourceUrl','imageType','summary','diets', 'occasions','spoonacularSourceUrl','nutrition.properties','nutrition.flavonoids','nutrition.caloricBreakdown.percentProtein','nutrition.caloricBreakdown.percentFat','nutrition.caloricBreakdown.percentCarbs','nutrition.weightPerServing.amount',
                      'nutrition.weightPerServing.unit','preparationMinutes','cookingMinutes','author','nutrition.nutrients','nutrition.ingredients'],inplace=True)
recipe6_df
# Out:
#          id                                              title  \
# 0    649225                                      Lamb Moussaka
# 1    649196                                      Lamb Chop Fry
# 2    649248                                   Lamb Tagine Stew
# 3    649199                                  Lamb Chops Masala
# 4    649182                             Lamb and Bacon Burgers
# 5    649186                             Lamb and Mushroom Stew
# 6    649214                             Lamb In Red Mole Sauce
# 7    157834                           LAMB AND KIDNEY HOT- POT
# 8    649178                        Lamb & Sweet Potato Pot Pie
# 9    649187                      Lamb and Rice Noodle Stir Fry
# 10   716338                    Lamb Coconut Tomato Curry Sauce
# 11   649195                   Lamb Burgers With Tzatziki Sauce
# 12   649183                 Lamb and Fresh Goat Cheese Roulade
# 13   651180                                  Masala Lamb Chops
# 14   660961  Spiced Lamb Meatballs With Lemon Mint Yogurt S...
# 15   641079                                 Curried Lamb Tarts
# 16   635834                                 Braised Lamb Chops
# 17   657710                          Rack of Lamb With Parsley
# 18   654432  Pan Seared Lamb Loin With Chimichurri & Roaste...
# 19   660290                             Slow Cooker Lamb Curry
# 20   644889                          Gluten-Free Lamb Moussaka
# 21  1096265                    Slow Cooker Lamb Beet Meatballs
# 22   632901                          Asian-Braised Lamb Shanks
# 23   665550                      Yogurt Marinated Lamb Skewers
# 24   633932                      Balsamic Marinated Lamb Chops
# 25  1098301  Slow Braised Red Wine Lamb Stew with Moroccan ...
# 26  1697565                      Grilled Marinated Leg of Lamb
# 27   641973  Easy Garlic Roast Leg Of Lamb With Rosemary an...
# 28   642091       Easy Shepherd's Pie (Beef And/or Lamb Combo)
# 29  1052360  The Secret to the Best Ever Instant Pot Lamb Stew
# 30   649254                Lamb’s Lettuce & Crispy Bacon Salad
# 31   654313      Pachai Payaru Kulambu (Green Moong Dal Curry)
# 32   646071                                              Gyros
# 33   649403                                    Lebanese Kibbeh
# 34    57810                                   Choucroute Garni
# 35   637275                                   Cassoulet for 10
# 36   664828                                 Vietnamese Banh Mi
# 37   651076                                 Marinated Souvlaki
# 38   651914                                Minced Mutton Curry
# 39   663121                                Thai Massaman Curry
# 40   648774                                Kashmiri Rogan Josh
# 41  1095880                                Easy Shepherd’s Pie
# 42   636096                     Bridget Jones's Shepherd's Pie
# 43   655771               Persian Rhubarb Stew (Khoresh Rivas)
#
#     readyInMinutes  servings  \
# 0               45        12
# 1               45        10
# 2               45         4
# 3               45         1
# 4               45         6
# 5               45         6
# 6               45         4
# 7               90         4
# 8               45         8
# 9               45         4
# 10              45         3
# 11              45         4
# 12              45         6
# 13              45         2
# 14              45         4
# 15              45         6
# 16              45         4
# 17              45         4
# 18              45         4
# 19              45         8
# 20              45         4
# 21             210         2
# 22              45         4
# 23              45        12
# 24              45         2
# 25             155         4
# 26              45         4
# 27              45         8
# 28              45         6
# 29              40         8
# 30              45         2
# 31              45         4
# 32              45         6
# 33              45         6
# 34              45         4
# 35              45        10
# 36              45         6
# 37              45         6
# 38              45         4
# 39              45         5
# 40              45         6
# 41              75         4
# 42              45         4
# 43              45         6
#
#                                                 image  \
# 0   https://spoonacular.com/recipeImages/649225-31...
# 1   https://spoonacular.com/recipeImages/649196-31...
# 2   https://spoonacular.com/recipeImages/649248-31...
# 3   https://spoonacular.com/recipeImages/649199-31...
# 4   https://spoonacular.com/recipeImages/649182-31...
# 5   https://spoonacular.com/recipeImages/649186-31...
# 6   https://spoonacular.com/recipeImages/649214-31...
# 7   https://spoonacular.com/recipeImages/157834-31...
# 8   https://spoonacular.com/recipeImages/649178-31...
# 9   https://spoonacular.com/recipeImages/649187-31...
# 10  https://spoonacular.com/recipeImages/716338-31...
# 11  https://spoonacular.com/recipeImages/649195-31...
# 12  https://spoonacular.com/recipeImages/649183-31...
# 13  https://spoonacular.com/recipeImages/651180-31...
# 14  https://spoonacular.com/recipeImages/660961-31...
# 15  https://spoonacular.com/recipeImages/641079-31...
# 16  https://spoonacular.com/recipeImages/635834-31...
# 17  https://spoonacular.com/recipeImages/657710-31...
# 18  https://spoonacular.com/recipeImages/654432-31...
# 19  https://spoonacular.com/recipeImages/660290-31...
# 20  https://spoonacular.com/recipeImages/644889-31...
# 21  https://spoonacular.com/recipeImages/1096265-3...
# 22  https://spoonacular.com/recipeImages/632901-31...
# 23  https://spoonacular.com/recipeImages/665550-31...
# 24  https://spoonacular.com/recipeImages/633932-31...
# 25  https://spoonacular.com/recipeImages/1098301-3...
# 26  https://spoonacular.com/recipeImages/1697565-3...
# 27  https://spoonacular.com/recipeImages/641973-31...
# 28  https://spoonacular.com/recipeImages/642091-31...
# 29  https://spoonacular.com/recipeImages/1052360-3...
# 30  https://spoonacular.com/recipeImages/649254-31...
# 31  https://spoonacular.com/recipeImages/654313-31...
# 32  https://spoonacular.com/recipeImages/646071-31...
# 33  https://spoonacular.com/recipeImages/649403-31...
# 34  https://spoonacular.com/recipeImages/57810-312...
# 35  https://spoonacular.com/recipeImages/637275-31...
# 36  https://spoonacular.com/recipeImages/664828-31...
# 37  https://spoonacular.com/recipeImages/651076-31...
# 38  https://spoonacular.com/recipeImages/651914-31...
# 39  https://spoonacular.com/recipeImages/663121-31...
# 40  https://spoonacular.com/recipeImages/648774-31...
# 41  https://spoonacular.com/recipeImages/1095880-3...
# 42  https://spoonacular.com/recipeImages/636096-31...
# 43  https://spoonacular.com/recipeImages/655771-31...
#
#                             cuisines  \
# 0   [Mediterranean, European, Greek]
# 1                                 []
# 2                                 []
# 3                    [Indian, Asian]
# 4                         [American]
# 5                                 []
# 6                                 []
# 7                                 []
# 8                                 []
# 9                                 []
# 10                   [Indian, Asian]
# 11  [Mediterranean, European, Greek]
# 12                [German, European]
# 13                   [Indian, Asian]
# 14                                []
# 15                                []
# 16                                []
# 17                                []
# 18  [South American, Latin American]
# 19                   [Indian, Asian]
# 20  [Mediterranean, European, Greek]
# 21                                []
# 22                                []
# 23                                []
# 24                                []
# 25                                []
# 26                                []
# 27                                []
# 28                 [European, Irish]
# 29                                []
# 30                                []
# 31                   [Indian, Asian]
# 32  [Mediterranean, European, Greek]
# 33                  [Middle Eastern]
# 34                                []
# 35                                []
# 36               [Vietnamese, Asian]
# 37  [Mediterranean, European, Greek]
# 38                   [Indian, Asian]
# 39                     [Thai, Asian]
# 40                   [Indian, Asian]
# 41                                []
# 42                 [European, Irish]
# 43                                []
#
#                                         dishTypes  \
# 0         [lunch, main course, main dish, dinner]
# 1         [lunch, main course, main dish, dinner]
# 2         [lunch, main course, main dish, dinner]
# 3         [lunch, main course, main dish, dinner]
# 4                                     [side dish]
# 5         [lunch, main course, main dish, dinner]
# 6                                         [sauce]
# 7         [lunch, main course, main dish, dinner]
# 8         [lunch, main course, main dish, dinner]
# 9         [lunch, main course, main dish, dinner]
# 10                                        [sauce]
# 11        [lunch, main course, main dish, dinner]
# 12        [lunch, main course, main dish, dinner]
# 13        [lunch, main course, main dish, dinner]
# 14        [lunch, main course, main dish, dinner]
# 15                                             []
# 16        [lunch, main course, main dish, dinner]
# 17                                             []
# 18        [lunch, main course, main dish, dinner]
# 19        [lunch, main course, main dish, dinner]
# 20        [lunch, main course, main dish, dinner]
# 21        [lunch, main course, main dish, dinner]
# 22        [lunch, main course, main dish, dinner]
# 23        [lunch, main course, main dish, dinner]
# 24                                             []
# 25  [soup, lunch, main course, main dish, dinner]
# 26                                             []
# 27                                             []
# 28        [lunch, main course, main dish, dinner]
# 29        [lunch, main course, main dish, dinner]
# 30                                        [salad]
# 31        [lunch, main course, main dish, dinner]
# 32        [lunch, main course, main dish, dinner]
# 33                                             []
# 34        [lunch, main course, main dish, dinner]
# 35        [lunch, main course, main dish, dinner]
# 36        [lunch, main course, main dish, dinner]
# 37        [lunch, main course, main dish, dinner]
# 38                                    [side dish]
# 39        [lunch, main course, main dish, dinner]
# 40        [lunch, main course, main dish, dinner]
# 41                                             []
# 42        [lunch, main course, main dish, dinner]
# 43        [lunch, main course, main dish, dinner]
#
#                                  analyzedInstructions
# 0   [{'name': '', 'steps': [{'number': 1, 'step': ...
# 1   [{'name': '', 'steps': [{'number': 1, 'step': ...
# 2   [{'name': '', 'steps': [{'number': 1, 'step': ...
# 3   [{'name': '', 'steps': [{'number': 1, 'step': ...
# 4   [{'name': '', 'steps': [{'number': 1, 'step': ...
# 5   [{'name': '', 'steps': [{'number': 1, 'step': ...
# 6   [{'name': '', 'steps': [{'number': 1, 'step': ...
# 7   [{'name': '', 'steps': [{'number': 1, 'step': ...
# 8   [{'name': '', 'steps': [{'number': 1, 'step': ...
# 9   [{'name': '', 'steps': [{'number': 1, 'step': ...
# 10  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 11  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 12  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 13  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 14  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 15  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 16  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 17  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 18  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 19  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 20  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 21  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 22  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 23  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 24  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 25  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 26  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 27  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 28  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 29  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 30  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 31  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 32  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 33  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 34  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 35  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 36  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 37  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 38  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 39  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 40  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 41  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 42  [{'name': '', 'steps': [{'number': 1, 'step': ...
# 43  [{'name': '', 'steps': [{'number': 1, 'step': ...

# %% [markdown]
# # One hot encoding dishType column

# %%
recipe6_df['dish']=0
recipe6_df.columns
# Out:
# Index(['id', 'title', 'readyInMinutes', 'servings', 'image', 'cuisines',
#        'dishTypes', 'analyzedInstructions', 'dish'],
#       dtype='object')

# %%
for i in range(0,44):
    item =recipe6_df['dishTypes'][i]
    if len(item)==0:
        recipe6_df.iloc[i,8]=0
        
    else:
        #print(item[0])
        
        if any(x in ['lunch', 'dinner', 'antipasti','side dish','salad'] for x in item):
            #print(f"{i}:lunch")
            recipe6_df.iloc[i,8]=1
        if any(x in ['breakfast', 'bread'] for x in item):
            recipe6_df.iloc[i,8]=0
recipe6_df
# Out:
#          id                                              title  \
# 0    649225                                      Lamb Moussaka
# 1    649196                                      Lamb Chop Fry
# 2    649248                                   Lamb Tagine Stew
# 3    649199                                  Lamb Chops Masala
# 4    649182                             Lamb and Bacon Burgers
# 5    649186                             Lamb and Mushroom Stew
# 6    649214                             Lamb In Red Mole Sauce
# 7    157834                           LAMB AND KIDNEY HOT- POT
# 8    649178                        Lamb & Sweet Potato Pot Pie
# 9    649187                      Lamb and Rice Noodle Stir Fry
# 10   716338                    Lamb Coconut Tomato Curry Sauce
# 11   649195                   Lamb Burgers With Tzatziki Sauce
# 12   649183                 Lamb and Fresh Goat Cheese Roulade
# 13   651180                                  Masala Lamb Chops
# 14   660961  Spiced Lamb Meatballs With Lemon Mint Yogurt S...
# 15   641079                                 Curried Lamb Tarts
# 16   635834                                 Braised Lamb Chops
# 17   657710                          Rack of Lamb With Parsley
# 18   654432  Pan Seared Lamb Loin With Chimichurri & Roaste...
# 19   660290                             Slow Cooker Lamb Curry
# 20   644889                          Gluten-Free Lamb Moussaka
# 21  1096265                    Slow Cooker Lamb Beet Meatballs
# 22   632901                          Asian-Braised Lamb Shanks
# 23   665550                      Yogurt Marinated Lamb Skewers
# 24   633932                      Balsamic Marinated Lamb Chops
# 25  1098301  Slow Braised Red Wine Lamb Stew with Moroccan ...
# 26  1697565                      Grilled Marinated Leg of Lamb
# 27   641973  Easy Garlic Roast Leg Of Lamb With Rosemary an...
# 28   642091       Easy Shepherd's Pie (Beef And/or Lamb Combo)
# 29  1052360  The Secret to the Best Ever Instant Pot Lamb Stew
# 30   649254                Lamb’s Lettuce & Crispy Bacon Salad
# 31   654313      Pachai Payaru Kulambu (Green Moong Dal Curry)
# 32   646071                                              Gyros
# 33   649403                                    Lebanese Kibbeh
# 34    57810                                   Choucroute Garni
# 35   637275                                   Cassoulet for 10
# 36   664828                                 Vietnamese Banh Mi
# 37   651076                                 Marinated Souvlaki
# 38   651914                                Minced Mutton Curry
# 39   663121                                Thai Massaman Curry
# 40   648774                                Kashmiri Rogan Josh
# 41  1095880                                Easy Shepherd’s Pie
# 42   636096                     Bridget Jones's Shepherd's Pie
# 43   655771               Persian Rhubarb Stew (Khoresh Rivas)
#
#     readyInMinutes  servings  \
# 0               45        12
# 1               45        10
# 2               45         4
# 3               45         1
# 4               45         6
# 5               45         6
# 6               45         4
# 7               90         4
# 8               45         8
# 9               45         4
# 10              45         3
# 11              45         4
# 12              45         6
# 13              45         2
# 14              45         4
# 15              45         6
# 16              45         4
# 17              45         4
# 18              45         4
# 19              45         8
# 20              45         4
# 21             210         2
# 22              45         4
# 23              45        12
# 24              45         2
# 25             155         4
# 26              45         4
# 27              45         8
# 28              45         6
# 29              40         8
# 30              45         2
# 31              45         4
# 32              45         6
# 33              45         6
# 34              45         4
# 35              45        10
# 36              45         6
# 37              45         6
# 38              45         4
# 39              45         5
# 40              45         6
# 41              75         4
# 42              45         4
# 43              45         6
#
#                                                 image  \
# 0   https://spoonacular.com/recipeImages/649225-31...
# 1   https://spoonacular.com/recipeImages/649196-31...
# 2   https://spoonacular.com/recipeImages/649248-31...
# 3   https://spoonacular.com/recipeImages/649199-31...
# 4   https://spoonacular.com/recipeImages/649182-31...
# 5   https://spoonacular.com/recipeImages/649186-31...
# 6   https://spoonacular.com/recipeImages/649214-31...
# 7   https://spoonacular.com/recipeImages/157834-31...
# 8   https://spoonacular.com/recipeImages/649178-31...
# 9   https://spoonacular.com/recipeImages/649187-31...
# 10  https://spoonacular.com/recipeImages/716338-31...
# 11  https://spoonacular.com/recipeImages/649195-31...
# 12  https://spoonacular.com/recipeImages/649183-31...
# 13  https://spoonacular.com/recipeImages/651180-31...
# 14  https://spoonacular.com/recipeImages/660961-31...
# 15  https://spoonacular.com/recipeImages/641079-31...
# 16  https://spoonacular.com/recipeImages/635834-31...
# 17  https://spoonacular.com/recipeImages/657710-31...
# 18  https://spoonacular.com/recipeImages/654432-31...
# 19  https://spoonacular.com/recipeImages/660290-31...
# 20  https://spoonacular.com/recipeImages/644889-31...
# 21  https://spoonacular.com/recipeImages/1096265-3...
# 22  https://spoonacular.com/recipeImages/632901-31...
# 23  https://spoonacular.com/recipeImages/665550-31...
# 24  https://spoonacular.com/recipeImages/633932-31...
# 25  https://spoonacular.com/recipeImages/1098301-3...
# 26  https://spoonacular.com/recipeImages/1697565-3...
# 27  https://spoonacular.com/recipeImages/641973-31...
# 28  https://spoonacular.com/recipeImages/642091-31...
# 29  https://spoonacular.com/recipeImages/1052360-3...
# 30  https://spoonacular.com/recipeImages/649254-31...
# 31  https://spoonacular.com/recipeImages/654313-31...
# 32  https://spoonacular.com/recipeImages/646071-31...
# 33  https://spoonacular.com/recipeImages/649403-31...
# 34  https://spoonacular.com/recipeImages/57810-312...
# 35  https://spoonacular.com/recipeImages/637275-31...
# 36  https://spoonacular.com/recipeImages/664828-31...
# 37  https://spoonacular.com/recipeImages/651076-31...
# 38  https://spoonacular.com/recipeImages/651914-31...
# 39  https://spoonacular.com/recipeImages/663121-31...
# 40  https://spoonacular.com/recipeImages/648774-31...
# 41  https://spoonacular.com/recipeImages/1095880-3...
# 42  https://spoonacular.com/recipeImages/636096-31...
# 43  https://spoonacular.com/recipeImages/655771-31...
#
#                             cuisines  \
# 0   [Mediterranean, European, Greek]
# 1                                 []
# 2                                 []
# 3                    [Indian, Asian]
# 4                         [American]
# 5                                 []
# 6                                 []
# 7                                 []
# 8                                 []
# 9                                 []
# 10                   [Indian, Asian]
# 11  [Mediterranean, European, Greek]
# 12                [German, European]
# 13                   [Indian, Asian]
# 14                                []
# 15                                []
# 16                                []
# 17                                []
# 18  [South American, Latin American]
# 19                   [Indian, Asian]
# 20  [Mediterranean, European, Greek]
# 21                                []
# 22                                []
# 23                                []
# 24                                []
# 25                                []
# 26                                []
# 27                                []
# 28                 [European, Irish]
# 29                                []
# 30                                []
# 31                   [Indian, Asian]
# 32  [Mediterranean, European, Greek]
# 33                  [Middle Eastern]
# 34                                []
# 35                                []
# 36               [Vietnamese, Asian]
# 37  [Mediterranean, European, Greek]
# 38                   [Indian, Asian]
# 39                     [Thai, Asian]
# 40                   [Indian, Asian]
# 41                                []
# 42                 [European, Irish]
# 43                                []
#
#                                         dishTypes  \
# 0         [lunch, main course, main dish, dinner]
# 1         [lunch, main course, main dish, dinner]
# 2         [lunch, main course, main dish, dinner]
# 3         [lunch, main course, main dish, dinner]
# 4                                     [side dish]
# 5         [lunch, main course, main dish, dinner]
# 6                                         [sauce]
# 7         [lunch, main course, main dish, dinner]
# 8         [lunch, main course, main dish, dinner]
# 9         [lunch, main course, main dish, dinner]
# 10                                        [sauce]
# 11        [lunch, main course, main dish, dinner]
# 12        [lunch, main course, main dish, dinner]
# 13        [lunch, main course, main dish, dinner]
# 14        [lunch, main course, main dish, dinner]
# 15                                             []
# 16        [lunch, main course, main dish, dinner]
# 17                                             []
# 18        [lunch, main course, main dish, dinner]
# 19        [lunch, main course, main dish, dinner]
# 20        [lunch, main course, main dish, dinner]
# 21        [lunch, main course, main dish, dinner]
# 22        [lunch, main course, main dish, dinner]
# 23        [lunch, main course, main dish, dinner]
# 24                                             []
# 25  [soup, lunch, main course, main dish, dinner]
# 26                                             []
# 27                                             []
# 28        [lunch, main course, main dish, dinner]
# 29        [lunch, main course, main dish, dinner]
# 30                                        [salad]
# 31        [lunch, main course, main dish, dinner]
# 32        [lunch, main course, main dish, dinner]
# 33                                             []
# 34        [lunch, main course, main dish, dinner]
# 35        [lunch, main course, main dish, dinner]
# 36        [lunch, main course, main dish, dinner]
# 37        [lunch, main course, main dish, dinner]
# 38                                    [side dish]
# 39        [lunch, main course, main dish, dinner]
# 40        [lunch, main course, main dish, dinner]
# 41                                             []
# 42        [lunch, main course, main dish, dinner]
# 43        [lunch, main course, main dish, dinner]
#
#                                  analyzedInstructions  dish
# 0   [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 1   [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 2   [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 3   [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 4   [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 5   [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 6   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 7   [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 8   [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 9   [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 10  [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 11  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 12  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 13  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 14  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 15  [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 16  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 17  [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 18  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 19  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 20  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 21  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 22  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 23  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 24  [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 25  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 26  [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 27  [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 28  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 29  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 30  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 31  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 32  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 33  [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 34  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 35  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 36  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 37  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 38  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 39  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 40  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 41  [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 42  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 43  [{'name': '', 'steps': [{'number': 1, 'step': ...     1

# %%
recipe6_df.drop(columns=['dishTypes'],inplace=True)
recipe6_df
# Out:
#          id                                              title  \
# 0    649225                                      Lamb Moussaka
# 1    649196                                      Lamb Chop Fry
# 2    649248                                   Lamb Tagine Stew
# 3    649199                                  Lamb Chops Masala
# 4    649182                             Lamb and Bacon Burgers
# 5    649186                             Lamb and Mushroom Stew
# 6    649214                             Lamb In Red Mole Sauce
# 7    157834                           LAMB AND KIDNEY HOT- POT
# 8    649178                        Lamb & Sweet Potato Pot Pie
# 9    649187                      Lamb and Rice Noodle Stir Fry
# 10   716338                    Lamb Coconut Tomato Curry Sauce
# 11   649195                   Lamb Burgers With Tzatziki Sauce
# 12   649183                 Lamb and Fresh Goat Cheese Roulade
# 13   651180                                  Masala Lamb Chops
# 14   660961  Spiced Lamb Meatballs With Lemon Mint Yogurt S...
# 15   641079                                 Curried Lamb Tarts
# 16   635834                                 Braised Lamb Chops
# 17   657710                          Rack of Lamb With Parsley
# 18   654432  Pan Seared Lamb Loin With Chimichurri & Roaste...
# 19   660290                             Slow Cooker Lamb Curry
# 20   644889                          Gluten-Free Lamb Moussaka
# 21  1096265                    Slow Cooker Lamb Beet Meatballs
# 22   632901                          Asian-Braised Lamb Shanks
# 23   665550                      Yogurt Marinated Lamb Skewers
# 24   633932                      Balsamic Marinated Lamb Chops
# 25  1098301  Slow Braised Red Wine Lamb Stew with Moroccan ...
# 26  1697565                      Grilled Marinated Leg of Lamb
# 27   641973  Easy Garlic Roast Leg Of Lamb With Rosemary an...
# 28   642091       Easy Shepherd's Pie (Beef And/or Lamb Combo)
# 29  1052360  The Secret to the Best Ever Instant Pot Lamb Stew
# 30   649254                Lamb’s Lettuce & Crispy Bacon Salad
# 31   654313      Pachai Payaru Kulambu (Green Moong Dal Curry)
# 32   646071                                              Gyros
# 33   649403                                    Lebanese Kibbeh
# 34    57810                                   Choucroute Garni
# 35   637275                                   Cassoulet for 10
# 36   664828                                 Vietnamese Banh Mi
# 37   651076                                 Marinated Souvlaki
# 38   651914                                Minced Mutton Curry
# 39   663121                                Thai Massaman Curry
# 40   648774                                Kashmiri Rogan Josh
# 41  1095880                                Easy Shepherd’s Pie
# 42   636096                     Bridget Jones's Shepherd's Pie
# 43   655771               Persian Rhubarb Stew (Khoresh Rivas)
#
#     readyInMinutes  servings  \
# 0               45        12
# 1               45        10
# 2               45         4
# 3               45         1
# 4               45         6
# 5               45         6
# 6               45         4
# 7               90         4
# 8               45         8
# 9               45         4
# 10              45         3
# 11              45         4
# 12              45         6
# 13              45         2
# 14              45         4
# 15              45         6
# 16              45         4
# 17              45         4
# 18              45         4
# 19              45         8
# 20              45         4
# 21             210         2
# 22              45         4
# 23              45        12
# 24              45         2
# 25             155         4
# 26              45         4
# 27              45         8
# 28              45         6
# 29              40         8
# 30              45         2
# 31              45         4
# 32              45         6
# 33              45         6
# 34              45         4
# 35              45        10
# 36              45         6
# 37              45         6
# 38              45         4
# 39              45         5
# 40              45         6
# 41              75         4
# 42              45         4
# 43              45         6
#
#                                                 image  \
# 0   https://spoonacular.com/recipeImages/649225-31...
# 1   https://spoonacular.com/recipeImages/649196-31...
# 2   https://spoonacular.com/recipeImages/649248-31...
# 3   https://spoonacular.com/recipeImages/649199-31...
# 4   https://spoonacular.com/recipeImages/649182-31...
# 5   https://spoonacular.com/recipeImages/649186-31...
# 6   https://spoonacular.com/recipeImages/649214-31...
# 7   https://spoonacular.com/recipeImages/157834-31...
# 8   https://spoonacular.com/recipeImages/649178-31...
# 9   https://spoonacular.com/recipeImages/649187-31...
# 10  https://spoonacular.com/recipeImages/716338-31...
# 11  https://spoonacular.com/recipeImages/649195-31...
# 12  https://spoonacular.com/recipeImages/649183-31...
# 13  https://spoonacular.com/recipeImages/651180-31...
# 14  https://spoonacular.com/recipeImages/660961-31...
# 15  https://spoonacular.com/recipeImages/641079-31...
# 16  https://spoonacular.com/recipeImages/635834-31...
# 17  https://spoonacular.com/recipeImages/657710-31...
# 18  https://spoonacular.com/recipeImages/654432-31...
# 19  https://spoonacular.com/recipeImages/660290-31...
# 20  https://spoonacular.com/recipeImages/644889-31...
# 21  https://spoonacular.com/recipeImages/1096265-3...
# 22  https://spoonacular.com/recipeImages/632901-31...
# 23  https://spoonacular.com/recipeImages/665550-31...
# 24  https://spoonacular.com/recipeImages/633932-31...
# 25  https://spoonacular.com/recipeImages/1098301-3...
# 26  https://spoonacular.com/recipeImages/1697565-3...
# 27  https://spoonacular.com/recipeImages/641973-31...
# 28  https://spoonacular.com/recipeImages/642091-31...
# 29  https://spoonacular.com/recipeImages/1052360-3...
# 30  https://spoonacular.com/recipeImages/649254-31...
# 31  https://spoonacular.com/recipeImages/654313-31...
# 32  https://spoonacular.com/recipeImages/646071-31...
# 33  https://spoonacular.com/recipeImages/649403-31...
# 34  https://spoonacular.com/recipeImages/57810-312...
# 35  https://spoonacular.com/recipeImages/637275-31...
# 36  https://spoonacular.com/recipeImages/664828-31...
# 37  https://spoonacular.com/recipeImages/651076-31...
# 38  https://spoonacular.com/recipeImages/651914-31...
# 39  https://spoonacular.com/recipeImages/663121-31...
# 40  https://spoonacular.com/recipeImages/648774-31...
# 41  https://spoonacular.com/recipeImages/1095880-3...
# 42  https://spoonacular.com/recipeImages/636096-31...
# 43  https://spoonacular.com/recipeImages/655771-31...
#
#                             cuisines  \
# 0   [Mediterranean, European, Greek]
# 1                                 []
# 2                                 []
# 3                    [Indian, Asian]
# 4                         [American]
# 5                                 []
# 6                                 []
# 7                                 []
# 8                                 []
# 9                                 []
# 10                   [Indian, Asian]
# 11  [Mediterranean, European, Greek]
# 12                [German, European]
# 13                   [Indian, Asian]
# 14                                []
# 15                                []
# 16                                []
# 17                                []
# 18  [South American, Latin American]
# 19                   [Indian, Asian]
# 20  [Mediterranean, European, Greek]
# 21                                []
# 22                                []
# 23                                []
# 24                                []
# 25                                []
# 26                                []
# 27                                []
# 28                 [European, Irish]
# 29                                []
# 30                                []
# 31                   [Indian, Asian]
# 32  [Mediterranean, European, Greek]
# 33                  [Middle Eastern]
# 34                                []
# 35                                []
# 36               [Vietnamese, Asian]
# 37  [Mediterranean, European, Greek]
# 38                   [Indian, Asian]
# 39                     [Thai, Asian]
# 40                   [Indian, Asian]
# 41                                []
# 42                 [European, Irish]
# 43                                []
#
#                                  analyzedInstructions  dish
# 0   [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 1   [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 2   [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 3   [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 4   [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 5   [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 6   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 7   [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 8   [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 9   [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 10  [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 11  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 12  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 13  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 14  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 15  [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 16  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 17  [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 18  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 19  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 20  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 21  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 22  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 23  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 24  [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 25  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 26  [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 27  [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 28  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 29  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 30  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 31  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 32  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 33  [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 34  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 35  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 36  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 37  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 38  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 39  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 40  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 41  [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 42  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 43  [{'name': '', 'steps': [{'number': 1, 'step': ...     1

# %%
#Getting ingredients for each recipe
#Ingredients is a list of dictionaries in nutrition key
ingredients_list=[]
recipe_idlist=[]

for recipe in new_res2['results']:
    recipe_id =recipe['id']
    ingres=recipe['nutrition']['ingredients']
    ingri_dict={}
    for ingredient_dict in ingres:
        name=ingredient_dict['name']
        amount=ingredient_dict['amount']
        unit=ingredient_dict['unit']
        value=str(round(amount,2))+' '+unit 
        ingri_dict[name]=value
    ingredients_list.append(ingri_dict)
    recipe_idlist.append(recipe_id)

# %%
ingredient_names=[]
for i in range(0,44):
    ingredients=list(ingredients_list[i])
    ingredient_names.append(ingredients)
len(ingredient_names)
# Out:
# 44

# %%
recipe6_df['ingredients']=ingredients_list

# %%
recipe6_df['grocery']=ingredient_names
recipe6_df
# Out:
#          id                                              title  \
# 0    649225                                      Lamb Moussaka
# 1    649196                                      Lamb Chop Fry
# 2    649248                                   Lamb Tagine Stew
# 3    649199                                  Lamb Chops Masala
# 4    649182                             Lamb and Bacon Burgers
# 5    649186                             Lamb and Mushroom Stew
# 6    649214                             Lamb In Red Mole Sauce
# 7    157834                           LAMB AND KIDNEY HOT- POT
# 8    649178                        Lamb & Sweet Potato Pot Pie
# 9    649187                      Lamb and Rice Noodle Stir Fry
# 10   716338                    Lamb Coconut Tomato Curry Sauce
# 11   649195                   Lamb Burgers With Tzatziki Sauce
# 12   649183                 Lamb and Fresh Goat Cheese Roulade
# 13   651180                                  Masala Lamb Chops
# 14   660961  Spiced Lamb Meatballs With Lemon Mint Yogurt S...
# 15   641079                                 Curried Lamb Tarts
# 16   635834                                 Braised Lamb Chops
# 17   657710                          Rack of Lamb With Parsley
# 18   654432  Pan Seared Lamb Loin With Chimichurri & Roaste...
# 19   660290                             Slow Cooker Lamb Curry
# 20   644889                          Gluten-Free Lamb Moussaka
# 21  1096265                    Slow Cooker Lamb Beet Meatballs
# 22   632901                          Asian-Braised Lamb Shanks
# 23   665550                      Yogurt Marinated Lamb Skewers
# 24   633932                      Balsamic Marinated Lamb Chops
# 25  1098301  Slow Braised Red Wine Lamb Stew with Moroccan ...
# 26  1697565                      Grilled Marinated Leg of Lamb
# 27   641973  Easy Garlic Roast Leg Of Lamb With Rosemary an...
# 28   642091       Easy Shepherd's Pie (Beef And/or Lamb Combo)
# 29  1052360  The Secret to the Best Ever Instant Pot Lamb Stew
# 30   649254                Lamb’s Lettuce & Crispy Bacon Salad
# 31   654313      Pachai Payaru Kulambu (Green Moong Dal Curry)
# 32   646071                                              Gyros
# 33   649403                                    Lebanese Kibbeh
# 34    57810                                   Choucroute Garni
# 35   637275                                   Cassoulet for 10
# 36   664828                                 Vietnamese Banh Mi
# 37   651076                                 Marinated Souvlaki
# 38   651914                                Minced Mutton Curry
# 39   663121                                Thai Massaman Curry
# 40   648774                                Kashmiri Rogan Josh
# 41  1095880                                Easy Shepherd’s Pie
# 42   636096                     Bridget Jones's Shepherd's Pie
# 43   655771               Persian Rhubarb Stew (Khoresh Rivas)
#
#     readyInMinutes  servings  \
# 0               45        12
# 1               45        10
# 2               45         4
# 3               45         1
# 4               45         6
# 5               45         6
# 6               45         4
# 7               90         4
# 8               45         8
# 9               45         4
# 10              45         3
# 11              45         4
# 12              45         6
# 13              45         2
# 14              45         4
# 15              45         6
# 16              45         4
# 17              45         4
# 18              45         4
# 19              45         8
# 20              45         4
# 21             210         2
# 22              45         4
# 23              45        12
# 24              45         2
# 25             155         4
# 26              45         4
# 27              45         8
# 28              45         6
# 29              40         8
# 30              45         2
# 31              45         4
# 32              45         6
# 33              45         6
# 34              45         4
# 35              45        10
# 36              45         6
# 37              45         6
# 38              45         4
# 39              45         5
# 40              45         6
# 41              75         4
# 42              45         4
# 43              45         6
#
#                                                 image  \
# 0   https://spoonacular.com/recipeImages/649225-31...
# 1   https://spoonacular.com/recipeImages/649196-31...
# 2   https://spoonacular.com/recipeImages/649248-31...
# 3   https://spoonacular.com/recipeImages/649199-31...
# 4   https://spoonacular.com/recipeImages/649182-31...
# 5   https://spoonacular.com/recipeImages/649186-31...
# 6   https://spoonacular.com/recipeImages/649214-31...
# 7   https://spoonacular.com/recipeImages/157834-31...
# 8   https://spoonacular.com/recipeImages/649178-31...
# 9   https://spoonacular.com/recipeImages/649187-31...
# 10  https://spoonacular.com/recipeImages/716338-31...
# 11  https://spoonacular.com/recipeImages/649195-31...
# 12  https://spoonacular.com/recipeImages/649183-31...
# 13  https://spoonacular.com/recipeImages/651180-31...
# 14  https://spoonacular.com/recipeImages/660961-31...
# 15  https://spoonacular.com/recipeImages/641079-31...
# 16  https://spoonacular.com/recipeImages/635834-31...
# 17  https://spoonacular.com/recipeImages/657710-31...
# 18  https://spoonacular.com/recipeImages/654432-31...
# 19  https://spoonacular.com/recipeImages/660290-31...
# 20  https://spoonacular.com/recipeImages/644889-31...
# 21  https://spoonacular.com/recipeImages/1096265-3...
# 22  https://spoonacular.com/recipeImages/632901-31...
# 23  https://spoonacular.com/recipeImages/665550-31...
# 24  https://spoonacular.com/recipeImages/633932-31...
# 25  https://spoonacular.com/recipeImages/1098301-3...
# 26  https://spoonacular.com/recipeImages/1697565-3...
# 27  https://spoonacular.com/recipeImages/641973-31...
# 28  https://spoonacular.com/recipeImages/642091-31...
# 29  https://spoonacular.com/recipeImages/1052360-3...
# 30  https://spoonacular.com/recipeImages/649254-31...
# 31  https://spoonacular.com/recipeImages/654313-31...
# 32  https://spoonacular.com/recipeImages/646071-31...
# 33  https://spoonacular.com/recipeImages/649403-31...
# 34  https://spoonacular.com/recipeImages/57810-312...
# 35  https://spoonacular.com/recipeImages/637275-31...
# 36  https://spoonacular.com/recipeImages/664828-31...
# 37  https://spoonacular.com/recipeImages/651076-31...
# 38  https://spoonacular.com/recipeImages/651914-31...
# 39  https://spoonacular.com/recipeImages/663121-31...
# 40  https://spoonacular.com/recipeImages/648774-31...
# 41  https://spoonacular.com/recipeImages/1095880-3...
# 42  https://spoonacular.com/recipeImages/636096-31...
# 43  https://spoonacular.com/recipeImages/655771-31...
#
#                             cuisines  \
# 0   [Mediterranean, European, Greek]
# 1                                 []
# 2                                 []
# 3                    [Indian, Asian]
# 4                         [American]
# 5                                 []
# 6                                 []
# 7                                 []
# 8                                 []
# 9                                 []
# 10                   [Indian, Asian]
# 11  [Mediterranean, European, Greek]
# 12                [German, European]
# 13                   [Indian, Asian]
# 14                                []
# 15                                []
# 16                                []
# 17                                []
# 18  [South American, Latin American]
# 19                   [Indian, Asian]
# 20  [Mediterranean, European, Greek]
# 21                                []
# 22                                []
# 23                                []
# 24                                []
# 25                                []
# 26                                []
# 27                                []
# 28                 [European, Irish]
# 29                                []
# 30                                []
# 31                   [Indian, Asian]
# 32  [Mediterranean, European, Greek]
# 33                  [Middle Eastern]
# 34                                []
# 35                                []
# 36               [Vietnamese, Asian]
# 37  [Mediterranean, European, Greek]
# 38                   [Indian, Asian]
# 39                     [Thai, Asian]
# 40                   [Indian, Asian]
# 41                                []
# 42                 [European, Irish]
# 43                                []
#
#                                  analyzedInstructions  dish  \
# 0   [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 1   [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 2   [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 3   [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 4   [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 5   [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 6   [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 7   [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 8   [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 9   [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 10  [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 11  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 12  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 13  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 14  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 15  [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 16  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 17  [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 18  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 19  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 20  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 21  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 22  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 23  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 24  [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 25  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 26  [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 27  [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 28  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 29  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 30  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 31  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 32  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 33  [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 34  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 35  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 36  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 37  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 38  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 39  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 40  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 41  [{'name': '', 'steps': [{'number': 1, 'step': ...     0
# 42  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
# 43  [{'name': '', 'steps': [{'number': 1, 'step': ...     1
#
#                                           ingredients  \
# 0   {'all purpose flour': '0.04 cup', 'canned toma...
# 1   {'chillies': '0.4 ', 'curry powder': '0.2 tabl...
# 2   {'black pepper': '0.13 teaspoon', 'carrot': '1...
# 3   {'cayenne': '1.0 tablespoon', 'coriander': '1....
# 4   {'bacon': '0.5 strips', 'breadcrumbs': '0.33 o...
# 5   {'bell pepper': '1.0 servings', 'carrots': '0....
# 6   {'chipotle peppers': '0.5 ', 'peppers': '0.5 '...
# 7   {'butter': '6.25 g', 'ground pepper': '1.0 ser...
# 8   {'bay leaf': '0.13 ', 'black pepper': '0.06 ta...
# 9   {'baby corn': '31.25 grams', 'bean sprouts': '...
# 10  {'coconut milk': '0.33 cup', 'curry powder': '...
# 11  {'cucumber': '0.25 ', 'egg': '0.25 ', 'extra v...
# 12  {'goat cheese': '0.67 oz', 'lamb': '2.67 ounce...
# 13  {'cumin': '1.5 teaspoons', 'fresh cilantro': '...
# 14  {'curry powder': '0.5 tsp', 'extra virgin oliv...
# 15  {'vegetable oil': '0.33 tbsp', 'cumin seeds': ...
# 16  {'lamb chops': '1.0 ', 'mint leaves': '0.25 te...
# 17  {'rack of lamb': '0.25 ', 'peanut oil': '0.25 ...
# 18  {'cilantro': '0.06 cup', 'extra virgin olive o...
# 19  {'baking potatoes': '0.25 ', 'beef broth': '0....
# 20  {'eggplants': '0.5 large', 'olive oil': '0.5 t...
# 21  {'ground lamb': '7.0 oz', 'olive oil': '1.5 Ta...
# 22  {'beer': '0.25 bottle', 'brown sugar': '0.5 te...
# 23  {'cooking oil': '0.42 tablespoons', 'cumin': '...
# 24  {'lamb loin chops': '2.0 ', 'garlic': '0.5 Clo...
# 25  {'leg of lamb': '0.5 pounds', 'cooking oil': '...
# 26  {'leg of lamb': '0.25 ', 'garlic': '1.5 cloves...
# 27  {'leg of lamb': '1.0 lbs', 'garlic cloves': '0...
# 28  {'beef stock': '0.17 cup', 'butter': '0.33 tab...
# 29  {'avocado oil': '0.13 tablespoon', 'beef stock...
# 30  {'bacon strips': '2.0 ', 'extra virgin olive o...
# 31  {'moong dal': '0.25 cup', 'garlic': '1.25 ', '...
# 32  {'dijon mustard': '0.08 teaspoon', 'garlic': '...
# 33  {'bulgur wheat': '0.13 cup', 'lamb': '1.33 oun...
# 34  {'onion': '0.25 ', 'juniper berries': '0.75 ',...
# 35  {'bread crumbs': '0.2 cups', 'carrots': '0.15 ...
# 36  {'sub rolls': '1.0 ', 'lamb loin': '0.17 pound...
# 37  {'lamb': '0.33 pounds', 'onion': '0.5 ounces',...
# 38  {'cardamon pods': '0.5 ', 'cilantro leaves': '...
# 39  {'lamb': '100.0 g', 'red skin potatoes': '0.4 ...
# 40  {'asafetida': '0.17 ', 'beef broth': '0.61 cup...
# 41  {'potatoes': '225.0 g', 'butter': '20.0 g', 'm...
# 42  {'onions': '0.5 ', 'olive oil': '0.5 tablespoo...
# 43  {'lamb stew meat': '0.25 pounds', 'oil': '0.33...
#
#                                               grocery
# 0   [all purpose flour, canned tomatoes, cup cake,...
# 1   [chillies, curry powder, ginger, juice of lemo...
# 2   [black pepper, carrot, cinnamon, green peas, j...
# 3   [cayenne, coriander, cumin seeds, duck fat, ga...
# 4   [bacon, breadcrumbs, egg, ground lamb, iceberg...
# 5   [bell pepper, carrots, cloves, cornstarch, dry...
# 6   [chipotle peppers, peppers, plum tomatoes, gar...
# 7   [butter, ground pepper, lamb, onions, potatoes...
# 8   [bay leaf, black pepper, butter, caraway seeds...
# 9   [baby corn, bean sprouts, coriander, elk fille...
# 10  [coconut milk, curry powder, garlic, ginger, i...
# 11  [cucumber, egg, extra virgin olive oil, flat l...
# 12  [goat cheese, lamb, olive oil, baby spinach, g...
# 13  [cumin, fresh cilantro, garam masala, garlic c...
# 14  [curry powder, extra virgin olive oil, fresh m...
# 15  [vegetable oil, cumin seeds, garlic, ginger, o...
# 16  [lamb chops, mint leaves, mustard, bell pepper...
# 17  [rack of lamb, peanut oil, salt, pepper, dijon...
# 18  [cilantro, extra virgin olive oil, flat leaf p...
# 19  [baking potatoes, beef broth, butter, cilantro...
# 20  [eggplants, olive oil, lean ground lamb, garli...
# 21  [ground lamb, olive oil, onion, white button m...
# 22  [beer, brown sugar, cinnamon, cinnamon stick, ...
# 23  [cooking oil, cumin, leg of lamb, nutmeg, papr...
# 24  [lamb loin chops, garlic, balsamic vinegar, di...
# 25  [leg of lamb, cooking oil, onion, garlic, dry ...
# 26  [leg of lamb, garlic, coriander seeds, kosher ...
# 27  [leg of lamb, garlic cloves, extra virgin oliv...
# 28  [beef stock, butter, carrot, cream cheese, egg...
# 29  [avocado oil, beef stock, beer, honey, lamb st...
# 30  [bacon strips, extra virgin olive oil, lambs l...
# 31  [moong dal, garlic, shallots, ginger, turmeric...
# 32  [dijon mustard, garlic, ground cumin, ground f...
# 33  [bulgur wheat, lamb, onion, butter, ground pep...
# 34  [onion, juniper berries, garlic, bay leaf, pep...
# 35  [bread crumbs, carrots, chicken broth, duck le...
# 36  [sub rolls, lamb loin, garlic, fish sauce, sug...
# 37  [lamb, onion, carrot, celery, garlic clove, th...
# 38  [cardamon pods, cilantro leaves, cinnamon stic...
# 39  [lamb, red skin potatoes, bay leaves, fish sau...
# 40  [asafetida, beef broth, cayenne pepper, dried ...
# 41  [potatoes, butter, milk, sunflower oil, onion,...
# 42  [onions, olive oil, lamb, plain flour, thyme, ...
# 43  [lamb stew meat, oil, onion, rhubarb, salt and...

# %% [markdown]
# # Extracting Instructions

# %%
recipe_instructions=recipe6_df[['analyzedInstructions','id']]
#recipe_instructions.head

# %%
recipe_inst=[]
for instructions,ids in zip(list(recipe_instructions['analyzedInstructions'].values),list(recipe_instructions['id'].values)):
    #print(instructions,ids)
    #print(instructions[0]['steps'])
    instruct={}
    recipe_step=''
    try:
    #break   
        for no_steps in range(len(instructions[0]['steps'])):
            #print(no_steps)
            recipe_step+=instructions[0]['steps'][no_steps]['step']    
            #break
            #print(recipe_step)
        instruct[ids]=recipe_step
        #print(instruct)
        recipe_inst.append(instruct)
    except:
        pass

# %%
instruction_final=pd.DataFrame()
for dict_recipe in recipe_inst:
    df=pd.DataFrame(dict_recipe,index=dict_recipe.keys())
    df.columns=['instructions']
    #print(df)
    #break
    instruction_final=pd.concat([instruction_final,df],ignore_index=False,axis=0)

# %%
instruction_final.index.names = ['id']
#instruction_final

# %%
recipe6_df=recipe6_df.merge(instruction_final,on='id')
recipe6_df.drop(columns=['analyzedInstructions'],inplace=True)

# %%
recipe6_df
# Out:
#          id                                              title  \
# 0    649225                                      Lamb Moussaka
# 1    649196                                      Lamb Chop Fry
# 2    649248                                   Lamb Tagine Stew
# 3    649199                                  Lamb Chops Masala
# 4    649182                             Lamb and Bacon Burgers
# 5    649186                             Lamb and Mushroom Stew
# 6    649214                             Lamb In Red Mole Sauce
# 7    157834                           LAMB AND KIDNEY HOT- POT
# 8    649178                        Lamb & Sweet Potato Pot Pie
# 9    649187                      Lamb and Rice Noodle Stir Fry
# 10   716338                    Lamb Coconut Tomato Curry Sauce
# 11   649195                   Lamb Burgers With Tzatziki Sauce
# 12   649183                 Lamb and Fresh Goat Cheese Roulade
# 13   651180                                  Masala Lamb Chops
# 14   660961  Spiced Lamb Meatballs With Lemon Mint Yogurt S...
# 15   641079                                 Curried Lamb Tarts
# 16   635834                                 Braised Lamb Chops
# 17   657710                          Rack of Lamb With Parsley
# 18   654432  Pan Seared Lamb Loin With Chimichurri & Roaste...
# 19   660290                             Slow Cooker Lamb Curry
# 20   644889                          Gluten-Free Lamb Moussaka
# 21  1096265                    Slow Cooker Lamb Beet Meatballs
# 22   632901                          Asian-Braised Lamb Shanks
# 23   665550                      Yogurt Marinated Lamb Skewers
# 24   633932                      Balsamic Marinated Lamb Chops
# 25  1098301  Slow Braised Red Wine Lamb Stew with Moroccan ...
# 26  1697565                      Grilled Marinated Leg of Lamb
# 27   641973  Easy Garlic Roast Leg Of Lamb With Rosemary an...
# 28   642091       Easy Shepherd's Pie (Beef And/or Lamb Combo)
# 29  1052360  The Secret to the Best Ever Instant Pot Lamb Stew
# 30   649254                Lamb’s Lettuce & Crispy Bacon Salad
# 31   654313      Pachai Payaru Kulambu (Green Moong Dal Curry)
# 32   646071                                              Gyros
# 33   649403                                    Lebanese Kibbeh
# 34    57810                                   Choucroute Garni
# 35   637275                                   Cassoulet for 10
# 36   664828                                 Vietnamese Banh Mi
# 37   651076                                 Marinated Souvlaki
# 38   651914                                Minced Mutton Curry
# 39   663121                                Thai Massaman Curry
# 40   648774                                Kashmiri Rogan Josh
# 41  1095880                                Easy Shepherd’s Pie
# 42   636096                     Bridget Jones's Shepherd's Pie
# 43   655771               Persian Rhubarb Stew (Khoresh Rivas)
#
#     readyInMinutes  servings  \
# 0               45        12
# 1               45        10
# 2               45         4
# 3               45         1
# 4               45         6
# 5               45         6
# 6               45         4
# 7               90         4
# 8               45         8
# 9               45         4
# 10              45         3
# 11              45         4
# 12              45         6
# 13              45         2
# 14              45         4
# 15              45         6
# 16              45         4
# 17              45         4
# 18              45         4
# 19              45         8
# 20              45         4
# 21             210         2
# 22              45         4
# 23              45        12
# 24              45         2
# 25             155         4
# 26              45         4
# 27              45         8
# 28              45         6
# 29              40         8
# 30              45         2
# 31              45         4
# 32              45         6
# 33              45         6
# 34              45         4
# 35              45        10
# 36              45         6
# 37              45         6
# 38              45         4
# 39              45         5
# 40              45         6
# 41              75         4
# 42              45         4
# 43              45         6
#
#                                                 image  \
# 0   https://spoonacular.com/recipeImages/649225-31...
# 1   https://spoonacular.com/recipeImages/649196-31...
# 2   https://spoonacular.com/recipeImages/649248-31...
# 3   https://spoonacular.com/recipeImages/649199-31...
# 4   https://spoonacular.com/recipeImages/649182-31...
# 5   https://spoonacular.com/recipeImages/649186-31...
# 6   https://spoonacular.com/recipeImages/649214-31...
# 7   https://spoonacular.com/recipeImages/157834-31...
# 8   https://spoonacular.com/recipeImages/649178-31...
# 9   https://spoonacular.com/recipeImages/649187-31...
# 10  https://spoonacular.com/recipeImages/716338-31...
# 11  https://spoonacular.com/recipeImages/649195-31...
# 12  https://spoonacular.com/recipeImages/649183-31...
# 13  https://spoonacular.com/recipeImages/651180-31...
# 14  https://spoonacular.com/recipeImages/660961-31...
# 15  https://spoonacular.com/recipeImages/641079-31...
# 16  https://spoonacular.com/recipeImages/635834-31...
# 17  https://spoonacular.com/recipeImages/657710-31...
# 18  https://spoonacular.com/recipeImages/654432-31...
# 19  https://spoonacular.com/recipeImages/660290-31...
# 20  https://spoonacular.com/recipeImages/644889-31...
# 21  https://spoonacular.com/recipeImages/1096265-3...
# 22  https://spoonacular.com/recipeImages/632901-31...
# 23  https://spoonacular.com/recipeImages/665550-31...
# 24  https://spoonacular.com/recipeImages/633932-31...
# 25  https://spoonacular.com/recipeImages/1098301-3...
# 26  https://spoonacular.com/recipeImages/1697565-3...
# 27  https://spoonacular.com/recipeImages/641973-31...
# 28  https://spoonacular.com/recipeImages/642091-31...
# 29  https://spoonacular.com/recipeImages/1052360-3...
# 30  https://spoonacular.com/recipeImages/649254-31...
# 31  https://spoonacular.com/recipeImages/654313-31...
# 32  https://spoonacular.com/recipeImages/646071-31...
# 33  https://spoonacular.com/recipeImages/649403-31...
# 34  https://spoonacular.com/recipeImages/57810-312...
# 35  https://spoonacular.com/recipeImages/637275-31...
# 36  https://spoonacular.com/recipeImages/664828-31...
# 37  https://spoonacular.com/recipeImages/651076-31...
# 38  https://spoonacular.com/recipeImages/651914-31...
# 39  https://spoonacular.com/recipeImages/663121-31...
# 40  https://spoonacular.com/recipeImages/648774-31...
# 41  https://spoonacular.com/recipeImages/1095880-3...
# 42  https://spoonacular.com/recipeImages/636096-31...
# 43  https://spoonacular.com/recipeImages/655771-31...
#
#                             cuisines  dish  \
# 0   [Mediterranean, European, Greek]     1
# 1                                 []     1
# 2                                 []     1
# 3                    [Indian, Asian]     1
# 4                         [American]     1
# 5                                 []     1
# 6                                 []     0
# 7                                 []     1
# 8                                 []     1
# 9                                 []     1
# 10                   [Indian, Asian]     0
# 11  [Mediterranean, European, Greek]     1
# 12                [German, European]     1
# 13                   [Indian, Asian]     1
# 14                                []     1
# 15                                []     0
# 16                                []     1
# 17                                []     0
# 18  [South American, Latin American]     1
# 19                   [Indian, Asian]     1
# 20  [Mediterranean, European, Greek]     1
# 21                                []     1
# 22                                []     1
# 23                                []     1
# 24                                []     0
# 25                                []     1
# 26                                []     0
# 27                                []     0
# 28                 [European, Irish]     1
# 29                                []     1
# 30                                []     1
# 31                   [Indian, Asian]     1
# 32  [Mediterranean, European, Greek]     1
# 33                  [Middle Eastern]     0
# 34                                []     1
# 35                                []     1
# 36               [Vietnamese, Asian]     1
# 37  [Mediterranean, European, Greek]     1
# 38                   [Indian, Asian]     1
# 39                     [Thai, Asian]     1
# 40                   [Indian, Asian]     1
# 41                                []     0
# 42                 [European, Irish]     1
# 43                                []     1
#
#                                           ingredients  \
# 0   {'all purpose flour': '0.04 cup', 'canned toma...
# 1   {'chillies': '0.4 ', 'curry powder': '0.2 tabl...
# 2   {'black pepper': '0.13 teaspoon', 'carrot': '1...
# 3   {'cayenne': '1.0 tablespoon', 'coriander': '1....
# 4   {'bacon': '0.5 strips', 'breadcrumbs': '0.33 o...
# 5   {'bell pepper': '1.0 servings', 'carrots': '0....
# 6   {'chipotle peppers': '0.5 ', 'peppers': '0.5 '...
# 7   {'butter': '6.25 g', 'ground pepper': '1.0 ser...
# 8   {'bay leaf': '0.13 ', 'black pepper': '0.06 ta...
# 9   {'baby corn': '31.25 grams', 'bean sprouts': '...
# 10  {'coconut milk': '0.33 cup', 'curry powder': '...
# 11  {'cucumber': '0.25 ', 'egg': '0.25 ', 'extra v...
# 12  {'goat cheese': '0.67 oz', 'lamb': '2.67 ounce...
# 13  {'cumin': '1.5 teaspoons', 'fresh cilantro': '...
# 14  {'curry powder': '0.5 tsp', 'extra virgin oliv...
# 15  {'vegetable oil': '0.33 tbsp', 'cumin seeds': ...
# 16  {'lamb chops': '1.0 ', 'mint leaves': '0.25 te...
# 17  {'rack of lamb': '0.25 ', 'peanut oil': '0.25 ...
# 18  {'cilantro': '0.06 cup', 'extra virgin olive o...
# 19  {'baking potatoes': '0.25 ', 'beef broth': '0....
# 20  {'eggplants': '0.5 large', 'olive oil': '0.5 t...
# 21  {'ground lamb': '7.0 oz', 'olive oil': '1.5 Ta...
# 22  {'beer': '0.25 bottle', 'brown sugar': '0.5 te...
# 23  {'cooking oil': '0.42 tablespoons', 'cumin': '...
# 24  {'lamb loin chops': '2.0 ', 'garlic': '0.5 Clo...
# 25  {'leg of lamb': '0.5 pounds', 'cooking oil': '...
# 26  {'leg of lamb': '0.25 ', 'garlic': '1.5 cloves...
# 27  {'leg of lamb': '1.0 lbs', 'garlic cloves': '0...
# 28  {'beef stock': '0.17 cup', 'butter': '0.33 tab...
# 29  {'avocado oil': '0.13 tablespoon', 'beef stock...
# 30  {'bacon strips': '2.0 ', 'extra virgin olive o...
# 31  {'moong dal': '0.25 cup', 'garlic': '1.25 ', '...
# 32  {'dijon mustard': '0.08 teaspoon', 'garlic': '...
# 33  {'bulgur wheat': '0.13 cup', 'lamb': '1.33 oun...
# 34  {'onion': '0.25 ', 'juniper berries': '0.75 ',...
# 35  {'bread crumbs': '0.2 cups', 'carrots': '0.15 ...
# 36  {'sub rolls': '1.0 ', 'lamb loin': '0.17 pound...
# 37  {'lamb': '0.33 pounds', 'onion': '0.5 ounces',...
# 38  {'cardamon pods': '0.5 ', 'cilantro leaves': '...
# 39  {'lamb': '100.0 g', 'red skin potatoes': '0.4 ...
# 40  {'asafetida': '0.17 ', 'beef broth': '0.61 cup...
# 41  {'potatoes': '225.0 g', 'butter': '20.0 g', 'm...
# 42  {'onions': '0.5 ', 'olive oil': '0.5 tablespoo...
# 43  {'lamb stew meat': '0.25 pounds', 'oil': '0.33...
#
#                                               grocery  \
# 0   [all purpose flour, canned tomatoes, cup cake,...
# 1   [chillies, curry powder, ginger, juice of lemo...
# 2   [black pepper, carrot, cinnamon, green peas, j...
# 3   [cayenne, coriander, cumin seeds, duck fat, ga...
# 4   [bacon, breadcrumbs, egg, ground lamb, iceberg...
# 5   [bell pepper, carrots, cloves, cornstarch, dry...
# 6   [chipotle peppers, peppers, plum tomatoes, gar...
# 7   [butter, ground pepper, lamb, onions, potatoes...
# 8   [bay leaf, black pepper, butter, caraway seeds...
# 9   [baby corn, bean sprouts, coriander, elk fille...
# 10  [coconut milk, curry powder, garlic, ginger, i...
# 11  [cucumber, egg, extra virgin olive oil, flat l...
# 12  [goat cheese, lamb, olive oil, baby spinach, g...
# 13  [cumin, fresh cilantro, garam masala, garlic c...
# 14  [curry powder, extra virgin olive oil, fresh m...
# 15  [vegetable oil, cumin seeds, garlic, ginger, o...
# 16  [lamb chops, mint leaves, mustard, bell pepper...
# 17  [rack of lamb, peanut oil, salt, pepper, dijon...
# 18  [cilantro, extra virgin olive oil, flat leaf p...
# 19  [baking potatoes, beef broth, butter, cilantro...
# 20  [eggplants, olive oil, lean ground lamb, garli...
# 21  [ground lamb, olive oil, onion, white button m...
# 22  [beer, brown sugar, cinnamon, cinnamon stick, ...
# 23  [cooking oil, cumin, leg of lamb, nutmeg, papr...
# 24  [lamb loin chops, garlic, balsamic vinegar, di...
# 25  [leg of lamb, cooking oil, onion, garlic, dry ...
# 26  [leg of lamb, garlic, coriander seeds, kosher ...
# 27  [leg of lamb, garlic cloves, extra virgin oliv...
# 28  [beef stock, butter, carrot, cream cheese, egg...
# 29  [avocado oil, beef stock, beer, honey, lamb st...
# 30  [bacon strips, extra virgin olive oil, lambs l...
# 31  [moong dal, garlic, shallots, ginger, turmeric...
# 32  [dijon mustard, garlic, ground cumin, ground f...
# 33  [bulgur wheat, lamb, onion, butter, ground pep...
# 34  [onion, juniper berries, garlic, bay leaf, pep...
# 35  [bread crumbs, carrots, chicken broth, duck le...
# 36  [sub rolls, lamb loin, garlic, fish sauce, sug...
# 37  [lamb, onion, carrot, celery, garlic clove, th...
# 38  [cardamon pods, cilantro leaves, cinnamon stic...
# 39  [lamb, red skin potatoes, bay leaves, fish sau...
# 40  [asafetida, beef broth, cayenne pepper, dried ...
# 41  [potatoes, butter, milk, sunflower oil, onion,...
# 42  [onions, olive oil, lamb, plain flour, thyme, ...
# 43  [lamb stew meat, oil, onion, rhubarb, salt and...
#
#                                          instructions
# 0   CUT eggplant into 1/4" (5mm) thick slices.Laye...
# 1   Wash the lamb chops,pat dry, keep aside, ,grin...
# 2   Saute lamb chops in 2 teaspoons of olive oil.P...
# 3   Here's a tasty Punjabi recipe for lamb chops. ...
# 4   In a large bowl, mix together the lamb, breadc...
# 5   In a 6-quart pressure cooker over high heat, f...
# 6   To make mole sauce, soak chipotle peppers in h...
# 7   Heat the oven to 160 c. gas markTrim the piece...
# 8   Start with crust.Combine flour, sugar, rosemar...
# 9   Heat the wok on the floor of the roasting oven...
# 10  Wash your lamb and season with seasoning cubes...
# 11  For the lamb burger, mix 1 pound ground lamb, ...
# 12  Heat 2 tbsp. olive oil in a saut pan over medi...
# 13  Put the coriander, cumin powder, garam masala,...
# 14  To make sauce, combine all sauce ingredients (...
# 15  Warm oil in a non-stick skillet over medium hi...
# 16  Season lamb chops with mint, mustard and peppe...
# 17  Preheat the oven to 40Brush the rack with oil,...
# 18  Preheat oven to 400F.For the Chimichurri, plac...
# 19  Pull out your slow cooker and add everything i...
# 20  Lay the eggplant slices in a single layer over...
# 21  Season the ground lamb with salt and form into...
# 22  Heat large skillet over med-hi heat with oil.C...
# 23  Bone the lamb and cut into 1" cubes.Combine al...
# 24  In a mixing bowl, mix above ingredients, excep...
# 25  Preheat oven to 300 F.I used a cast iron dutch...
# 26  Start a wood or charcoal fireDry and trim leg ...
# 27  With the tip of a small sharp knife, poke hole...
# 28  Boil potatoes in salted water until tender, ab...
# 29  Wash, peel, cut, and prep the vegetables.Heat ...
# 30  Pan fried the bacon strips then set aside to c...
# 31  Add dal, garlic, shallots, ginger, turmeric po...
# 32  Combine ground lamb, water, onion, parsley, or...
# 33  Preheat the oven to 375F degrees. Rinse the bu...
# 34  Cook onions in bacon drippings until tender.Re...
# 35  Rinse beans.Add water to cover. Bring to boil....
# 36  Mix all marinade ingredients (except for pork)...
# 37  Cut the meat into small cubes. In a bowl, pref...
# 38  Heat cooking oil in a pot. Fry cardamon seeds,...
# 39  In the heated oil, fry curry paste till aromat...
# 40  Grind the fennel seeds until find.Put the yogu...
# 41  Peel and dice the potatoes.Boil the potatoes u...
# 42  Preheat the oven to 180 C.In a large frying pa...
# 43  In a pan, heat 2-3 tablespoons of oil and saut...

# %%
#Saving 44 recipes dataframe to a csv
recipe6_df.to_csv('./all_recipes/recipe6.csv',index=False)

# %% [markdown]
# # scraping nutrition data

# %%
nutri_list =[]
id_list=[]
for recipe in new_res2['results']:
    recipe_id =recipe['id']
    nutrients =recipe['nutrition']['nutrients']
    nutri_dict={}
    for nutrient_dict in nutrients:
        name = nutrient_dict['name']
        amount = nutrient_dict['amount']
        unit = nutrient_dict['unit']
        #value = str(round(amount,2))+' '+unit
        key=name+' '+unit
        nutri_dict[key]=amount
    nutri_list.append(nutri_dict)
    id_list.append(recipe_id)

# %%
nutrition6_df= pd.DataFrame(nutri_list,index=id_list)
nutrition6_df.index.name='recipe_id'
nutrition6_df.head()
# Out:
#            Calories kcal  Fat g  Saturated Fat g  Carbohydrates g  \
# recipe_id
# 649225            763.16  32.56            10.88            35.64
# 649196            138.47   6.38             2.05             2.62
# 649248            880.02  67.66            25.15            20.05
# 649199            422.46  15.29             8.17            57.10
# 649182            318.45   8.31             1.90            50.71
#
#            Net Carbohydrates g  Sugar g  Cholesterol mg  Sodium mg  Alcohol g  \
# recipe_id
# 649225                   29.69    20.59          261.50    1587.14       1.05
# 649196                    1.92     1.07           51.44     236.10        NaN
# 649248                   14.52     8.10          165.56     704.48        NaN
# 649199                   47.83    32.10           52.03     384.53        NaN
# 649182                   45.51    11.95           34.60     657.30        NaN
#
#            Protein g  ...  Manganese mg  Vitamin C mg  Iron mg  Folate µg  \
# recipe_id             ...
# 649225         78.70  ...          0.60         24.71     4.58     100.48
# 649196         17.23  ...          0.10         27.20     2.05       6.67
# 649248         46.29  ...          0.49         39.80     4.93     103.44
# 649199         20.46  ...          0.89         72.62     3.72     112.34
# 649182         11.55  ...          0.46         28.03    12.40      70.18
#
#            Fiber g  Vitamin A IU  Copper mg  Vitamin E mg  Vitamin D µg  \
# recipe_id
# 649225        5.95       1089.49       0.42          2.94          1.57
# 649196        0.69        183.37       0.14          0.64           NaN
# 649248        5.53      10639.23       0.45          3.04          0.27
# 649199        9.27       4008.23       0.36          2.94          0.39
# 649182        5.20       2001.42       0.17          1.39          0.19
#
#            Caffeine mg
# recipe_id
# 649225             NaN
# 649196             NaN
# 649248             NaN
# 649199             NaN
# 649182             NaN
#
# [5 rows x 33 columns]

# %%
print(nutrition6_df.duplicated().sum())
# Out:
# 0

# %%
#saving the nutrition details of 100 recipes dataframe to csv
nutrition6_df.to_csv('./all_nutrition/nutrition6.csv',index=True)

# %%
#Defining dataframe for ingredients
ingres6_df=pd.DataFrame(ingredients_list,index= recipe_idlist)
ingres6_df.fillna(value=0,inplace=True)
ingres6_df.index.name='recipe_id'
ingres6_df.head()
# Out:
#           all purpose flour canned tomatoes  cup cake dry red wine    egg  \
# recipe_id
# 649225             0.04 cup        0.08 can  0.08 cup     0.04 cup  0.33
# 649196                    0               0         0            0      0
# 649248                    0               0         0            0      0
# 649199                    0               0         0            0      0
# 649182                    0               0         0            0  0.17
#
#               eggplant fat-free milk fat free mozzarella cheese fresh parsley  \
# recipe_id
# 649225     0.21 pounds     0.33 cups                  0.25 cups      0.04 cup
# 649196               0             0                          0             0
# 649248               0             0                          0             0
# 649199               0             0                          0             0
# 649182               0             0                          0             0
#
#                garlic  ... lime rind asafetida cayenne pepper dried ginger  \
# recipe_id              ...
# 649225          0.17   ...         0         0              0            0
# 649196              0  ...         0         0              0            0
# 649248              0  ...         0         0              0            0
# 649199     2.0 Cloves  ...         0         0              0            0
# 649182              0  ...         0         0              0            0
#
#           fennel seeds lamb mince tomato puree worcestershire sauce  \
# recipe_id
# 649225               0          0            0                    0
# 649196               0          0            0                    0
# 649248               0          0            0                    0
# 649199               0          0            0                    0
# 649182               0          0            0                    0
#
#           plain flour rhubarb
# recipe_id
# 649225              0       0
# 649196              0       0
# 649248              0       0
# 649199              0       0
# 649182              0       0
#
# [5 rows x 258 columns]

# %%
#saving the ingredients of 100 recipes dataframe to csv
ingres6_df.to_csv('./all_ingredients/ingredients6.csv',index=True)
